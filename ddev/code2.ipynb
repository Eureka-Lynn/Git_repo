# %%
import pandas as pd

# 读取文件
file_1 = '附件1.xlsx'  # 修改为你本地的文件路径
file_2 = '附件2.xlsx'  # 修改为你本地的文件路径

# 加载Excel文件中的工作表
file_1_data = pd.ExcelFile(file_1)
file_2_data = pd.ExcelFile(file_2)

# 读取2023年农作物种植情况和2023年统计的相关数据
crop_data_2023 = file_2_data.parse('2023年的农作物种植情况')
crop_statistics_2023 = file_2_data.parse('2023年统计的相关数据')

# 计算平均销售价格，处理价格区间以及已经为数字的情况
crop_statistics_2023['平均销售价格'] = crop_statistics_2023['销售单价/(元/斤)'].apply(
    lambda x: (float(x.split('-')[0]) + float(x.split('-')[1])) / 2 if isinstance(x, str) and '-' in x else x)

# 提取关键字段用于分析
crop_summary = crop_statistics_2023[['作物编号', '作物名称', '亩产量/斤', '种植成本/(元/亩)', '平均销售价格']]

# 将2023年种植数据与作物统计数据进行合并
merged_data = pd.merge(crop_data_2023, crop_summary, on='作物编号', how='left')

# 计算每块地的总产量和预期收益
merged_data['总产量/斤'] = merged_data['种植面积/亩'] * merged_data['亩产量/斤']
merged_data['预期收益/元'] = merged_data['总产量/斤'] * merged_data['平均销售价格'] - merged_data['种植面积/亩'] * merged_data['种植成本/(元/亩)']

# 打印合并后的数据
print(merged_data.head())  # 你可以选择将数据保存为文件或进行进一步处理
# Out:
#   种植地块 作物编号 作物名称_x 作物类型  种植面积/亩 种植季次 作物名称_y   亩产量/斤  种植成本/(元/亩)  平均销售价格  \
# 0   A1    6     小麦   粮食    80.0   单季     小麦   800.0       450.0     3.5
# 1   A1    6     小麦   粮食    80.0   单季     小麦   760.0       450.0     3.5
# 2   A1    6     小麦   粮食    80.0   单季     小麦   720.0       450.0     3.5
# 3   A2    7     玉米   粮食    55.0   单季     玉米  1000.0       500.0     3.0
# 4   A2    7     玉米   粮食    55.0   单季     玉米   950.0       500.0     3.0
#
#      总产量/斤    预期收益/元
# 0  64000.0  188000.0
# 1  60800.0  176800.0
# 2  57600.0  165600.0
# 3  55000.0  137500.0
# 4  52250.0  129250.0

# %%
import pulp
# 初始化问题（最大化收益）

model = pulp.LpProblem("Maximize_Crop_Profit_Discount", pulp.LpMaximize)

# 从 merged_data 生成 land_area_dict，确保每个地块都有正确的面积
land_area_dict = merged_data.set_index('种植地块')['种植面积/亩'].to_dict()

# 获取实际数据
plot_codes = merged_data['种植地块'].unique()  # 地块编码
crop_names = merged_data['作物名称_x'].unique()  # 作物名称
crop_yield = merged_data.groupby('作物名称_x')['亩产量/斤'].mean().tolist()  # 每种作物的亩产量
crop_cost = merged_data.groupby('作物名称_x')['种植成本/(元/亩)'].mean().tolist()  # 每种作物的种植成本
crop_price = merged_data.groupby('作物名称_x')['平均销售价格'].mean().tolist()  # 每种作物的销售价格
expected_sales = merged_data.groupby('作物名称_x')['总产量/斤'].mean().tolist()  # 每种作物的预期销售量


# 使用前向填充方法来填充空缺值，确保数据完整性
merged_data.fillna(method='ffill', inplace=True)

# 清理地块编码，确保只有字符串类型的地块编码被处理
plot_codes_clean = [str(plot).strip() if isinstance(plot, str) else str(plot) for plot in plot_codes]

# 筛选出豆类作物
bean_crops = merged_data[merged_data['作物类型'].isin(['粮食（豆类）', '蔬菜（豆类）'])]['作物名称_x'].unique()

# 初始化每个地块的计数器，记录每块地连续多少年没有种植豆类
bean_counter = {plot: 0 for plot in plot_codes_clean}

# 初始化字典来记录上一年每块地种植的作物
previous_year_crops = {}

# 筛选出地块类型
abc_plots = [plot for plot in plot_codes_clean if plot[0] in ['A', 'B', 'C']]
water_irrigated_plots = [plot for plot in plot_codes_clean if plot[0] == 'D']
restricted_crops = ['大白菜', '白萝卜', '红萝卜']
normal_greenhouse_plots = [plot for plot in plot_codes_clean if plot[0] == 'E']
# 筛选出智慧大棚的地块（假设智慧大棚的标识为F）
smart_greenhouse_plots = [plot for plot in plot_codes_clean if plot[0] == 'F']
# 筛选出作物类型为食用菌的作物
mushroom_crops = merged_data[merged_data['作物类型'] == '食用菌']['作物名称_x'].unique()
# 筛选出作物类型为蔬菜的作物
vegetable_data = merged_data[merged_data['作物类型'] == '蔬菜']


# 定义两个季度
seasons = [1, 2]
results = []

sales_normal = pulp.LpVariable.dicts(f"sales_normal",
                                     ((plot, crop, season) for plot in plot_codes_clean for crop in crop_names for season in seasons),
                                     lowBound=0, cat='Continuous')
sales_discounted = pulp.LpVariable.dicts(f"sales_discounted",
                                         ((plot, crop, season) for plot in plot_codes_clean for crop in crop_names for season in seasons),
                                         lowBound=0, cat='Continuous')
crop_binary_vars = pulp.LpVariable.dicts("CropBinaryVars",
                                         ((plot, crop) for plot in plot_codes_clean for crop in crop_names),
                                         cat='Binary')
grain_crops = [crop for crop in crop_names if '水稻' not in crop and '粮食' in merged_data[merged_data['作物名称_x'] == crop]['作物类型'].values]

# 初始化豆类种植的计数器，记录每个地块在过去的年份是否种植过豆类
bean_counter = {plot: 0 for plot in plot_codes_clean}



# 循环优化每年的种植方案（2023-2030）
for year in range(2024, 2031):
    print(f"Optimizing for the year: {year}")

    # 定义一个二进制变量，表示某个地块是否完全种植豆类作物
    bean_planted_full = pulp.LpVariable.dicts(f"bean_planted_full_{year}",
                                            (plot for plot in plot_codes_clean),
                                            cat='Binary')
    # 定义每块地每季度的种植决策变量 x_{plot_code, crop, season}: 每块地 i 在季节 season 种植作物 j 的面积
    crop_vars = pulp.LpVariable.dicts(f"x_{year}",
                                      ((plot, crop, season) for plot in plot_codes_clean for crop in crop_names for season in seasons),
                                      lowBound=0, cat='Continuous')

    # 定义实际销售量 y_{plot_code, crop, season} 用于处理滞销问题
    sales_vars = pulp.LpVariable.dicts(f"y_{year}",
                                       ((plot, crop, season) for plot in plot_codes_clean for crop in crop_names for season in seasons),
                                       lowBound=0, cat='Continuous')

    # 目标函数：最大化每季的收益,增加折价销售部分
    model += pulp.lpSum([sales_normal[plot, crop, season] * crop_price[j]
                     + sales_discounted[plot, crop, season] * (0.5 * crop_price[j])
                     - crop_vars[plot, crop, season] * crop_cost[j]
                     for plot in plot_codes_clean
                     for crop, j in zip(crop_names, range(len(crop_names)))
                     for season in seasons])

    # 添加销售量约束
    for plot in plot_codes_clean:
        for crop, j in zip(crop_names, range(len(crop_names))):
            for season in seasons:
                # 正常销售部分不能超过预期销售量，约束名称加入年份，确保唯一性
                model += sales_normal[plot, crop, season] <= expected_sales[j], f"Sales_Normal_Limit_{plot}_{crop}_{season}_{year}"

                # 总销售量（正常销售+折价销售）不能超过实际产量
                model += sales_normal[plot, crop, season] + sales_discounted[plot, crop, season] <= crop_vars[plot, crop, season] * crop_yield[j], f"Total_Sales_Limit_{plot}_{crop}_{season}_{year}"

                # 折价销售部分为超过预期销售量的部分，使用两条约束来模拟 max(0, 产量 - 预期销售量)
                model += sales_discounted[plot, crop, season] >= 0, f"Discounted_Sales_NonNegative_{plot}_{crop}_{season}_{year}"
                model += sales_discounted[plot, crop, season] >= (crop_vars[plot, crop, season] * crop_yield[j] - expected_sales[j]), f"Discounted_Sales_Limit_{plot}_{crop}_{season}_{year}"


    # 检查三年内是否种植过豆类
    for plot in plot_codes_clean:
        if bean_counter[plot] >= 2:  # 如果三年内没有种植过豆类，强制种植豆类
            print(f"Plot {plot} must plant beans in year {year}.")
            model += pulp.lpSum([crop_vars[plot, crop, season] for crop in bean_crops for season in seasons]) == land_area_dict.get(plot, 0), f"Force_Bean_Planting_{plot}_{year}"
            bean_counter[plot] = 0  # 种植后重置计数器
        else:
            # 如果模型已求解，可以检查种植结果是否为豆类
            if model.status == pulp.LpStatusOptimal:
                planted_beans = any(crop_vars[plot, crop, 1].varValue is not None and crop_vars[plot, crop, 1].varValue > 0
                                    for crop in bean_crops) or any(crop_vars[plot, crop, 2].varValue is not None and crop_vars[plot, crop, 2].varValue > 0
                                    for crop in bean_crops)

                if planted_beans:
                    bean_counter[plot] = 0  # 种植了豆类，计数器归零
                else:
                    bean_counter[plot] += 1  # 没种植豆类，计数器加1

    # 为每个地块添加种植面积总量的约束
    for plot in plot_codes_clean:
        # 计算地块的总种植面积：包括第一季和第二季的所有作物
        total_area_planted = pulp.lpSum([crop_vars[plot, crop, season] for crop in crop_names for season in seasons])
        # 确保总种植面积不能超过该地块的总面积
        model += total_area_planted <= land_area_dict.get(plot, 0), f"Total_Area_Limit_{plot}_{year}"

    # 添加约束：每块地最多种植 3 种作物
    max_crops_per_plot = 3
    for plot in plot_codes_clean:
        # 限制每块地最多种植 max_crops_per_plot 种作物
        model += pulp.lpSum([crop_binary_vars[plot, crop] for crop in crop_names]) <= max_crops_per_plot, f"MaxCrops_{plot}_{year}"

    # 添加约束：实际销售量不能超过预期销售量和种植产量
    for plot in plot_codes_clean:
        for crop, j in zip(crop_names, range(len(crop_names))):
            for season in seasons:
                model += sales_vars[plot, crop, season] <= expected_sales[j], f"Sales_Limit_{plot}_{crop}_{season}_{year}"
                model += sales_vars[plot, crop, season] <= crop_vars[plot, crop, season] * crop_yield[j], f"Yield_Limit_{plot}_{crop}_{season}_{year}"

    # 每块地每季度的种植面积不能超过其总面积
    for plot in plot_codes_clean:
        for season in seasons:
            model += pulp.lpSum([crop_vars[plot, crop, season] for crop in crop_names]) <= land_area_dict.get(plot, 0), f"Land_Limit_{plot}_{season}_{year}"
    # 为平旱地、梯田和山坡地的地块添加约束
    for plot in abc_plots:
        for crop in crop_names:
            # 限制只能种植粮食类作物（不包括水稻）
            if crop in grain_crops:
                # 只允许第一季种植作物，第二季种植面积必须为 0
                model += crop_vars[plot, crop, 2] == 0, f"ABC_Plot_Season2_Zero_{plot}_{crop}_{year}"
            else:
                # 不能种植非粮食作物
                model += crop_vars[plot, crop, 1] == 0, f"ABC_Plot_Grain_Only_{plot}_{crop}_{year}"

    # 在ABC类型地块的season2中不种植作物
    for plot in abc_plots:
        for crop in crop_names:
            model += crop_vars[plot, crop, 2] == 0, f"Season2_Zero_Limit_{plot}_{crop}_{year}"

    # 添加连续两年不能种植同一种作物的约束，按季度进行
    if year > 2023:
        for plot in plot_codes_clean:
            if plot in previous_year_crops:
                for crop in crop_names:
                    for season in seasons:
                        # 如果上一年相同季度种植了某种作物，今年同一季度不能种同一种作物
                        model += crop_vars[plot, crop, season] <= (1 - previous_year_crops[plot][crop, season]) * land_area_dict.get(plot, 0), f"Rotation_Limit_{plot}_{crop}_{season}_{year}"


        # 添加新的约束：水浇地每年可以单季种植水稻或两季种植蔬菜作物
    for plot in water_irrigated_plots:
        for crop in crop_names:
            for season in seasons:
                if '水稻' in crop:
                    # 如果种植水稻，season2 全部设置为 0
                    model += crop_vars[plot, crop, 2] == 0, f"Water_Irrigated_Season2_Zero_{plot}_{crop}_Season_{season}_Year_{year}"
                elif '蔬菜' in crop:
                    # 第一季可以种植任意蔬菜，除大白菜、白萝卜和红萝卜外
                    if season == 1 and crop not in restricted_crops:
                        model += crop_vars[plot, crop, season] >= 0, f"Water_Irrigated_Season1_Veg_{plot}_{crop}_Season_{season}_Year_{year}"
                    # 第二季只能种植大白菜、白萝卜和红萝卜
                    if season == 2 and crop in restricted_crops:
                        model += crop_vars[plot, crop, season] >= 0, f"Water_Irrigated_Season2_RestrictedVeg_{plot}_{crop}_Season_{season}_Year_{year}"

    # 确保第二季只能种植大白菜、白萝卜和红萝卜中的一种
    for plot in water_irrigated_plots:
        # 确保只能种植一种受限制的作物
        model += pulp.lpSum([crop_vars[plot, crop, 2] for crop in restricted_crops]) <= land_area_dict.get(plot, 0), f"Water_Irrigated_Season2_OneCrop_{plot}_Year_{year}"

    # 添加普通大棚的种植约束
    for plot in normal_greenhouse_plots:
        for crop in crop_names:
            for season in seasons:
                if season == 1 and crop not in restricted_crops:
                    # 第一季可以种植任何蔬菜，除大白菜、白萝卜和红萝卜外
                    model += crop_vars[plot, crop, season] >= 0, f"NormalGreenhouse_Season1_Veg_{plot}_{crop}_Season_{season}_Year_{year}"
                elif season == 2 and crop in mushroom_crops:
                    # 第二季只能种植食用菌
                    model += crop_vars[plot, crop, season] >= 0, f"NormalGreenhouse_Season2_Mushroom_{plot}_{crop}_Season_{season}_Year_{year}"
    # 确保第二季只能种植食用菌
    for plot in normal_greenhouse_plots:
        # 确保只能种植食用菌
        model += pulp.lpSum([crop_vars[plot, crop, 2] for crop in mushroom_crops]) <= land_area_dict.get(plot, 0), f"NormalGreenhouse_Season2_OnlyMushroom_{plot}_Year_{year}"
        # 筛选出不包含大白菜、白萝卜和红萝卜的蔬菜作物
    allowed_vegetable_crops = vegetable_data[~vegetable_data['作物名称_x'].isin(restricted_crops)]['作物名称_x'].unique()



    # 应用智慧大棚的种植约束：每年可以种植两季蔬菜，除大白菜、白萝卜和红萝卜外
    for plot in smart_greenhouse_plots:
        for crop in allowed_vegetable_crops:
            for season in seasons:
                # 第一季和第二季都可以种植任意蔬菜，除大白菜、白萝卜和红萝卜外
                model += crop_vars[plot, crop, season] >= 0, f"SmartGreenhouse_Season{season}_Veg_{plot}_{crop}_Year_{year}"


    solver = pulp.PULP_CBC_CMD(msg=True, timeLimit=600)
    model.solve(solver)

    # 在求解之后保存当前年份的种植作物信息，用于下一个年份的轮作限制
    for plot in plot_codes_clean:
        previous_year_crops[plot] = {(crop, season): (crop_vars[plot, crop, season].varValue > 0) for crop in crop_names for season in seasons}

    # 输出每年优化结果
    # print(f"Year {year} results:")
    for plot in plot_codes_clean:
        for crop in crop_names:
            for season in seasons:
                print(f"Plot {plot}, Crop {crop}, Season {season}, Area: {crop_vars[plot, crop, season].varValue}")
    for plot in plot_codes_clean:  # 遍历地块
        for crop in crop_names:  # 遍历作物
            for season in seasons:  # 遍历季次（1, 2）
                # 获取每块地每季的种植面积
                area = crop_vars[plot, crop, season].varValue
                # 如果有种植面积大于0的作物，存储结果
                if area is not None and area > 0:
                    results.append([year, plot, season, crop, area])
# 将结果列表转换为 DataFrame
df_results = pd.DataFrame(results, columns=['年份', '地块', '季次', '作物名称', '种植面积'])

# 查看优化结果 DataFrame
print(df_results)
# 输出总收益
print(f"Maximized Profit for {2023}-{2030}: {pulp.value(model.objective)}")
# Out:
# Optimizing for the year: 2024
# C:\Users\18798\AppData\Local\Temp\ipykernel_10512\2758051839.py:19: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   merged_data.fillna(method='ffill', inplace=True)
# C:\Users\18798\AppData\Local\Temp\ipykernel_10512\2758051839.py:19: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   merged_data.fillna(method='ffill', inplace=True)
# Plot A1, Crop 小麦, Season 1, Area: 0.0
# Plot A1, Crop 小麦, Season 2, Area: 0.0
# Plot A1, Crop 玉米, Season 1, Area: 0.0
# Plot A1, Crop 玉米, Season 2, Area: 0.0
# Plot A1, Crop 黄豆, Season 1, Area: 0.0
# Plot A1, Crop 黄豆, Season 2, Area: 0.0
# Plot A1, Crop 绿豆, Season 1, Area: 0.0
# Plot A1, Crop 绿豆, Season 2, Area: 0.0
# Plot A1, Crop 谷子, Season 1, Area: 0.0
# Plot A1, Crop 谷子, Season 2, Area: 0.0
# Plot A1, Crop 黑豆, Season 1, Area: 0.0
# Plot A1, Crop 黑豆, Season 2, Area: 0.0
# Plot A1, Crop 红豆, Season 1, Area: 0.0
# Plot A1, Crop 红豆, Season 2, Area: 0.0
# Plot A1, Crop 爬豆, Season 1, Area: 0.0
# Plot A1, Crop 爬豆, Season 2, Area: 0.0
# Plot A1, Crop 高粱, Season 1, Area: 80.0
# Plot A1, Crop 高粱, Season 2, Area: 0.0
# Plot A1, Crop 黍子, Season 1, Area: 0.0
# Plot A1, Crop 黍子, Season 2, Area: 0.0
# Plot A1, Crop 莜麦, Season 1, Area: 0.0
# Plot A1, Crop 莜麦, Season 2, Area: 0.0
# Plot A1, Crop 大麦, Season 1, Area: 0.0
# Plot A1, Crop 大麦, Season 2, Area: 0.0
# Plot A1, Crop 荞麦, Season 1, Area: 0.0
# Plot A1, Crop 荞麦, Season 2, Area: 0.0
# Plot A1, Crop 南瓜, Season 1, Area: 0.0
# Plot A1, Crop 南瓜, Season 2, Area: 0.0
# Plot A1, Crop 红薯, Season 1, Area: 0.0
# Plot A1, Crop 红薯, Season 2, Area: 0.0
# Plot A1, Crop 土豆, Season 1, Area: 0.0
# Plot A1, Crop 土豆, Season 2, Area: 0.0
# Plot A1, Crop 白萝卜, Season 1, Area: 0.0
# Plot A1, Crop 白萝卜, Season 2, Area: 0.0
# Plot A1, Crop 小青菜, Season 1, Area: 0.0
# Plot A1, Crop 小青菜, Season 2, Area: 0.0
# Plot A1, Crop 大白菜, Season 1, Area: 0.0
# Plot A1, Crop 大白菜, Season 2, Area: 0.0
# Plot A1, Crop 西红柿, Season 1, Area: 0.0
# Plot A1, Crop 西红柿, Season 2, Area: 0.0
# Plot A1, Crop 茄子, Season 1, Area: 0.0
# Plot A1, Crop 茄子, Season 2, Area: 0.0
# Plot A1, Crop 豇豆, Season 1, Area: 0.0
# Plot A1, Crop 豇豆, Season 2, Area: 0.0
# Plot A1, Crop 刀豆, Season 1, Area: 0.0
# Plot A1, Crop 刀豆, Season 2, Area: 0.0
# Plot A1, Crop 红萝卜, Season 1, Area: 0.0
# Plot A1, Crop 红萝卜, Season 2, Area: 0.0
# Plot A1, Crop 水稻, Season 1, Area: 0.0
# Plot A1, Crop 水稻, Season 2, Area: 0.0
# Plot A1, Crop 榆黄菇, Season 1, Area: 0.0
# Plot A1, Crop 榆黄菇, Season 2, Area: 0.0
# Plot A1, Crop 青椒, Season 1, Area: 0.0
# Plot A1, Crop 青椒, Season 2, Area: 0.0
# Plot A1, Crop 菜花, Season 1, Area: 0.0
# Plot A1, Crop 菜花, Season 2, Area: 0.0
# Plot A1, Crop 包菜, Season 1, Area: 0.0
# Plot A1, Crop 包菜, Season 2, Area: 0.0
# Plot A1, Crop 香菇, Season 1, Area: 0.0
# Plot A1, Crop 香菇, Season 2, Area: 0.0
# Plot A1, Crop 油麦菜, Season 1, Area: 0.0
# Plot A1, Crop 油麦菜, Season 2, Area: 0.0
# Plot A1, Crop 芸豆, Season 1, Area: 0.0
# Plot A1, Crop 芸豆, Season 2, Area: 0.0
# Plot A1, Crop 白灵菇, Season 1, Area: 0.0
# Plot A1, Crop 白灵菇, Season 2, Area: 0.0
# Plot A1, Crop 羊肚菌, Season 1, Area: 0.0
# Plot A1, Crop 羊肚菌, Season 2, Area: 0.0
# Plot A1, Crop 黄瓜, Season 1, Area: 0.0
# Plot A1, Crop 黄瓜, Season 2, Area: 0.0
# Plot A1, Crop 生菜, Season 1, Area: 0.0
# Plot A1, Crop 生菜, Season 2, Area: 0.0
# Plot A1, Crop 辣椒, Season 1, Area: 0.0
# Plot A1, Crop 辣椒, Season 2, Area: 0.0
# Plot A1, Crop 空心菜, Season 1, Area: 0.0
# Plot A1, Crop 空心菜, Season 2, Area: 0.0
# Plot A1, Crop 黄心菜, Season 1, Area: 0.0
# Plot A1, Crop 黄心菜, Season 2, Area: 0.0
# Plot A1, Crop 生菜 , Season 1, Area: 0.0
# Plot A1, Crop 生菜 , Season 2, Area: 0.0
# Plot A1, Crop 芹菜, Season 1, Area: 0.0
# Plot A1, Crop 芹菜, Season 2, Area: 0.0
# Plot A1, Crop 菠菜 , Season 1, Area: 0.0
# Plot A1, Crop 菠菜 , Season 2, Area: 0.0
# Plot A2, Crop 小麦, Season 1, Area: 0.0
# Plot A2, Crop 小麦, Season 2, Area: 0.0
# Plot A2, Crop 玉米, Season 1, Area: 0.0
# Plot A2, Crop 玉米, Season 2, Area: 0.0
# Plot A2, Crop 黄豆, Season 1, Area: 0.0
# Plot A2, Crop 黄豆, Season 2, Area: 0.0
# Plot A2, Crop 绿豆, Season 1, Area: 0.0
# Plot A2, Crop 绿豆, Season 2, Area: 0.0
# Plot A2, Crop 谷子, Season 1, Area: 0.0
# Plot A2, Crop 谷子, Season 2, Area: 0.0
# Plot A2, Crop 黑豆, Season 1, Area: 0.0
# Plot A2, Crop 黑豆, Season 2, Area: 0.0
# Plot A2, Crop 红豆, Season 1, Area: 0.0
# Plot A2, Crop 红豆, Season 2, Area: 0.0
# Plot A2, Crop 爬豆, Season 1, Area: 0.0
# Plot A2, Crop 爬豆, Season 2, Area: 0.0
# Plot A2, Crop 高粱, Season 1, Area: 55.0
# Plot A2, Crop 高粱, Season 2, Area: 0.0
# Plot A2, Crop 黍子, Season 1, Area: 0.0
# Plot A2, Crop 黍子, Season 2, Area: 0.0
# Plot A2, Crop 莜麦, Season 1, Area: 0.0
# Plot A2, Crop 莜麦, Season 2, Area: 0.0
# Plot A2, Crop 大麦, Season 1, Area: 0.0
# Plot A2, Crop 大麦, Season 2, Area: 0.0
# Plot A2, Crop 荞麦, Season 1, Area: 0.0
# Plot A2, Crop 荞麦, Season 2, Area: 0.0
# Plot A2, Crop 南瓜, Season 1, Area: 0.0
# Plot A2, Crop 南瓜, Season 2, Area: 0.0
# Plot A2, Crop 红薯, Season 1, Area: 0.0
# Plot A2, Crop 红薯, Season 2, Area: 0.0
# Plot A2, Crop 土豆, Season 1, Area: 0.0
# Plot A2, Crop 土豆, Season 2, Area: 0.0
# Plot A2, Crop 白萝卜, Season 1, Area: 0.0
# Plot A2, Crop 白萝卜, Season 2, Area: 0.0
# Plot A2, Crop 小青菜, Season 1, Area: 0.0
# Plot A2, Crop 小青菜, Season 2, Area: 0.0
# Plot A2, Crop 大白菜, Season 1, Area: 0.0
# Plot A2, Crop 大白菜, Season 2, Area: 0.0
# Plot A2, Crop 西红柿, Season 1, Area: 0.0
# Plot A2, Crop 西红柿, Season 2, Area: 0.0
# Plot A2, Crop 茄子, Season 1, Area: 0.0
# Plot A2, Crop 茄子, Season 2, Area: 0.0
# Plot A2, Crop 豇豆, Season 1, Area: 0.0
# Plot A2, Crop 豇豆, Season 2, Area: 0.0
# Plot A2, Crop 刀豆, Season 1, Area: 0.0
# Plot A2, Crop 刀豆, Season 2, Area: 0.0
# Plot A2, Crop 红萝卜, Season 1, Area: 0.0
# Plot A2, Crop 红萝卜, Season 2, Area: 0.0
# Plot A2, Crop 水稻, Season 1, Area: 0.0
# Plot A2, Crop 水稻, Season 2, Area: 0.0
# Plot A2, Crop 榆黄菇, Season 1, Area: 0.0
# Plot A2, Crop 榆黄菇, Season 2, Area: 0.0
# Plot A2, Crop 青椒, Season 1, Area: 0.0
# Plot A2, Crop 青椒, Season 2, Area: 0.0
# Plot A2, Crop 菜花, Season 1, Area: 0.0
# Plot A2, Crop 菜花, Season 2, Area: 0.0
# Plot A2, Crop 包菜, Season 1, Area: 0.0
# Plot A2, Crop 包菜, Season 2, Area: 0.0
# Plot A2, Crop 香菇, Season 1, Area: 0.0
# Plot A2, Crop 香菇, Season 2, Area: 0.0
# Plot A2, Crop 油麦菜, Season 1, Area: 0.0
# Plot A2, Crop 油麦菜, Season 2, Area: 0.0
# Plot A2, Crop 芸豆, Season 1, Area: 0.0
# Plot A2, Crop 芸豆, Season 2, Area: 0.0
# Plot A2, Crop 白灵菇, Season 1, Area: 0.0
# Plot A2, Crop 白灵菇, Season 2, Area: 0.0
# Plot A2, Crop 羊肚菌, Season 1, Area: 0.0
# Plot A2, Crop 羊肚菌, Season 2, Area: 0.0
# Plot A2, Crop 黄瓜, Season 1, Area: 0.0
# Plot A2, Crop 黄瓜, Season 2, Area: 0.0
# Plot A2, Crop 生菜, Season 1, Area: 0.0
# Plot A2, Crop 生菜, Season 2, Area: 0.0
# Plot A2, Crop 辣椒, Season 1, Area: 0.0
# Plot A2, Crop 辣椒, Season 2, Area: 0.0
# Plot A2, Crop 空心菜, Season 1, Area: 0.0
# Plot A2, Crop 空心菜, Season 2, Area: 0.0
# Plot A2, Crop 黄心菜, Season 1, Area: 0.0
# Plot A2, Crop 黄心菜, Season 2, Area: 0.0
# Plot A2, Crop 生菜 , Season 1, Area: 0.0
# Plot A2, Crop 生菜 , Season 2, Area: 0.0
# Plot A2, Crop 芹菜, Season 1, Area: 0.0
# Plot A2, Crop 芹菜, Season 2, Area: 0.0
# Plot A2, Crop 菠菜 , Season 1, Area: 0.0
# Plot A2, Crop 菠菜 , Season 2, Area: 0.0
# Plot A3, Crop 小麦, Season 1, Area: 0.0
# Plot A3, Crop 小麦, Season 2, Area: 0.0
# Plot A3, Crop 玉米, Season 1, Area: 0.0
# Plot A3, Crop 玉米, Season 2, Area: 0.0
# Plot A3, Crop 黄豆, Season 1, Area: 0.0
# Plot A3, Crop 黄豆, Season 2, Area: 0.0
# Plot A3, Crop 绿豆, Season 1, Area: 0.0
# Plot A3, Crop 绿豆, Season 2, Area: 0.0
# Plot A3, Crop 谷子, Season 1, Area: 0.0
# Plot A3, Crop 谷子, Season 2, Area: 0.0
# Plot A3, Crop 黑豆, Season 1, Area: 0.0
# Plot A3, Crop 黑豆, Season 2, Area: 0.0
# Plot A3, Crop 红豆, Season 1, Area: 0.0
# Plot A3, Crop 红豆, Season 2, Area: 0.0
# Plot A3, Crop 爬豆, Season 1, Area: 0.0
# Plot A3, Crop 爬豆, Season 2, Area: 0.0
# Plot A3, Crop 高粱, Season 1, Area: 35.0
# Plot A3, Crop 高粱, Season 2, Area: 0.0
# Plot A3, Crop 黍子, Season 1, Area: 0.0
# Plot A3, Crop 黍子, Season 2, Area: 0.0
# Plot A3, Crop 莜麦, Season 1, Area: 0.0
# Plot A3, Crop 莜麦, Season 2, Area: 0.0
# Plot A3, Crop 大麦, Season 1, Area: 0.0
# Plot A3, Crop 大麦, Season 2, Area: 0.0
# Plot A3, Crop 荞麦, Season 1, Area: 0.0
# Plot A3, Crop 荞麦, Season 2, Area: 0.0
# Plot A3, Crop 南瓜, Season 1, Area: 0.0
# Plot A3, Crop 南瓜, Season 2, Area: 0.0
# Plot A3, Crop 红薯, Season 1, Area: 0.0
# Plot A3, Crop 红薯, Season 2, Area: 0.0
# Plot A3, Crop 土豆, Season 1, Area: 0.0
# Plot A3, Crop 土豆, Season 2, Area: 0.0
# Plot A3, Crop 白萝卜, Season 1, Area: 0.0
# Plot A3, Crop 白萝卜, Season 2, Area: 0.0
# Plot A3, Crop 小青菜, Season 1, Area: 0.0
# Plot A3, Crop 小青菜, Season 2, Area: 0.0
# Plot A3, Crop 大白菜, Season 1, Area: 0.0
# Plot A3, Crop 大白菜, Season 2, Area: 0.0
# Plot A3, Crop 西红柿, Season 1, Area: 0.0
# Plot A3, Crop 西红柿, Season 2, Area: 0.0
# Plot A3, Crop 茄子, Season 1, Area: 0.0
# Plot A3, Crop 茄子, Season 2, Area: 0.0
# Plot A3, Crop 豇豆, Season 1, Area: 0.0
# Plot A3, Crop 豇豆, Season 2, Area: 0.0
# Plot A3, Crop 刀豆, Season 1, Area: 0.0
# Plot A3, Crop 刀豆, Season 2, Area: 0.0
# Plot A3, Crop 红萝卜, Season 1, Area: 0.0
# Plot A3, Crop 红萝卜, Season 2, Area: 0.0
# Plot A3, Crop 水稻, Season 1, Area: 0.0
# Plot A3, Crop 水稻, Season 2, Area: 0.0
# Plot A3, Crop 榆黄菇, Season 1, Area: 0.0
# Plot A3, Crop 榆黄菇, Season 2, Area: 0.0
# Plot A3, Crop 青椒, Season 1, Area: 0.0
# Plot A3, Crop 青椒, Season 2, Area: 0.0
# Plot A3, Crop 菜花, Season 1, Area: 0.0
# Plot A3, Crop 菜花, Season 2, Area: 0.0
# Plot A3, Crop 包菜, Season 1, Area: 0.0
# Plot A3, Crop 包菜, Season 2, Area: 0.0
# Plot A3, Crop 香菇, Season 1, Area: 0.0
# Plot A3, Crop 香菇, Season 2, Area: 0.0
# Plot A3, Crop 油麦菜, Season 1, Area: 0.0
# Plot A3, Crop 油麦菜, Season 2, Area: 0.0
# Plot A3, Crop 芸豆, Season 1, Area: 0.0
# Plot A3, Crop 芸豆, Season 2, Area: 0.0
# Plot A3, Crop 白灵菇, Season 1, Area: 0.0
# Plot A3, Crop 白灵菇, Season 2, Area: 0.0
# Plot A3, Crop 羊肚菌, Season 1, Area: 0.0
# Plot A3, Crop 羊肚菌, Season 2, Area: 0.0
# Plot A3, Crop 黄瓜, Season 1, Area: 0.0
# Plot A3, Crop 黄瓜, Season 2, Area: 0.0
# Plot A3, Crop 生菜, Season 1, Area: 0.0
# Plot A3, Crop 生菜, Season 2, Area: 0.0
# Plot A3, Crop 辣椒, Season 1, Area: 0.0
# Plot A3, Crop 辣椒, Season 2, Area: 0.0
# Plot A3, Crop 空心菜, Season 1, Area: 0.0
# Plot A3, Crop 空心菜, Season 2, Area: 0.0
# Plot A3, Crop 黄心菜, Season 1, Area: 0.0
# Plot A3, Crop 黄心菜, Season 2, Area: 0.0
# Plot A3, Crop 生菜 , Season 1, Area: 0.0
# Plot A3, Crop 生菜 , Season 2, Area: 0.0
# Plot A3, Crop 芹菜, Season 1, Area: 0.0
# Plot A3, Crop 芹菜, Season 2, Area: 0.0
# Plot A3, Crop 菠菜 , Season 1, Area: 0.0
# Plot A3, Crop 菠菜 , Season 2, Area: 0.0
# Plot A4, Crop 小麦, Season 1, Area: 0.0
# Plot A4, Crop 小麦, Season 2, Area: 0.0
# Plot A4, Crop 玉米, Season 1, Area: 0.0
# Plot A4, Crop 玉米, Season 2, Area: 0.0
# Plot A4, Crop 黄豆, Season 1, Area: 0.0
# Plot A4, Crop 黄豆, Season 2, Area: 0.0
# Plot A4, Crop 绿豆, Season 1, Area: 0.0
# Plot A4, Crop 绿豆, Season 2, Area: 0.0
# Plot A4, Crop 谷子, Season 1, Area: 0.0
# Plot A4, Crop 谷子, Season 2, Area: 0.0
# Plot A4, Crop 黑豆, Season 1, Area: 0.0
# Plot A4, Crop 黑豆, Season 2, Area: 0.0
# Plot A4, Crop 红豆, Season 1, Area: 0.0
# Plot A4, Crop 红豆, Season 2, Area: 0.0
# Plot A4, Crop 爬豆, Season 1, Area: 0.0
# Plot A4, Crop 爬豆, Season 2, Area: 0.0
# Plot A4, Crop 高粱, Season 1, Area: 72.0
# Plot A4, Crop 高粱, Season 2, Area: 0.0
# Plot A4, Crop 黍子, Season 1, Area: 0.0
# Plot A4, Crop 黍子, Season 2, Area: 0.0
# Plot A4, Crop 莜麦, Season 1, Area: 0.0
# Plot A4, Crop 莜麦, Season 2, Area: 0.0
# Plot A4, Crop 大麦, Season 1, Area: 0.0
# Plot A4, Crop 大麦, Season 2, Area: 0.0
# Plot A4, Crop 荞麦, Season 1, Area: 0.0
# Plot A4, Crop 荞麦, Season 2, Area: 0.0
# Plot A4, Crop 南瓜, Season 1, Area: 0.0
# Plot A4, Crop 南瓜, Season 2, Area: 0.0
# Plot A4, Crop 红薯, Season 1, Area: 0.0
# Plot A4, Crop 红薯, Season 2, Area: 0.0
# Plot A4, Crop 土豆, Season 1, Area: 0.0
# Plot A4, Crop 土豆, Season 2, Area: 0.0
# Plot A4, Crop 白萝卜, Season 1, Area: 0.0
# Plot A4, Crop 白萝卜, Season 2, Area: 0.0
# Plot A4, Crop 小青菜, Season 1, Area: 0.0
# Plot A4, Crop 小青菜, Season 2, Area: 0.0
# Plot A4, Crop 大白菜, Season 1, Area: 0.0
# Plot A4, Crop 大白菜, Season 2, Area: 0.0
# Plot A4, Crop 西红柿, Season 1, Area: 0.0
# Plot A4, Crop 西红柿, Season 2, Area: 0.0
# Plot A4, Crop 茄子, Season 1, Area: 0.0
# Plot A4, Crop 茄子, Season 2, Area: 0.0
# Plot A4, Crop 豇豆, Season 1, Area: 0.0
# Plot A4, Crop 豇豆, Season 2, Area: 0.0
# Plot A4, Crop 刀豆, Season 1, Area: 0.0
# Plot A4, Crop 刀豆, Season 2, Area: 0.0
# Plot A4, Crop 红萝卜, Season 1, Area: 0.0
# Plot A4, Crop 红萝卜, Season 2, Area: 0.0
# Plot A4, Crop 水稻, Season 1, Area: 0.0
# Plot A4, Crop 水稻, Season 2, Area: 0.0
# Plot A4, Crop 榆黄菇, Season 1, Area: 0.0
# Plot A4, Crop 榆黄菇, Season 2, Area: 0.0
# Plot A4, Crop 青椒, Season 1, Area: 0.0
# Plot A4, Crop 青椒, Season 2, Area: 0.0
# Plot A4, Crop 菜花, Season 1, Area: 0.0
# Plot A4, Crop 菜花, Season 2, Area: 0.0
# Plot A4, Crop 包菜, Season 1, Area: 0.0
# Plot A4, Crop 包菜, Season 2, Area: 0.0
# Plot A4, Crop 香菇, Season 1, Area: 0.0
# Plot A4, Crop 香菇, Season 2, Area: 0.0
# Plot A4, Crop 油麦菜, Season 1, Area: 0.0
# Plot A4, Crop 油麦菜, Season 2, Area: 0.0
# Plot A4, Crop 芸豆, Season 1, Area: 0.0
# Plot A4, Crop 芸豆, Season 2, Area: 0.0
# Plot A4, Crop 白灵菇, Season 1, Area: 0.0
# Plot A4, Crop 白灵菇, Season 2, Area: 0.0
# Plot A4, Crop 羊肚菌, Season 1, Area: 0.0
# Plot A4, Crop 羊肚菌, Season 2, Area: 0.0
# Plot A4, Crop 黄瓜, Season 1, Area: 0.0
# Plot A4, Crop 黄瓜, Season 2, Area: 0.0
# Plot A4, Crop 生菜, Season 1, Area: 0.0
# Plot A4, Crop 生菜, Season 2, Area: 0.0
# Plot A4, Crop 辣椒, Season 1, Area: 0.0
# Plot A4, Crop 辣椒, Season 2, Area: 0.0
# Plot A4, Crop 空心菜, Season 1, Area: 0.0
# Plot A4, Crop 空心菜, Season 2, Area: 0.0
# Plot A4, Crop 黄心菜, Season 1, Area: 0.0
# Plot A4, Crop 黄心菜, Season 2, Area: 0.0
# Plot A4, Crop 生菜 , Season 1, Area: 0.0
# Plot A4, Crop 生菜 , Season 2, Area: 0.0
# Plot A4, Crop 芹菜, Season 1, Area: 0.0
# Plot A4, Crop 芹菜, Season 2, Area: 0.0
# Plot A4, Crop 菠菜 , Season 1, Area: 0.0
# Plot A4, Crop 菠菜 , Season 2, Area: 0.0
# Plot A5, Crop 小麦, Season 1, Area: 0.0
# Plot A5, Crop 小麦, Season 2, Area: 0.0
# Plot A5, Crop 玉米, Season 1, Area: 0.0
# Plot A5, Crop 玉米, Season 2, Area: 0.0
# Plot A5, Crop 黄豆, Season 1, Area: 0.0
# Plot A5, Crop 黄豆, Season 2, Area: 0.0
# Plot A5, Crop 绿豆, Season 1, Area: 0.0
# Plot A5, Crop 绿豆, Season 2, Area: 0.0
# Plot A5, Crop 谷子, Season 1, Area: 0.0
# Plot A5, Crop 谷子, Season 2, Area: 0.0
# Plot A5, Crop 黑豆, Season 1, Area: 0.0
# Plot A5, Crop 黑豆, Season 2, Area: 0.0
# Plot A5, Crop 红豆, Season 1, Area: 0.0
# Plot A5, Crop 红豆, Season 2, Area: 0.0
# Plot A5, Crop 爬豆, Season 1, Area: 0.0
# Plot A5, Crop 爬豆, Season 2, Area: 0.0
# Plot A5, Crop 高粱, Season 1, Area: 68.0
# Plot A5, Crop 高粱, Season 2, Area: 0.0
# Plot A5, Crop 黍子, Season 1, Area: 0.0
# Plot A5, Crop 黍子, Season 2, Area: 0.0
# Plot A5, Crop 莜麦, Season 1, Area: 0.0
# Plot A5, Crop 莜麦, Season 2, Area: 0.0
# Plot A5, Crop 大麦, Season 1, Area: 0.0
# Plot A5, Crop 大麦, Season 2, Area: 0.0
# Plot A5, Crop 荞麦, Season 1, Area: 0.0
# Plot A5, Crop 荞麦, Season 2, Area: 0.0
# Plot A5, Crop 南瓜, Season 1, Area: 0.0
# Plot A5, Crop 南瓜, Season 2, Area: 0.0
# Plot A5, Crop 红薯, Season 1, Area: 0.0
# Plot A5, Crop 红薯, Season 2, Area: 0.0
# Plot A5, Crop 土豆, Season 1, Area: 0.0
# Plot A5, Crop 土豆, Season 2, Area: 0.0
# Plot A5, Crop 白萝卜, Season 1, Area: 0.0
# Plot A5, Crop 白萝卜, Season 2, Area: 0.0
# Plot A5, Crop 小青菜, Season 1, Area: 0.0
# Plot A5, Crop 小青菜, Season 2, Area: 0.0
# Plot A5, Crop 大白菜, Season 1, Area: 0.0
# Plot A5, Crop 大白菜, Season 2, Area: 0.0
# Plot A5, Crop 西红柿, Season 1, Area: 0.0
# Plot A5, Crop 西红柿, Season 2, Area: 0.0
# Plot A5, Crop 茄子, Season 1, Area: 0.0
# Plot A5, Crop 茄子, Season 2, Area: 0.0
# Plot A5, Crop 豇豆, Season 1, Area: 0.0
# Plot A5, Crop 豇豆, Season 2, Area: 0.0
# Plot A5, Crop 刀豆, Season 1, Area: 0.0
# Plot A5, Crop 刀豆, Season 2, Area: 0.0
# Plot A5, Crop 红萝卜, Season 1, Area: 0.0
# Plot A5, Crop 红萝卜, Season 2, Area: 0.0
# Plot A5, Crop 水稻, Season 1, Area: 0.0
# Plot A5, Crop 水稻, Season 2, Area: 0.0
# Plot A5, Crop 榆黄菇, Season 1, Area: 0.0
# Plot A5, Crop 榆黄菇, Season 2, Area: 0.0
# Plot A5, Crop 青椒, Season 1, Area: 0.0
# Plot A5, Crop 青椒, Season 2, Area: 0.0
# Plot A5, Crop 菜花, Season 1, Area: 0.0
# Plot A5, Crop 菜花, Season 2, Area: 0.0
# Plot A5, Crop 包菜, Season 1, Area: 0.0
# Plot A5, Crop 包菜, Season 2, Area: 0.0
# Plot A5, Crop 香菇, Season 1, Area: 0.0
# Plot A5, Crop 香菇, Season 2, Area: 0.0
# Plot A5, Crop 油麦菜, Season 1, Area: 0.0
# Plot A5, Crop 油麦菜, Season 2, Area: 0.0
# Plot A5, Crop 芸豆, Season 1, Area: 0.0
# Plot A5, Crop 芸豆, Season 2, Area: 0.0
# Plot A5, Crop 白灵菇, Season 1, Area: 0.0
# Plot A5, Crop 白灵菇, Season 2, Area: 0.0
# Plot A5, Crop 羊肚菌, Season 1, Area: 0.0
# Plot A5, Crop 羊肚菌, Season 2, Area: 0.0
# Plot A5, Crop 黄瓜, Season 1, Area: 0.0
# Plot A5, Crop 黄瓜, Season 2, Area: 0.0
# Plot A5, Crop 生菜, Season 1, Area: 0.0
# Plot A5, Crop 生菜, Season 2, Area: 0.0
# Plot A5, Crop 辣椒, Season 1, Area: 0.0
# Plot A5, Crop 辣椒, Season 2, Area: 0.0
# Plot A5, Crop 空心菜, Season 1, Area: 0.0
# Plot A5, Crop 空心菜, Season 2, Area: 0.0
# Plot A5, Crop 黄心菜, Season 1, Area: 0.0
# Plot A5, Crop 黄心菜, Season 2, Area: 0.0
# Plot A5, Crop 生菜 , Season 1, Area: 0.0
# Plot A5, Crop 生菜 , Season 2, Area: 0.0
# Plot A5, Crop 芹菜, Season 1, Area: 0.0
# Plot A5, Crop 芹菜, Season 2, Area: 0.0
# Plot A5, Crop 菠菜 , Season 1, Area: 0.0
# Plot A5, Crop 菠菜 , Season 2, Area: 0.0
# Plot A6, Crop 小麦, Season 1, Area: 0.0
# Plot A6, Crop 小麦, Season 2, Area: 0.0
# Plot A6, Crop 玉米, Season 1, Area: 0.0
# Plot A6, Crop 玉米, Season 2, Area: 0.0
# Plot A6, Crop 黄豆, Season 1, Area: 0.0
# Plot A6, Crop 黄豆, Season 2, Area: 0.0
# Plot A6, Crop 绿豆, Season 1, Area: 0.0
# Plot A6, Crop 绿豆, Season 2, Area: 0.0
# Plot A6, Crop 谷子, Season 1, Area: 0.0
# Plot A6, Crop 谷子, Season 2, Area: 0.0
# Plot A6, Crop 黑豆, Season 1, Area: 0.0
# Plot A6, Crop 黑豆, Season 2, Area: 0.0
# Plot A6, Crop 红豆, Season 1, Area: 0.0
# Plot A6, Crop 红豆, Season 2, Area: 0.0
# Plot A6, Crop 爬豆, Season 1, Area: 0.0
# Plot A6, Crop 爬豆, Season 2, Area: 0.0
# Plot A6, Crop 高粱, Season 1, Area: 55.0
# Plot A6, Crop 高粱, Season 2, Area: 0.0
# Plot A6, Crop 黍子, Season 1, Area: 0.0
# Plot A6, Crop 黍子, Season 2, Area: 0.0
# Plot A6, Crop 莜麦, Season 1, Area: 0.0
# Plot A6, Crop 莜麦, Season 2, Area: 0.0
# Plot A6, Crop 大麦, Season 1, Area: 0.0
# Plot A6, Crop 大麦, Season 2, Area: 0.0
# Plot A6, Crop 荞麦, Season 1, Area: 0.0
# Plot A6, Crop 荞麦, Season 2, Area: 0.0
# Plot A6, Crop 南瓜, Season 1, Area: 0.0
# Plot A6, Crop 南瓜, Season 2, Area: 0.0
# Plot A6, Crop 红薯, Season 1, Area: 0.0
# Plot A6, Crop 红薯, Season 2, Area: 0.0
# Plot A6, Crop 土豆, Season 1, Area: 0.0
# Plot A6, Crop 土豆, Season 2, Area: 0.0
# Plot A6, Crop 白萝卜, Season 1, Area: 0.0
# Plot A6, Crop 白萝卜, Season 2, Area: 0.0
# Plot A6, Crop 小青菜, Season 1, Area: 0.0
# Plot A6, Crop 小青菜, Season 2, Area: 0.0
# Plot A6, Crop 大白菜, Season 1, Area: 0.0
# Plot A6, Crop 大白菜, Season 2, Area: 0.0
# Plot A6, Crop 西红柿, Season 1, Area: 0.0
# Plot A6, Crop 西红柿, Season 2, Area: 0.0
# Plot A6, Crop 茄子, Season 1, Area: 0.0
# Plot A6, Crop 茄子, Season 2, Area: 0.0
# Plot A6, Crop 豇豆, Season 1, Area: 0.0
# Plot A6, Crop 豇豆, Season 2, Area: 0.0
# Plot A6, Crop 刀豆, Season 1, Area: 0.0
# Plot A6, Crop 刀豆, Season 2, Area: 0.0
# Plot A6, Crop 红萝卜, Season 1, Area: 0.0
# Plot A6, Crop 红萝卜, Season 2, Area: 0.0
# Plot A6, Crop 水稻, Season 1, Area: 0.0
# Plot A6, Crop 水稻, Season 2, Area: 0.0
# Plot A6, Crop 榆黄菇, Season 1, Area: 0.0
# Plot A6, Crop 榆黄菇, Season 2, Area: 0.0
# Plot A6, Crop 青椒, Season 1, Area: 0.0
# Plot A6, Crop 青椒, Season 2, Area: 0.0
# Plot A6, Crop 菜花, Season 1, Area: 0.0
# Plot A6, Crop 菜花, Season 2, Area: 0.0
# Plot A6, Crop 包菜, Season 1, Area: 0.0
# Plot A6, Crop 包菜, Season 2, Area: 0.0
# Plot A6, Crop 香菇, Season 1, Area: 0.0
# Plot A6, Crop 香菇, Season 2, Area: 0.0
# Plot A6, Crop 油麦菜, Season 1, Area: 0.0
# Plot A6, Crop 油麦菜, Season 2, Area: 0.0
# Plot A6, Crop 芸豆, Season 1, Area: 0.0
# Plot A6, Crop 芸豆, Season 2, Area: 0.0
# Plot A6, Crop 白灵菇, Season 1, Area: 0.0
# Plot A6, Crop 白灵菇, Season 2, Area: 0.0
# Plot A6, Crop 羊肚菌, Season 1, Area: 0.0
# Plot A6, Crop 羊肚菌, Season 2, Area: 0.0
# Plot A6, Crop 黄瓜, Season 1, Area: 0.0
# Plot A6, Crop 黄瓜, Season 2, Area: 0.0
# Plot A6, Crop 生菜, Season 1, Area: 0.0
# Plot A6, Crop 生菜, Season 2, Area: 0.0
# Plot A6, Crop 辣椒, Season 1, Area: 0.0
# Plot A6, Crop 辣椒, Season 2, Area: 0.0
# Plot A6, Crop 空心菜, Season 1, Area: 0.0
# Plot A6, Crop 空心菜, Season 2, Area: 0.0
# Plot A6, Crop 黄心菜, Season 1, Area: 0.0
# Plot A6, Crop 黄心菜, Season 2, Area: 0.0
# Plot A6, Crop 生菜 , Season 1, Area: 0.0
# Plot A6, Crop 生菜 , Season 2, Area: 0.0
# Plot A6, Crop 芹菜, Season 1, Area: 0.0
# Plot A6, Crop 芹菜, Season 2, Area: 0.0
# Plot A6, Crop 菠菜 , Season 1, Area: 0.0
# Plot A6, Crop 菠菜 , Season 2, Area: 0.0
# Plot B1, Crop 小麦, Season 1, Area: 0.0
# Plot B1, Crop 小麦, Season 2, Area: 0.0
# Plot B1, Crop 玉米, Season 1, Area: 0.0
# Plot B1, Crop 玉米, Season 2, Area: 0.0
# Plot B1, Crop 黄豆, Season 1, Area: 0.0
# Plot B1, Crop 黄豆, Season 2, Area: 0.0
# Plot B1, Crop 绿豆, Season 1, Area: 0.0
# Plot B1, Crop 绿豆, Season 2, Area: 0.0
# Plot B1, Crop 谷子, Season 1, Area: 0.0
# Plot B1, Crop 谷子, Season 2, Area: 0.0
# Plot B1, Crop 黑豆, Season 1, Area: 0.0
# Plot B1, Crop 黑豆, Season 2, Area: 0.0
# Plot B1, Crop 红豆, Season 1, Area: 0.0
# Plot B1, Crop 红豆, Season 2, Area: 0.0
# Plot B1, Crop 爬豆, Season 1, Area: 0.0
# Plot B1, Crop 爬豆, Season 2, Area: 0.0
# Plot B1, Crop 高粱, Season 1, Area: 60.0
# Plot B1, Crop 高粱, Season 2, Area: 0.0
# Plot B1, Crop 黍子, Season 1, Area: 0.0
# Plot B1, Crop 黍子, Season 2, Area: 0.0
# Plot B1, Crop 莜麦, Season 1, Area: 0.0
# Plot B1, Crop 莜麦, Season 2, Area: 0.0
# Plot B1, Crop 大麦, Season 1, Area: 0.0
# Plot B1, Crop 大麦, Season 2, Area: 0.0
# Plot B1, Crop 荞麦, Season 1, Area: 0.0
# Plot B1, Crop 荞麦, Season 2, Area: 0.0
# Plot B1, Crop 南瓜, Season 1, Area: 0.0
# Plot B1, Crop 南瓜, Season 2, Area: 0.0
# Plot B1, Crop 红薯, Season 1, Area: 0.0
# Plot B1, Crop 红薯, Season 2, Area: 0.0
# Plot B1, Crop 土豆, Season 1, Area: 0.0
# Plot B1, Crop 土豆, Season 2, Area: 0.0
# Plot B1, Crop 白萝卜, Season 1, Area: 0.0
# Plot B1, Crop 白萝卜, Season 2, Area: 0.0
# Plot B1, Crop 小青菜, Season 1, Area: 0.0
# Plot B1, Crop 小青菜, Season 2, Area: 0.0
# Plot B1, Crop 大白菜, Season 1, Area: 0.0
# Plot B1, Crop 大白菜, Season 2, Area: 0.0
# Plot B1, Crop 西红柿, Season 1, Area: 0.0
# Plot B1, Crop 西红柿, Season 2, Area: 0.0
# Plot B1, Crop 茄子, Season 1, Area: 0.0
# Plot B1, Crop 茄子, Season 2, Area: 0.0
# Plot B1, Crop 豇豆, Season 1, Area: 0.0
# Plot B1, Crop 豇豆, Season 2, Area: 0.0
# Plot B1, Crop 刀豆, Season 1, Area: 0.0
# Plot B1, Crop 刀豆, Season 2, Area: 0.0
# Plot B1, Crop 红萝卜, Season 1, Area: 0.0
# Plot B1, Crop 红萝卜, Season 2, Area: 0.0
# Plot B1, Crop 水稻, Season 1, Area: 0.0
# Plot B1, Crop 水稻, Season 2, Area: 0.0
# Plot B1, Crop 榆黄菇, Season 1, Area: 0.0
# Plot B1, Crop 榆黄菇, Season 2, Area: 0.0
# Plot B1, Crop 青椒, Season 1, Area: 0.0
# Plot B1, Crop 青椒, Season 2, Area: 0.0
# Plot B1, Crop 菜花, Season 1, Area: 0.0
# Plot B1, Crop 菜花, Season 2, Area: 0.0
# Plot B1, Crop 包菜, Season 1, Area: 0.0
# Plot B1, Crop 包菜, Season 2, Area: 0.0
# Plot B1, Crop 香菇, Season 1, Area: 0.0
# Plot B1, Crop 香菇, Season 2, Area: 0.0
# Plot B1, Crop 油麦菜, Season 1, Area: 0.0
# Plot B1, Crop 油麦菜, Season 2, Area: 0.0
# Plot B1, Crop 芸豆, Season 1, Area: 0.0
# Plot B1, Crop 芸豆, Season 2, Area: 0.0
# Plot B1, Crop 白灵菇, Season 1, Area: 0.0
# Plot B1, Crop 白灵菇, Season 2, Area: 0.0
# Plot B1, Crop 羊肚菌, Season 1, Area: 0.0
# Plot B1, Crop 羊肚菌, Season 2, Area: 0.0
# Plot B1, Crop 黄瓜, Season 1, Area: 0.0
# Plot B1, Crop 黄瓜, Season 2, Area: 0.0
# Plot B1, Crop 生菜, Season 1, Area: 0.0
# Plot B1, Crop 生菜, Season 2, Area: 0.0
# Plot B1, Crop 辣椒, Season 1, Area: 0.0
# Plot B1, Crop 辣椒, Season 2, Area: 0.0
# Plot B1, Crop 空心菜, Season 1, Area: 0.0
# Plot B1, Crop 空心菜, Season 2, Area: 0.0
# Plot B1, Crop 黄心菜, Season 1, Area: 0.0
# Plot B1, Crop 黄心菜, Season 2, Area: 0.0
# Plot B1, Crop 生菜 , Season 1, Area: 0.0
# Plot B1, Crop 生菜 , Season 2, Area: 0.0
# Plot B1, Crop 芹菜, Season 1, Area: 0.0
# Plot B1, Crop 芹菜, Season 2, Area: 0.0
# Plot B1, Crop 菠菜 , Season 1, Area: 0.0
# Plot B1, Crop 菠菜 , Season 2, Area: 0.0
# Plot B2, Crop 小麦, Season 1, Area: 0.0
# Plot B2, Crop 小麦, Season 2, Area: 0.0
# Plot B2, Crop 玉米, Season 1, Area: 0.0
# Plot B2, Crop 玉米, Season 2, Area: 0.0
# Plot B2, Crop 黄豆, Season 1, Area: 0.0
# Plot B2, Crop 黄豆, Season 2, Area: 0.0
# Plot B2, Crop 绿豆, Season 1, Area: 0.0
# Plot B2, Crop 绿豆, Season 2, Area: 0.0
# Plot B2, Crop 谷子, Season 1, Area: 0.0
# Plot B2, Crop 谷子, Season 2, Area: 0.0
# Plot B2, Crop 黑豆, Season 1, Area: 0.0
# Plot B2, Crop 黑豆, Season 2, Area: 0.0
# Plot B2, Crop 红豆, Season 1, Area: 0.0
# Plot B2, Crop 红豆, Season 2, Area: 0.0
# Plot B2, Crop 爬豆, Season 1, Area: 0.0
# Plot B2, Crop 爬豆, Season 2, Area: 0.0
# Plot B2, Crop 高粱, Season 1, Area: 46.0
# Plot B2, Crop 高粱, Season 2, Area: 0.0
# Plot B2, Crop 黍子, Season 1, Area: 0.0
# Plot B2, Crop 黍子, Season 2, Area: 0.0
# Plot B2, Crop 莜麦, Season 1, Area: 0.0
# Plot B2, Crop 莜麦, Season 2, Area: 0.0
# Plot B2, Crop 大麦, Season 1, Area: 0.0
# Plot B2, Crop 大麦, Season 2, Area: 0.0
# Plot B2, Crop 荞麦, Season 1, Area: 0.0
# Plot B2, Crop 荞麦, Season 2, Area: 0.0
# Plot B2, Crop 南瓜, Season 1, Area: 0.0
# Plot B2, Crop 南瓜, Season 2, Area: 0.0
# Plot B2, Crop 红薯, Season 1, Area: 0.0
# Plot B2, Crop 红薯, Season 2, Area: 0.0
# Plot B2, Crop 土豆, Season 1, Area: 0.0
# Plot B2, Crop 土豆, Season 2, Area: 0.0
# Plot B2, Crop 白萝卜, Season 1, Area: 0.0
# Plot B2, Crop 白萝卜, Season 2, Area: 0.0
# Plot B2, Crop 小青菜, Season 1, Area: 0.0
# Plot B2, Crop 小青菜, Season 2, Area: 0.0
# Plot B2, Crop 大白菜, Season 1, Area: 0.0
# Plot B2, Crop 大白菜, Season 2, Area: 0.0
# Plot B2, Crop 西红柿, Season 1, Area: 0.0
# Plot B2, Crop 西红柿, Season 2, Area: 0.0
# Plot B2, Crop 茄子, Season 1, Area: 0.0
# Plot B2, Crop 茄子, Season 2, Area: 0.0
# Plot B2, Crop 豇豆, Season 1, Area: 0.0
# Plot B2, Crop 豇豆, Season 2, Area: 0.0
# Plot B2, Crop 刀豆, Season 1, Area: 0.0
# Plot B2, Crop 刀豆, Season 2, Area: 0.0
# Plot B2, Crop 红萝卜, Season 1, Area: 0.0
# Plot B2, Crop 红萝卜, Season 2, Area: 0.0
# Plot B2, Crop 水稻, Season 1, Area: 0.0
# Plot B2, Crop 水稻, Season 2, Area: 0.0
# Plot B2, Crop 榆黄菇, Season 1, Area: 0.0
# Plot B2, Crop 榆黄菇, Season 2, Area: 0.0
# Plot B2, Crop 青椒, Season 1, Area: 0.0
# Plot B2, Crop 青椒, Season 2, Area: 0.0
# Plot B2, Crop 菜花, Season 1, Area: 0.0
# Plot B2, Crop 菜花, Season 2, Area: 0.0
# Plot B2, Crop 包菜, Season 1, Area: 0.0
# Plot B2, Crop 包菜, Season 2, Area: 0.0
# Plot B2, Crop 香菇, Season 1, Area: 0.0
# Plot B2, Crop 香菇, Season 2, Area: 0.0
# Plot B2, Crop 油麦菜, Season 1, Area: 0.0
# Plot B2, Crop 油麦菜, Season 2, Area: 0.0
# Plot B2, Crop 芸豆, Season 1, Area: 0.0
# Plot B2, Crop 芸豆, Season 2, Area: 0.0
# Plot B2, Crop 白灵菇, Season 1, Area: 0.0
# Plot B2, Crop 白灵菇, Season 2, Area: 0.0
# Plot B2, Crop 羊肚菌, Season 1, Area: 0.0
# Plot B2, Crop 羊肚菌, Season 2, Area: 0.0
# Plot B2, Crop 黄瓜, Season 1, Area: 0.0
# Plot B2, Crop 黄瓜, Season 2, Area: 0.0
# Plot B2, Crop 生菜, Season 1, Area: 0.0
# Plot B2, Crop 生菜, Season 2, Area: 0.0
# Plot B2, Crop 辣椒, Season 1, Area: 0.0
# Plot B2, Crop 辣椒, Season 2, Area: 0.0
# Plot B2, Crop 空心菜, Season 1, Area: 0.0
# Plot B2, Crop 空心菜, Season 2, Area: 0.0
# Plot B2, Crop 黄心菜, Season 1, Area: 0.0
# Plot B2, Crop 黄心菜, Season 2, Area: 0.0
# Plot B2, Crop 生菜 , Season 1, Area: 0.0
# Plot B2, Crop 生菜 , Season 2, Area: 0.0
# Plot B2, Crop 芹菜, Season 1, Area: 0.0
# Plot B2, Crop 芹菜, Season 2, Area: 0.0
# Plot B2, Crop 菠菜 , Season 1, Area: 0.0
# Plot B2, Crop 菠菜 , Season 2, Area: 0.0
# Plot B3, Crop 小麦, Season 1, Area: 0.0
# Plot B3, Crop 小麦, Season 2, Area: 0.0
# Plot B3, Crop 玉米, Season 1, Area: 0.0
# Plot B3, Crop 玉米, Season 2, Area: 0.0
# Plot B3, Crop 黄豆, Season 1, Area: 0.0
# Plot B3, Crop 黄豆, Season 2, Area: 0.0
# Plot B3, Crop 绿豆, Season 1, Area: 0.0
# Plot B3, Crop 绿豆, Season 2, Area: 0.0
# Plot B3, Crop 谷子, Season 1, Area: 0.0
# Plot B3, Crop 谷子, Season 2, Area: 0.0
# Plot B3, Crop 黑豆, Season 1, Area: 0.0
# Plot B3, Crop 黑豆, Season 2, Area: 0.0
# Plot B3, Crop 红豆, Season 1, Area: 0.0
# Plot B3, Crop 红豆, Season 2, Area: 0.0
# Plot B3, Crop 爬豆, Season 1, Area: 0.0
# Plot B3, Crop 爬豆, Season 2, Area: 0.0
# Plot B3, Crop 高粱, Season 1, Area: 40.0
# Plot B3, Crop 高粱, Season 2, Area: 0.0
# Plot B3, Crop 黍子, Season 1, Area: 0.0
# Plot B3, Crop 黍子, Season 2, Area: 0.0
# Plot B3, Crop 莜麦, Season 1, Area: 0.0
# Plot B3, Crop 莜麦, Season 2, Area: 0.0
# Plot B3, Crop 大麦, Season 1, Area: 0.0
# Plot B3, Crop 大麦, Season 2, Area: 0.0
# Plot B3, Crop 荞麦, Season 1, Area: 0.0
# Plot B3, Crop 荞麦, Season 2, Area: 0.0
# Plot B3, Crop 南瓜, Season 1, Area: 0.0
# Plot B3, Crop 南瓜, Season 2, Area: 0.0
# Plot B3, Crop 红薯, Season 1, Area: 0.0
# Plot B3, Crop 红薯, Season 2, Area: 0.0
# Plot B3, Crop 土豆, Season 1, Area: 0.0
# Plot B3, Crop 土豆, Season 2, Area: 0.0
# Plot B3, Crop 白萝卜, Season 1, Area: 0.0
# Plot B3, Crop 白萝卜, Season 2, Area: 0.0
# Plot B3, Crop 小青菜, Season 1, Area: 0.0
# Plot B3, Crop 小青菜, Season 2, Area: 0.0
# Plot B3, Crop 大白菜, Season 1, Area: 0.0
# Plot B3, Crop 大白菜, Season 2, Area: 0.0
# Plot B3, Crop 西红柿, Season 1, Area: 0.0
# Plot B3, Crop 西红柿, Season 2, Area: 0.0
# Plot B3, Crop 茄子, Season 1, Area: 0.0
# Plot B3, Crop 茄子, Season 2, Area: 0.0
# Plot B3, Crop 豇豆, Season 1, Area: 0.0
# Plot B3, Crop 豇豆, Season 2, Area: 0.0
# Plot B3, Crop 刀豆, Season 1, Area: 0.0
# Plot B3, Crop 刀豆, Season 2, Area: 0.0
# Plot B3, Crop 红萝卜, Season 1, Area: 0.0
# Plot B3, Crop 红萝卜, Season 2, Area: 0.0
# Plot B3, Crop 水稻, Season 1, Area: 0.0
# Plot B3, Crop 水稻, Season 2, Area: 0.0
# Plot B3, Crop 榆黄菇, Season 1, Area: 0.0
# Plot B3, Crop 榆黄菇, Season 2, Area: 0.0
# Plot B3, Crop 青椒, Season 1, Area: 0.0
# Plot B3, Crop 青椒, Season 2, Area: 0.0
# Plot B3, Crop 菜花, Season 1, Area: 0.0
# Plot B3, Crop 菜花, Season 2, Area: 0.0
# Plot B3, Crop 包菜, Season 1, Area: 0.0
# Plot B3, Crop 包菜, Season 2, Area: 0.0
# Plot B3, Crop 香菇, Season 1, Area: 0.0
# Plot B3, Crop 香菇, Season 2, Area: 0.0
# Plot B3, Crop 油麦菜, Season 1, Area: 0.0
# Plot B3, Crop 油麦菜, Season 2, Area: 0.0
# Plot B3, Crop 芸豆, Season 1, Area: 0.0
# Plot B3, Crop 芸豆, Season 2, Area: 0.0
# Plot B3, Crop 白灵菇, Season 1, Area: 0.0
# Plot B3, Crop 白灵菇, Season 2, Area: 0.0
# Plot B3, Crop 羊肚菌, Season 1, Area: 0.0
# Plot B3, Crop 羊肚菌, Season 2, Area: 0.0
# Plot B3, Crop 黄瓜, Season 1, Area: 0.0
# Plot B3, Crop 黄瓜, Season 2, Area: 0.0
# Plot B3, Crop 生菜, Season 1, Area: 0.0
# Plot B3, Crop 生菜, Season 2, Area: 0.0
# Plot B3, Crop 辣椒, Season 1, Area: 0.0
# Plot B3, Crop 辣椒, Season 2, Area: 0.0
# Plot B3, Crop 空心菜, Season 1, Area: 0.0
# Plot B3, Crop 空心菜, Season 2, Area: 0.0
# Plot B3, Crop 黄心菜, Season 1, Area: 0.0
# Plot B3, Crop 黄心菜, Season 2, Area: 0.0
# Plot B3, Crop 生菜 , Season 1, Area: 0.0
# Plot B3, Crop 生菜 , Season 2, Area: 0.0
# Plot B3, Crop 芹菜, Season 1, Area: 0.0
# Plot B3, Crop 芹菜, Season 2, Area: 0.0
# Plot B3, Crop 菠菜 , Season 1, Area: 0.0
# Plot B3, Crop 菠菜 , Season 2, Area: 0.0
# Plot B4, Crop 小麦, Season 1, Area: 0.0
# Plot B4, Crop 小麦, Season 2, Area: 0.0
# Plot B4, Crop 玉米, Season 1, Area: 0.0
# Plot B4, Crop 玉米, Season 2, Area: 0.0
# Plot B4, Crop 黄豆, Season 1, Area: 0.0
# Plot B4, Crop 黄豆, Season 2, Area: 0.0
# Plot B4, Crop 绿豆, Season 1, Area: 0.0
# Plot B4, Crop 绿豆, Season 2, Area: 0.0
# Plot B4, Crop 谷子, Season 1, Area: 0.0
# Plot B4, Crop 谷子, Season 2, Area: 0.0
# Plot B4, Crop 黑豆, Season 1, Area: 0.0
# Plot B4, Crop 黑豆, Season 2, Area: 0.0
# Plot B4, Crop 红豆, Season 1, Area: 0.0
# Plot B4, Crop 红豆, Season 2, Area: 0.0
# Plot B4, Crop 爬豆, Season 1, Area: 0.0
# Plot B4, Crop 爬豆, Season 2, Area: 0.0
# Plot B4, Crop 高粱, Season 1, Area: 28.0
# Plot B4, Crop 高粱, Season 2, Area: 0.0
# Plot B4, Crop 黍子, Season 1, Area: 0.0
# Plot B4, Crop 黍子, Season 2, Area: 0.0
# Plot B4, Crop 莜麦, Season 1, Area: 0.0
# Plot B4, Crop 莜麦, Season 2, Area: 0.0
# Plot B4, Crop 大麦, Season 1, Area: 0.0
# Plot B4, Crop 大麦, Season 2, Area: 0.0
# Plot B4, Crop 荞麦, Season 1, Area: 0.0
# Plot B4, Crop 荞麦, Season 2, Area: 0.0
# Plot B4, Crop 南瓜, Season 1, Area: 0.0
# Plot B4, Crop 南瓜, Season 2, Area: 0.0
# Plot B4, Crop 红薯, Season 1, Area: 0.0
# Plot B4, Crop 红薯, Season 2, Area: 0.0
# Plot B4, Crop 土豆, Season 1, Area: 0.0
# Plot B4, Crop 土豆, Season 2, Area: 0.0
# Plot B4, Crop 白萝卜, Season 1, Area: 0.0
# Plot B4, Crop 白萝卜, Season 2, Area: 0.0
# Plot B4, Crop 小青菜, Season 1, Area: 0.0
# Plot B4, Crop 小青菜, Season 2, Area: 0.0
# Plot B4, Crop 大白菜, Season 1, Area: 0.0
# Plot B4, Crop 大白菜, Season 2, Area: 0.0
# Plot B4, Crop 西红柿, Season 1, Area: 0.0
# Plot B4, Crop 西红柿, Season 2, Area: 0.0
# Plot B4, Crop 茄子, Season 1, Area: 0.0
# Plot B4, Crop 茄子, Season 2, Area: 0.0
# Plot B4, Crop 豇豆, Season 1, Area: 0.0
# Plot B4, Crop 豇豆, Season 2, Area: 0.0
# Plot B4, Crop 刀豆, Season 1, Area: 0.0
# Plot B4, Crop 刀豆, Season 2, Area: 0.0
# Plot B4, Crop 红萝卜, Season 1, Area: 0.0
# Plot B4, Crop 红萝卜, Season 2, Area: 0.0
# Plot B4, Crop 水稻, Season 1, Area: 0.0
# Plot B4, Crop 水稻, Season 2, Area: 0.0
# Plot B4, Crop 榆黄菇, Season 1, Area: 0.0
# Plot B4, Crop 榆黄菇, Season 2, Area: 0.0
# Plot B4, Crop 青椒, Season 1, Area: 0.0
# Plot B4, Crop 青椒, Season 2, Area: 0.0
# Plot B4, Crop 菜花, Season 1, Area: 0.0
# Plot B4, Crop 菜花, Season 2, Area: 0.0
# Plot B4, Crop 包菜, Season 1, Area: 0.0
# Plot B4, Crop 包菜, Season 2, Area: 0.0
# Plot B4, Crop 香菇, Season 1, Area: 0.0
# Plot B4, Crop 香菇, Season 2, Area: 0.0
# Plot B4, Crop 油麦菜, Season 1, Area: 0.0
# Plot B4, Crop 油麦菜, Season 2, Area: 0.0
# Plot B4, Crop 芸豆, Season 1, Area: 0.0
# Plot B4, Crop 芸豆, Season 2, Area: 0.0
# Plot B4, Crop 白灵菇, Season 1, Area: 0.0
# Plot B4, Crop 白灵菇, Season 2, Area: 0.0
# Plot B4, Crop 羊肚菌, Season 1, Area: 0.0
# Plot B4, Crop 羊肚菌, Season 2, Area: 0.0
# Plot B4, Crop 黄瓜, Season 1, Area: 0.0
# Plot B4, Crop 黄瓜, Season 2, Area: 0.0
# Plot B4, Crop 生菜, Season 1, Area: 0.0
# Plot B4, Crop 生菜, Season 2, Area: 0.0
# Plot B4, Crop 辣椒, Season 1, Area: 0.0
# Plot B4, Crop 辣椒, Season 2, Area: 0.0
# Plot B4, Crop 空心菜, Season 1, Area: 0.0
# Plot B4, Crop 空心菜, Season 2, Area: 0.0
# Plot B4, Crop 黄心菜, Season 1, Area: 0.0
# Plot B4, Crop 黄心菜, Season 2, Area: 0.0
# Plot B4, Crop 生菜 , Season 1, Area: 0.0
# Plot B4, Crop 生菜 , Season 2, Area: 0.0
# Plot B4, Crop 芹菜, Season 1, Area: 0.0
# Plot B4, Crop 芹菜, Season 2, Area: 0.0
# Plot B4, Crop 菠菜 , Season 1, Area: 0.0
# Plot B4, Crop 菠菜 , Season 2, Area: 0.0
# Plot B5, Crop 小麦, Season 1, Area: 0.0
# Plot B5, Crop 小麦, Season 2, Area: 0.0
# Plot B5, Crop 玉米, Season 1, Area: 0.0
# Plot B5, Crop 玉米, Season 2, Area: 0.0
# Plot B5, Crop 黄豆, Season 1, Area: 0.0
# Plot B5, Crop 黄豆, Season 2, Area: 0.0
# Plot B5, Crop 绿豆, Season 1, Area: 0.0
# Plot B5, Crop 绿豆, Season 2, Area: 0.0
# Plot B5, Crop 谷子, Season 1, Area: 0.0
# Plot B5, Crop 谷子, Season 2, Area: 0.0
# Plot B5, Crop 黑豆, Season 1, Area: 0.0
# Plot B5, Crop 黑豆, Season 2, Area: 0.0
# Plot B5, Crop 红豆, Season 1, Area: 0.0
# Plot B5, Crop 红豆, Season 2, Area: 0.0
# Plot B5, Crop 爬豆, Season 1, Area: 0.0
# Plot B5, Crop 爬豆, Season 2, Area: 0.0
# Plot B5, Crop 高粱, Season 1, Area: 25.0
# Plot B5, Crop 高粱, Season 2, Area: 0.0
# Plot B5, Crop 黍子, Season 1, Area: 0.0
# Plot B5, Crop 黍子, Season 2, Area: 0.0
# Plot B5, Crop 莜麦, Season 1, Area: 0.0
# Plot B5, Crop 莜麦, Season 2, Area: 0.0
# Plot B5, Crop 大麦, Season 1, Area: 0.0
# Plot B5, Crop 大麦, Season 2, Area: 0.0
# Plot B5, Crop 荞麦, Season 1, Area: 0.0
# Plot B5, Crop 荞麦, Season 2, Area: 0.0
# Plot B5, Crop 南瓜, Season 1, Area: 0.0
# Plot B5, Crop 南瓜, Season 2, Area: 0.0
# Plot B5, Crop 红薯, Season 1, Area: 0.0
# Plot B5, Crop 红薯, Season 2, Area: 0.0
# Plot B5, Crop 土豆, Season 1, Area: 0.0
# Plot B5, Crop 土豆, Season 2, Area: 0.0
# Plot B5, Crop 白萝卜, Season 1, Area: 0.0
# Plot B5, Crop 白萝卜, Season 2, Area: 0.0
# Plot B5, Crop 小青菜, Season 1, Area: 0.0
# Plot B5, Crop 小青菜, Season 2, Area: 0.0
# Plot B5, Crop 大白菜, Season 1, Area: 0.0
# Plot B5, Crop 大白菜, Season 2, Area: 0.0
# Plot B5, Crop 西红柿, Season 1, Area: 0.0
# Plot B5, Crop 西红柿, Season 2, Area: 0.0
# Plot B5, Crop 茄子, Season 1, Area: 0.0
# Plot B5, Crop 茄子, Season 2, Area: 0.0
# Plot B5, Crop 豇豆, Season 1, Area: 0.0
# Plot B5, Crop 豇豆, Season 2, Area: 0.0
# Plot B5, Crop 刀豆, Season 1, Area: 0.0
# Plot B5, Crop 刀豆, Season 2, Area: 0.0
# Plot B5, Crop 红萝卜, Season 1, Area: 0.0
# Plot B5, Crop 红萝卜, Season 2, Area: 0.0
# Plot B5, Crop 水稻, Season 1, Area: 0.0
# Plot B5, Crop 水稻, Season 2, Area: 0.0
# Plot B5, Crop 榆黄菇, Season 1, Area: 0.0
# Plot B5, Crop 榆黄菇, Season 2, Area: 0.0
# Plot B5, Crop 青椒, Season 1, Area: 0.0
# Plot B5, Crop 青椒, Season 2, Area: 0.0
# Plot B5, Crop 菜花, Season 1, Area: 0.0
# Plot B5, Crop 菜花, Season 2, Area: 0.0
# Plot B5, Crop 包菜, Season 1, Area: 0.0
# Plot B5, Crop 包菜, Season 2, Area: 0.0
# Plot B5, Crop 香菇, Season 1, Area: 0.0
# Plot B5, Crop 香菇, Season 2, Area: 0.0
# Plot B5, Crop 油麦菜, Season 1, Area: 0.0
# Plot B5, Crop 油麦菜, Season 2, Area: 0.0
# Plot B5, Crop 芸豆, Season 1, Area: 0.0
# Plot B5, Crop 芸豆, Season 2, Area: 0.0
# Plot B5, Crop 白灵菇, Season 1, Area: 0.0
# Plot B5, Crop 白灵菇, Season 2, Area: 0.0
# Plot B5, Crop 羊肚菌, Season 1, Area: 0.0
# Plot B5, Crop 羊肚菌, Season 2, Area: 0.0
# Plot B5, Crop 黄瓜, Season 1, Area: 0.0
# Plot B5, Crop 黄瓜, Season 2, Area: 0.0
# Plot B5, Crop 生菜, Season 1, Area: 0.0
# Plot B5, Crop 生菜, Season 2, Area: 0.0
# Plot B5, Crop 辣椒, Season 1, Area: 0.0
# Plot B5, Crop 辣椒, Season 2, Area: 0.0
# Plot B5, Crop 空心菜, Season 1, Area: 0.0
# Plot B5, Crop 空心菜, Season 2, Area: 0.0
# Plot B5, Crop 黄心菜, Season 1, Area: 0.0
# Plot B5, Crop 黄心菜, Season 2, Area: 0.0
# Plot B5, Crop 生菜 , Season 1, Area: 0.0
# Plot B5, Crop 生菜 , Season 2, Area: 0.0
# Plot B5, Crop 芹菜, Season 1, Area: 0.0
# Plot B5, Crop 芹菜, Season 2, Area: 0.0
# Plot B5, Crop 菠菜 , Season 1, Area: 0.0
# Plot B5, Crop 菠菜 , Season 2, Area: 0.0
# Plot B6, Crop 小麦, Season 1, Area: 0.0
# Plot B6, Crop 小麦, Season 2, Area: 0.0
# Plot B6, Crop 玉米, Season 1, Area: 0.0
# Plot B6, Crop 玉米, Season 2, Area: 0.0
# Plot B6, Crop 黄豆, Season 1, Area: 0.0
# Plot B6, Crop 黄豆, Season 2, Area: 0.0
# Plot B6, Crop 绿豆, Season 1, Area: 0.0
# Plot B6, Crop 绿豆, Season 2, Area: 0.0
# Plot B6, Crop 谷子, Season 1, Area: 0.0
# Plot B6, Crop 谷子, Season 2, Area: 0.0
# Plot B6, Crop 黑豆, Season 1, Area: 0.0
# Plot B6, Crop 黑豆, Season 2, Area: 0.0
# Plot B6, Crop 红豆, Season 1, Area: 0.0
# Plot B6, Crop 红豆, Season 2, Area: 0.0
# Plot B6, Crop 爬豆, Season 1, Area: 0.0
# Plot B6, Crop 爬豆, Season 2, Area: 0.0
# Plot B6, Crop 高粱, Season 1, Area: 86.0
# Plot B6, Crop 高粱, Season 2, Area: 0.0
# Plot B6, Crop 黍子, Season 1, Area: 0.0
# Plot B6, Crop 黍子, Season 2, Area: 0.0
# Plot B6, Crop 莜麦, Season 1, Area: 0.0
# Plot B6, Crop 莜麦, Season 2, Area: 0.0
# Plot B6, Crop 大麦, Season 1, Area: 0.0
# Plot B6, Crop 大麦, Season 2, Area: 0.0
# Plot B6, Crop 荞麦, Season 1, Area: 0.0
# Plot B6, Crop 荞麦, Season 2, Area: 0.0
# Plot B6, Crop 南瓜, Season 1, Area: 0.0
# Plot B6, Crop 南瓜, Season 2, Area: 0.0
# Plot B6, Crop 红薯, Season 1, Area: 0.0
# Plot B6, Crop 红薯, Season 2, Area: 0.0
# Plot B6, Crop 土豆, Season 1, Area: 0.0
# Plot B6, Crop 土豆, Season 2, Area: 0.0
# Plot B6, Crop 白萝卜, Season 1, Area: 0.0
# Plot B6, Crop 白萝卜, Season 2, Area: 0.0
# Plot B6, Crop 小青菜, Season 1, Area: 0.0
# Plot B6, Crop 小青菜, Season 2, Area: 0.0
# Plot B6, Crop 大白菜, Season 1, Area: 0.0
# Plot B6, Crop 大白菜, Season 2, Area: 0.0
# Plot B6, Crop 西红柿, Season 1, Area: 0.0
# Plot B6, Crop 西红柿, Season 2, Area: 0.0
# Plot B6, Crop 茄子, Season 1, Area: 0.0
# Plot B6, Crop 茄子, Season 2, Area: 0.0
# Plot B6, Crop 豇豆, Season 1, Area: 0.0
# Plot B6, Crop 豇豆, Season 2, Area: 0.0
# Plot B6, Crop 刀豆, Season 1, Area: 0.0
# Plot B6, Crop 刀豆, Season 2, Area: 0.0
# Plot B6, Crop 红萝卜, Season 1, Area: 0.0
# Plot B6, Crop 红萝卜, Season 2, Area: 0.0
# Plot B6, Crop 水稻, Season 1, Area: 0.0
# Plot B6, Crop 水稻, Season 2, Area: 0.0
# Plot B6, Crop 榆黄菇, Season 1, Area: 0.0
# Plot B6, Crop 榆黄菇, Season 2, Area: 0.0
# Plot B6, Crop 青椒, Season 1, Area: 0.0
# Plot B6, Crop 青椒, Season 2, Area: 0.0
# Plot B6, Crop 菜花, Season 1, Area: 0.0
# Plot B6, Crop 菜花, Season 2, Area: 0.0
# Plot B6, Crop 包菜, Season 1, Area: 0.0
# Plot B6, Crop 包菜, Season 2, Area: 0.0
# Plot B6, Crop 香菇, Season 1, Area: 0.0
# Plot B6, Crop 香菇, Season 2, Area: 0.0
# Plot B6, Crop 油麦菜, Season 1, Area: 0.0
# Plot B6, Crop 油麦菜, Season 2, Area: 0.0
# Plot B6, Crop 芸豆, Season 1, Area: 0.0
# Plot B6, Crop 芸豆, Season 2, Area: 0.0
# Plot B6, Crop 白灵菇, Season 1, Area: 0.0
# Plot B6, Crop 白灵菇, Season 2, Area: 0.0
# Plot B6, Crop 羊肚菌, Season 1, Area: 0.0
# Plot B6, Crop 羊肚菌, Season 2, Area: 0.0
# Plot B6, Crop 黄瓜, Season 1, Area: 0.0
# Plot B6, Crop 黄瓜, Season 2, Area: 0.0
# Plot B6, Crop 生菜, Season 1, Area: 0.0
# Plot B6, Crop 生菜, Season 2, Area: 0.0
# Plot B6, Crop 辣椒, Season 1, Area: 0.0
# Plot B6, Crop 辣椒, Season 2, Area: 0.0
# Plot B6, Crop 空心菜, Season 1, Area: 0.0
# Plot B6, Crop 空心菜, Season 2, Area: 0.0
# Plot B6, Crop 黄心菜, Season 1, Area: 0.0
# Plot B6, Crop 黄心菜, Season 2, Area: 0.0
# Plot B6, Crop 生菜 , Season 1, Area: 0.0
# Plot B6, Crop 生菜 , Season 2, Area: 0.0
# Plot B6, Crop 芹菜, Season 1, Area: 0.0
# Plot B6, Crop 芹菜, Season 2, Area: 0.0
# Plot B6, Crop 菠菜 , Season 1, Area: 0.0
# Plot B6, Crop 菠菜 , Season 2, Area: 0.0
# Plot B7, Crop 小麦, Season 1, Area: 0.0
# Plot B7, Crop 小麦, Season 2, Area: 0.0
# Plot B7, Crop 玉米, Season 1, Area: 0.0
# Plot B7, Crop 玉米, Season 2, Area: 0.0
# Plot B7, Crop 黄豆, Season 1, Area: 0.0
# Plot B7, Crop 黄豆, Season 2, Area: 0.0
# Plot B7, Crop 绿豆, Season 1, Area: 0.0
# Plot B7, Crop 绿豆, Season 2, Area: 0.0
# Plot B7, Crop 谷子, Season 1, Area: 0.0
# Plot B7, Crop 谷子, Season 2, Area: 0.0
# Plot B7, Crop 黑豆, Season 1, Area: 0.0
# Plot B7, Crop 黑豆, Season 2, Area: 0.0
# Plot B7, Crop 红豆, Season 1, Area: 0.0
# Plot B7, Crop 红豆, Season 2, Area: 0.0
# Plot B7, Crop 爬豆, Season 1, Area: 0.0
# Plot B7, Crop 爬豆, Season 2, Area: 0.0
# Plot B7, Crop 高粱, Season 1, Area: 55.0
# Plot B7, Crop 高粱, Season 2, Area: 0.0
# Plot B7, Crop 黍子, Season 1, Area: 0.0
# Plot B7, Crop 黍子, Season 2, Area: 0.0
# Plot B7, Crop 莜麦, Season 1, Area: 0.0
# Plot B7, Crop 莜麦, Season 2, Area: 0.0
# Plot B7, Crop 大麦, Season 1, Area: 0.0
# Plot B7, Crop 大麦, Season 2, Area: 0.0
# Plot B7, Crop 荞麦, Season 1, Area: 0.0
# Plot B7, Crop 荞麦, Season 2, Area: 0.0
# Plot B7, Crop 南瓜, Season 1, Area: 0.0
# Plot B7, Crop 南瓜, Season 2, Area: 0.0
# Plot B7, Crop 红薯, Season 1, Area: 0.0
# Plot B7, Crop 红薯, Season 2, Area: 0.0
# Plot B7, Crop 土豆, Season 1, Area: 0.0
# Plot B7, Crop 土豆, Season 2, Area: 0.0
# Plot B7, Crop 白萝卜, Season 1, Area: 0.0
# Plot B7, Crop 白萝卜, Season 2, Area: 0.0
# Plot B7, Crop 小青菜, Season 1, Area: 0.0
# Plot B7, Crop 小青菜, Season 2, Area: 0.0
# Plot B7, Crop 大白菜, Season 1, Area: 0.0
# Plot B7, Crop 大白菜, Season 2, Area: 0.0
# Plot B7, Crop 西红柿, Season 1, Area: 0.0
# Plot B7, Crop 西红柿, Season 2, Area: 0.0
# Plot B7, Crop 茄子, Season 1, Area: 0.0
# Plot B7, Crop 茄子, Season 2, Area: 0.0
# Plot B7, Crop 豇豆, Season 1, Area: 0.0
# Plot B7, Crop 豇豆, Season 2, Area: 0.0
# Plot B7, Crop 刀豆, Season 1, Area: 0.0
# Plot B7, Crop 刀豆, Season 2, Area: 0.0
# Plot B7, Crop 红萝卜, Season 1, Area: 0.0
# Plot B7, Crop 红萝卜, Season 2, Area: 0.0
# Plot B7, Crop 水稻, Season 1, Area: 0.0
# Plot B7, Crop 水稻, Season 2, Area: 0.0
# Plot B7, Crop 榆黄菇, Season 1, Area: 0.0
# Plot B7, Crop 榆黄菇, Season 2, Area: 0.0
# Plot B7, Crop 青椒, Season 1, Area: 0.0
# Plot B7, Crop 青椒, Season 2, Area: 0.0
# Plot B7, Crop 菜花, Season 1, Area: 0.0
# Plot B7, Crop 菜花, Season 2, Area: 0.0
# Plot B7, Crop 包菜, Season 1, Area: 0.0
# Plot B7, Crop 包菜, Season 2, Area: 0.0
# Plot B7, Crop 香菇, Season 1, Area: 0.0
# Plot B7, Crop 香菇, Season 2, Area: 0.0
# Plot B7, Crop 油麦菜, Season 1, Area: 0.0
# Plot B7, Crop 油麦菜, Season 2, Area: 0.0
# Plot B7, Crop 芸豆, Season 1, Area: 0.0
# Plot B7, Crop 芸豆, Season 2, Area: 0.0
# Plot B7, Crop 白灵菇, Season 1, Area: 0.0
# Plot B7, Crop 白灵菇, Season 2, Area: 0.0
# Plot B7, Crop 羊肚菌, Season 1, Area: 0.0
# Plot B7, Crop 羊肚菌, Season 2, Area: 0.0
# Plot B7, Crop 黄瓜, Season 1, Area: 0.0
# Plot B7, Crop 黄瓜, Season 2, Area: 0.0
# Plot B7, Crop 生菜, Season 1, Area: 0.0
# Plot B7, Crop 生菜, Season 2, Area: 0.0
# Plot B7, Crop 辣椒, Season 1, Area: 0.0
# Plot B7, Crop 辣椒, Season 2, Area: 0.0
# Plot B7, Crop 空心菜, Season 1, Area: 0.0
# Plot B7, Crop 空心菜, Season 2, Area: 0.0
# Plot B7, Crop 黄心菜, Season 1, Area: 0.0
# Plot B7, Crop 黄心菜, Season 2, Area: 0.0
# Plot B7, Crop 生菜 , Season 1, Area: 0.0
# Plot B7, Crop 生菜 , Season 2, Area: 0.0
# Plot B7, Crop 芹菜, Season 1, Area: 0.0
# Plot B7, Crop 芹菜, Season 2, Area: 0.0
# Plot B7, Crop 菠菜 , Season 1, Area: 0.0
# Plot B7, Crop 菠菜 , Season 2, Area: 0.0
# Plot B8, Crop 小麦, Season 1, Area: 0.0
# Plot B8, Crop 小麦, Season 2, Area: 0.0
# Plot B8, Crop 玉米, Season 1, Area: 0.0
# Plot B8, Crop 玉米, Season 2, Area: 0.0
# Plot B8, Crop 黄豆, Season 1, Area: 0.0
# Plot B8, Crop 黄豆, Season 2, Area: 0.0
# Plot B8, Crop 绿豆, Season 1, Area: 0.0
# Plot B8, Crop 绿豆, Season 2, Area: 0.0
# Plot B8, Crop 谷子, Season 1, Area: 0.0
# Plot B8, Crop 谷子, Season 2, Area: 0.0
# Plot B8, Crop 黑豆, Season 1, Area: 0.0
# Plot B8, Crop 黑豆, Season 2, Area: 0.0
# Plot B8, Crop 红豆, Season 1, Area: 0.0
# Plot B8, Crop 红豆, Season 2, Area: 0.0
# Plot B8, Crop 爬豆, Season 1, Area: 0.0
# Plot B8, Crop 爬豆, Season 2, Area: 0.0
# Plot B8, Crop 高粱, Season 1, Area: 44.0
# Plot B8, Crop 高粱, Season 2, Area: 0.0
# Plot B8, Crop 黍子, Season 1, Area: 0.0
# Plot B8, Crop 黍子, Season 2, Area: 0.0
# Plot B8, Crop 莜麦, Season 1, Area: 0.0
# Plot B8, Crop 莜麦, Season 2, Area: 0.0
# Plot B8, Crop 大麦, Season 1, Area: 0.0
# Plot B8, Crop 大麦, Season 2, Area: 0.0
# Plot B8, Crop 荞麦, Season 1, Area: 0.0
# Plot B8, Crop 荞麦, Season 2, Area: 0.0
# Plot B8, Crop 南瓜, Season 1, Area: 0.0
# Plot B8, Crop 南瓜, Season 2, Area: 0.0
# Plot B8, Crop 红薯, Season 1, Area: 0.0
# Plot B8, Crop 红薯, Season 2, Area: 0.0
# Plot B8, Crop 土豆, Season 1, Area: 0.0
# Plot B8, Crop 土豆, Season 2, Area: 0.0
# Plot B8, Crop 白萝卜, Season 1, Area: 0.0
# Plot B8, Crop 白萝卜, Season 2, Area: 0.0
# Plot B8, Crop 小青菜, Season 1, Area: 0.0
# Plot B8, Crop 小青菜, Season 2, Area: 0.0
# Plot B8, Crop 大白菜, Season 1, Area: 0.0
# Plot B8, Crop 大白菜, Season 2, Area: 0.0
# Plot B8, Crop 西红柿, Season 1, Area: 0.0
# Plot B8, Crop 西红柿, Season 2, Area: 0.0
# Plot B8, Crop 茄子, Season 1, Area: 0.0
# Plot B8, Crop 茄子, Season 2, Area: 0.0
# Plot B8, Crop 豇豆, Season 1, Area: 0.0
# Plot B8, Crop 豇豆, Season 2, Area: 0.0
# Plot B8, Crop 刀豆, Season 1, Area: 0.0
# Plot B8, Crop 刀豆, Season 2, Area: 0.0
# Plot B8, Crop 红萝卜, Season 1, Area: 0.0
# Plot B8, Crop 红萝卜, Season 2, Area: 0.0
# Plot B8, Crop 水稻, Season 1, Area: 0.0
# Plot B8, Crop 水稻, Season 2, Area: 0.0
# Plot B8, Crop 榆黄菇, Season 1, Area: 0.0
# Plot B8, Crop 榆黄菇, Season 2, Area: 0.0
# Plot B8, Crop 青椒, Season 1, Area: 0.0
# Plot B8, Crop 青椒, Season 2, Area: 0.0
# Plot B8, Crop 菜花, Season 1, Area: 0.0
# Plot B8, Crop 菜花, Season 2, Area: 0.0
# Plot B8, Crop 包菜, Season 1, Area: 0.0
# Plot B8, Crop 包菜, Season 2, Area: 0.0
# Plot B8, Crop 香菇, Season 1, Area: 0.0
# Plot B8, Crop 香菇, Season 2, Area: 0.0
# Plot B8, Crop 油麦菜, Season 1, Area: 0.0
# Plot B8, Crop 油麦菜, Season 2, Area: 0.0
# Plot B8, Crop 芸豆, Season 1, Area: 0.0
# Plot B8, Crop 芸豆, Season 2, Area: 0.0
# Plot B8, Crop 白灵菇, Season 1, Area: 0.0
# Plot B8, Crop 白灵菇, Season 2, Area: 0.0
# Plot B8, Crop 羊肚菌, Season 1, Area: 0.0
# Plot B8, Crop 羊肚菌, Season 2, Area: 0.0
# Plot B8, Crop 黄瓜, Season 1, Area: 0.0
# Plot B8, Crop 黄瓜, Season 2, Area: 0.0
# Plot B8, Crop 生菜, Season 1, Area: 0.0
# Plot B8, Crop 生菜, Season 2, Area: 0.0
# Plot B8, Crop 辣椒, Season 1, Area: 0.0
# Plot B8, Crop 辣椒, Season 2, Area: 0.0
# Plot B8, Crop 空心菜, Season 1, Area: 0.0
# Plot B8, Crop 空心菜, Season 2, Area: 0.0
# Plot B8, Crop 黄心菜, Season 1, Area: 0.0
# Plot B8, Crop 黄心菜, Season 2, Area: 0.0
# Plot B8, Crop 生菜 , Season 1, Area: 0.0
# Plot B8, Crop 生菜 , Season 2, Area: 0.0
# Plot B8, Crop 芹菜, Season 1, Area: 0.0
# Plot B8, Crop 芹菜, Season 2, Area: 0.0
# Plot B8, Crop 菠菜 , Season 1, Area: 0.0
# Plot B8, Crop 菠菜 , Season 2, Area: 0.0
# Plot B9, Crop 小麦, Season 1, Area: 0.0
# Plot B9, Crop 小麦, Season 2, Area: 0.0
# Plot B9, Crop 玉米, Season 1, Area: 0.0
# Plot B9, Crop 玉米, Season 2, Area: 0.0
# Plot B9, Crop 黄豆, Season 1, Area: 0.0
# Plot B9, Crop 黄豆, Season 2, Area: 0.0
# Plot B9, Crop 绿豆, Season 1, Area: 0.0
# Plot B9, Crop 绿豆, Season 2, Area: 0.0
# Plot B9, Crop 谷子, Season 1, Area: 0.0
# Plot B9, Crop 谷子, Season 2, Area: 0.0
# Plot B9, Crop 黑豆, Season 1, Area: 0.0
# Plot B9, Crop 黑豆, Season 2, Area: 0.0
# Plot B9, Crop 红豆, Season 1, Area: 0.0
# Plot B9, Crop 红豆, Season 2, Area: 0.0
# Plot B9, Crop 爬豆, Season 1, Area: 0.0
# Plot B9, Crop 爬豆, Season 2, Area: 0.0
# Plot B9, Crop 高粱, Season 1, Area: 50.0
# Plot B9, Crop 高粱, Season 2, Area: 0.0
# Plot B9, Crop 黍子, Season 1, Area: 0.0
# Plot B9, Crop 黍子, Season 2, Area: 0.0
# Plot B9, Crop 莜麦, Season 1, Area: 0.0
# Plot B9, Crop 莜麦, Season 2, Area: 0.0
# Plot B9, Crop 大麦, Season 1, Area: 0.0
# Plot B9, Crop 大麦, Season 2, Area: 0.0
# Plot B9, Crop 荞麦, Season 1, Area: 0.0
# Plot B9, Crop 荞麦, Season 2, Area: 0.0
# Plot B9, Crop 南瓜, Season 1, Area: 0.0
# Plot B9, Crop 南瓜, Season 2, Area: 0.0
# Plot B9, Crop 红薯, Season 1, Area: 0.0
# Plot B9, Crop 红薯, Season 2, Area: 0.0
# Plot B9, Crop 土豆, Season 1, Area: 0.0
# Plot B9, Crop 土豆, Season 2, Area: 0.0
# Plot B9, Crop 白萝卜, Season 1, Area: 0.0
# Plot B9, Crop 白萝卜, Season 2, Area: 0.0
# Plot B9, Crop 小青菜, Season 1, Area: 0.0
# Plot B9, Crop 小青菜, Season 2, Area: 0.0
# Plot B9, Crop 大白菜, Season 1, Area: 0.0
# Plot B9, Crop 大白菜, Season 2, Area: 0.0
# Plot B9, Crop 西红柿, Season 1, Area: 0.0
# Plot B9, Crop 西红柿, Season 2, Area: 0.0
# Plot B9, Crop 茄子, Season 1, Area: 0.0
# Plot B9, Crop 茄子, Season 2, Area: 0.0
# Plot B9, Crop 豇豆, Season 1, Area: 0.0
# Plot B9, Crop 豇豆, Season 2, Area: 0.0
# Plot B9, Crop 刀豆, Season 1, Area: 0.0
# Plot B9, Crop 刀豆, Season 2, Area: 0.0
# Plot B9, Crop 红萝卜, Season 1, Area: 0.0
# Plot B9, Crop 红萝卜, Season 2, Area: 0.0
# Plot B9, Crop 水稻, Season 1, Area: 0.0
# Plot B9, Crop 水稻, Season 2, Area: 0.0
# Plot B9, Crop 榆黄菇, Season 1, Area: 0.0
# Plot B9, Crop 榆黄菇, Season 2, Area: 0.0
# Plot B9, Crop 青椒, Season 1, Area: 0.0
# Plot B9, Crop 青椒, Season 2, Area: 0.0
# Plot B9, Crop 菜花, Season 1, Area: 0.0
# Plot B9, Crop 菜花, Season 2, Area: 0.0
# Plot B9, Crop 包菜, Season 1, Area: 0.0
# Plot B9, Crop 包菜, Season 2, Area: 0.0
# Plot B9, Crop 香菇, Season 1, Area: 0.0
# ...
# Plot E16, Crop 高粱, Season 1, Area: 0.6
# Plot E16, Crop 高粱, Season 2, Area: 0.0
# Plot E16, Crop 黍子, Season 1, Area: 0.0
# Plot E16, Crop 黍子, Season 2, Area: 0.0
# Plot E16, Crop 莜麦, Season 1, Area: 0.0
# Plot E16, Crop 莜麦, Season 2, Area: 0.0
# Plot E16, Crop 大麦, Season 1, Area: 0.0
# Plot E16, Crop 大麦, Season 2, Area: 0.0
# Plot E16, Crop 荞麦, Season 1, Area: 0.0
# Plot E16, Crop 荞麦, Season 2, Area: 0.0
# Plot E16, Crop 南瓜, Season 1, Area: 0.0
# Plot E16, Crop 南瓜, Season 2, Area: 0.0
# Plot E16, Crop 红薯, Season 1, Area: 0.0
# Plot E16, Crop 红薯, Season 2, Area: 0.0
# Plot E16, Crop 土豆, Season 1, Area: -0.6
# Plot E16, Crop 土豆, Season 2, Area: 0.6
# Plot E16, Crop 白萝卜, Season 1, Area: 0.0
# Plot E16, Crop 白萝卜, Season 2, Area: 0.0
# Plot E16, Crop 小青菜, Season 1, Area: 0.0
# Plot E16, Crop 小青菜, Season 2, Area: 0.0
# Plot E16, Crop 大白菜, Season 1, Area: 0.0
# Plot E16, Crop 大白菜, Season 2, Area: 0.0
# Plot E16, Crop 西红柿, Season 1, Area: 0.0
# Plot E16, Crop 西红柿, Season 2, Area: 0.0
# Plot E16, Crop 茄子, Season 1, Area: 0.0
# Plot E16, Crop 茄子, Season 2, Area: 0.0
# Plot E16, Crop 豇豆, Season 1, Area: 0.0
# Plot E16, Crop 豇豆, Season 2, Area: 0.0
# Plot E16, Crop 刀豆, Season 1, Area: 0.0
# Plot E16, Crop 刀豆, Season 2, Area: 0.0
# Plot E16, Crop 红萝卜, Season 1, Area: 0.0
# Plot E16, Crop 红萝卜, Season 2, Area: 0.0
# Plot E16, Crop 水稻, Season 1, Area: 0.0
# Plot E16, Crop 水稻, Season 2, Area: 0.0
# Plot E16, Crop 榆黄菇, Season 1, Area: 0.0
# Plot E16, Crop 榆黄菇, Season 2, Area: 0.0
# Plot E16, Crop 青椒, Season 1, Area: 0.0
# Plot E16, Crop 青椒, Season 2, Area: 0.0
# Plot E16, Crop 菜花, Season 1, Area: 0.0
# Plot E16, Crop 菜花, Season 2, Area: 0.0
# Plot E16, Crop 包菜, Season 1, Area: 0.0
# Plot E16, Crop 包菜, Season 2, Area: 0.0
# Plot E16, Crop 香菇, Season 1, Area: 0.0
# Plot E16, Crop 香菇, Season 2, Area: 0.0
# Plot E16, Crop 油麦菜, Season 1, Area: 0.0
# Plot E16, Crop 油麦菜, Season 2, Area: 0.0
# Plot E16, Crop 芸豆, Season 1, Area: 0.0
# Plot E16, Crop 芸豆, Season 2, Area: 0.0
# Plot E16, Crop 白灵菇, Season 1, Area: 0.0
# Plot E16, Crop 白灵菇, Season 2, Area: 0.0
# Plot E16, Crop 羊肚菌, Season 1, Area: 0.0
# Plot E16, Crop 羊肚菌, Season 2, Area: 0.0
# Plot E16, Crop 黄瓜, Season 1, Area: 0.0
# Plot E16, Crop 黄瓜, Season 2, Area: 0.0
# Plot E16, Crop 生菜, Season 1, Area: 0.0
# Plot E16, Crop 生菜, Season 2, Area: 0.0
# Plot E16, Crop 辣椒, Season 1, Area: 0.0
# Plot E16, Crop 辣椒, Season 2, Area: 0.0
# Plot E16, Crop 空心菜, Season 1, Area: 0.0
# Plot E16, Crop 空心菜, Season 2, Area: 0.0
# Plot E16, Crop 黄心菜, Season 1, Area: 0.0
# Plot E16, Crop 黄心菜, Season 2, Area: 0.0
# Plot E16, Crop 生菜 , Season 1, Area: 0.0
# Plot E16, Crop 生菜 , Season 2, Area: 0.0
# Plot E16, Crop 芹菜, Season 1, Area: 0.0
# Plot E16, Crop 芹菜, Season 2, Area: 0.0
# Plot E16, Crop 菠菜 , Season 1, Area: 0.0
# Plot E16, Crop 菠菜 , Season 2, Area: 0.0
# Plot F1, Crop 小麦, Season 1, Area: 0.0
# Plot F1, Crop 小麦, Season 2, Area: 0.0
# Plot F1, Crop 玉米, Season 1, Area: 0.0
# Plot F1, Crop 玉米, Season 2, Area: 0.0
# Plot F1, Crop 黄豆, Season 1, Area: 0.0
# Plot F1, Crop 黄豆, Season 2, Area: 0.0
# Plot F1, Crop 绿豆, Season 1, Area: 0.0
# Plot F1, Crop 绿豆, Season 2, Area: 0.0
# Plot F1, Crop 谷子, Season 1, Area: 0.0
# Plot F1, Crop 谷子, Season 2, Area: 0.0
# Plot F1, Crop 黑豆, Season 1, Area: 0.0
# Plot F1, Crop 黑豆, Season 2, Area: 0.0
# Plot F1, Crop 红豆, Season 1, Area: 0.0
# Plot F1, Crop 红豆, Season 2, Area: 0.0
# Plot F1, Crop 爬豆, Season 1, Area: 0.0
# Plot F1, Crop 爬豆, Season 2, Area: 0.0
# Plot F1, Crop 高粱, Season 1, Area: 0.6
# Plot F1, Crop 高粱, Season 2, Area: 0.0
# Plot F1, Crop 黍子, Season 1, Area: 0.0
# Plot F1, Crop 黍子, Season 2, Area: 0.0
# Plot F1, Crop 莜麦, Season 1, Area: 0.0
# Plot F1, Crop 莜麦, Season 2, Area: 0.0
# Plot F1, Crop 大麦, Season 1, Area: 0.0
# Plot F1, Crop 大麦, Season 2, Area: 0.0
# Plot F1, Crop 荞麦, Season 1, Area: 0.0
# Plot F1, Crop 荞麦, Season 2, Area: 0.0
# Plot F1, Crop 南瓜, Season 1, Area: 0.0
# Plot F1, Crop 南瓜, Season 2, Area: 0.0
# Plot F1, Crop 红薯, Season 1, Area: 0.0
# Plot F1, Crop 红薯, Season 2, Area: 0.0
# Plot F1, Crop 土豆, Season 1, Area: 0.6
# Plot F1, Crop 土豆, Season 2, Area: -0.9
# Plot F1, Crop 白萝卜, Season 1, Area: 0.0
# Plot F1, Crop 白萝卜, Season 2, Area: 0.0
# Plot F1, Crop 小青菜, Season 1, Area: 0.0
# Plot F1, Crop 小青菜, Season 2, Area: 0.0
# Plot F1, Crop 大白菜, Season 1, Area: 0.0
# Plot F1, Crop 大白菜, Season 2, Area: 0.0
# Plot F1, Crop 西红柿, Season 1, Area: 0.0
# Plot F1, Crop 西红柿, Season 2, Area: 0.0
# Plot F1, Crop 茄子, Season 1, Area: 0.0
# Plot F1, Crop 茄子, Season 2, Area: 0.0
# Plot F1, Crop 豇豆, Season 1, Area: 0.0
# Plot F1, Crop 豇豆, Season 2, Area: 0.0
# Plot F1, Crop 刀豆, Season 1, Area: 0.0
# Plot F1, Crop 刀豆, Season 2, Area: 0.0
# Plot F1, Crop 红萝卜, Season 1, Area: 0.0
# Plot F1, Crop 红萝卜, Season 2, Area: 0.0
# Plot F1, Crop 水稻, Season 1, Area: 0.0
# Plot F1, Crop 水稻, Season 2, Area: 0.0
# Plot F1, Crop 榆黄菇, Season 1, Area: 0.0
# Plot F1, Crop 榆黄菇, Season 2, Area: 0.0
# Plot F1, Crop 青椒, Season 1, Area: 0.0
# Plot F1, Crop 青椒, Season 2, Area: 0.0
# Plot F1, Crop 菜花, Season 1, Area: 0.0
# Plot F1, Crop 菜花, Season 2, Area: 0.0
# Plot F1, Crop 包菜, Season 1, Area: 0.0
# Plot F1, Crop 包菜, Season 2, Area: 0.0
# Plot F1, Crop 香菇, Season 1, Area: 0.0
# Plot F1, Crop 香菇, Season 2, Area: 0.0
# Plot F1, Crop 油麦菜, Season 1, Area: 0.0
# Plot F1, Crop 油麦菜, Season 2, Area: 0.0
# Plot F1, Crop 芸豆, Season 1, Area: 0.0
# Plot F1, Crop 芸豆, Season 2, Area: 0.0
# Plot F1, Crop 白灵菇, Season 1, Area: 0.0
# Plot F1, Crop 白灵菇, Season 2, Area: 0.0
# Plot F1, Crop 羊肚菌, Season 1, Area: 0.0
# Plot F1, Crop 羊肚菌, Season 2, Area: 0.0
# Plot F1, Crop 黄瓜, Season 1, Area: 0.0
# Plot F1, Crop 黄瓜, Season 2, Area: 0.0
# Plot F1, Crop 生菜, Season 1, Area: 0.0
# Plot F1, Crop 生菜, Season 2, Area: 0.0
# Plot F1, Crop 辣椒, Season 1, Area: 0.0
# Plot F1, Crop 辣椒, Season 2, Area: 0.0
# Plot F1, Crop 空心菜, Season 1, Area: 0.0
# Plot F1, Crop 空心菜, Season 2, Area: 0.0
# Plot F1, Crop 黄心菜, Season 1, Area: 0.0
# Plot F1, Crop 黄心菜, Season 2, Area: 0.0
# Plot F1, Crop 生菜 , Season 1, Area: 0.0
# Plot F1, Crop 生菜 , Season 2, Area: 0.0
# Plot F1, Crop 芹菜, Season 1, Area: 0.0
# Plot F1, Crop 芹菜, Season 2, Area: 0.0
# Plot F1, Crop 菠菜 , Season 1, Area: 0.0
# Plot F1, Crop 菠菜 , Season 2, Area: 0.0
# Plot F2, Crop 小麦, Season 1, Area: 0.0
# Plot F2, Crop 小麦, Season 2, Area: 0.0
# Plot F2, Crop 玉米, Season 1, Area: 0.0
# Plot F2, Crop 玉米, Season 2, Area: 0.0
# Plot F2, Crop 黄豆, Season 1, Area: 0.0
# Plot F2, Crop 黄豆, Season 2, Area: 0.0
# Plot F2, Crop 绿豆, Season 1, Area: 0.0
# Plot F2, Crop 绿豆, Season 2, Area: 0.0
# Plot F2, Crop 谷子, Season 1, Area: 0.0
# Plot F2, Crop 谷子, Season 2, Area: 0.0
# Plot F2, Crop 黑豆, Season 1, Area: 0.0
# Plot F2, Crop 黑豆, Season 2, Area: 0.0
# Plot F2, Crop 红豆, Season 1, Area: 0.0
# Plot F2, Crop 红豆, Season 2, Area: 0.0
# Plot F2, Crop 爬豆, Season 1, Area: 0.0
# Plot F2, Crop 爬豆, Season 2, Area: 0.0
# Plot F2, Crop 高粱, Season 1, Area: 0.6
# Plot F2, Crop 高粱, Season 2, Area: 0.6
# Plot F2, Crop 黍子, Season 1, Area: 0.0
# Plot F2, Crop 黍子, Season 2, Area: 0.0
# Plot F2, Crop 莜麦, Season 1, Area: 0.0
# Plot F2, Crop 莜麦, Season 2, Area: 0.0
# Plot F2, Crop 大麦, Season 1, Area: 0.0
# Plot F2, Crop 大麦, Season 2, Area: 0.0
# Plot F2, Crop 荞麦, Season 1, Area: 0.0
# Plot F2, Crop 荞麦, Season 2, Area: 0.0
# Plot F2, Crop 南瓜, Season 1, Area: 0.0
# Plot F2, Crop 南瓜, Season 2, Area: 0.0
# Plot F2, Crop 红薯, Season 1, Area: 0.0
# Plot F2, Crop 红薯, Season 2, Area: 0.0
# Plot F2, Crop 土豆, Season 1, Area: -1.5
# Plot F2, Crop 土豆, Season 2, Area: 0.6
# Plot F2, Crop 白萝卜, Season 1, Area: 0.0
# Plot F2, Crop 白萝卜, Season 2, Area: 0.0
# Plot F2, Crop 小青菜, Season 1, Area: 0.0
# Plot F2, Crop 小青菜, Season 2, Area: 0.0
# Plot F2, Crop 大白菜, Season 1, Area: 0.0
# Plot F2, Crop 大白菜, Season 2, Area: 0.0
# Plot F2, Crop 西红柿, Season 1, Area: 0.0
# Plot F2, Crop 西红柿, Season 2, Area: 0.0
# Plot F2, Crop 茄子, Season 1, Area: 0.0
# Plot F2, Crop 茄子, Season 2, Area: 0.0
# Plot F2, Crop 豇豆, Season 1, Area: 0.0
# Plot F2, Crop 豇豆, Season 2, Area: 0.0
# Plot F2, Crop 刀豆, Season 1, Area: 0.0
# Plot F2, Crop 刀豆, Season 2, Area: 0.0
# Plot F2, Crop 红萝卜, Season 1, Area: 0.0
# Plot F2, Crop 红萝卜, Season 2, Area: 0.0
# Plot F2, Crop 水稻, Season 1, Area: 0.0
# Plot F2, Crop 水稻, Season 2, Area: 0.0
# Plot F2, Crop 榆黄菇, Season 1, Area: 0.0
# Plot F2, Crop 榆黄菇, Season 2, Area: 0.0
# Plot F2, Crop 青椒, Season 1, Area: 0.0
# Plot F2, Crop 青椒, Season 2, Area: 0.0
# Plot F2, Crop 菜花, Season 1, Area: 0.0
# Plot F2, Crop 菜花, Season 2, Area: 0.0
# Plot F2, Crop 包菜, Season 1, Area: 0.0
# Plot F2, Crop 包菜, Season 2, Area: 0.0
# Plot F2, Crop 香菇, Season 1, Area: 0.0
# Plot F2, Crop 香菇, Season 2, Area: 0.0
# Plot F2, Crop 油麦菜, Season 1, Area: 0.0
# Plot F2, Crop 油麦菜, Season 2, Area: 0.0
# Plot F2, Crop 芸豆, Season 1, Area: 0.0
# Plot F2, Crop 芸豆, Season 2, Area: 0.0
# Plot F2, Crop 白灵菇, Season 1, Area: 0.0
# Plot F2, Crop 白灵菇, Season 2, Area: 0.0
# Plot F2, Crop 羊肚菌, Season 1, Area: 0.0
# Plot F2, Crop 羊肚菌, Season 2, Area: 0.0
# Plot F2, Crop 黄瓜, Season 1, Area: 0.0
# Plot F2, Crop 黄瓜, Season 2, Area: 0.0
# Plot F2, Crop 生菜, Season 1, Area: 0.0
# Plot F2, Crop 生菜, Season 2, Area: 0.0
# Plot F2, Crop 辣椒, Season 1, Area: 0.0
# Plot F2, Crop 辣椒, Season 2, Area: 0.0
# Plot F2, Crop 空心菜, Season 1, Area: 0.0
# Plot F2, Crop 空心菜, Season 2, Area: 0.0
# Plot F2, Crop 黄心菜, Season 1, Area: 0.0
# Plot F2, Crop 黄心菜, Season 2, Area: 0.0
# Plot F2, Crop 生菜 , Season 1, Area: 0.0
# Plot F2, Crop 生菜 , Season 2, Area: 0.0
# Plot F2, Crop 芹菜, Season 1, Area: 0.0
# Plot F2, Crop 芹菜, Season 2, Area: 0.0
# Plot F2, Crop 菠菜 , Season 1, Area: 0.0
# Plot F2, Crop 菠菜 , Season 2, Area: 0.0
# Plot F3, Crop 小麦, Season 1, Area: 0.0
# Plot F3, Crop 小麦, Season 2, Area: 0.0
# Plot F3, Crop 玉米, Season 1, Area: 0.0
# Plot F3, Crop 玉米, Season 2, Area: 0.0
# Plot F3, Crop 黄豆, Season 1, Area: 0.0
# Plot F3, Crop 黄豆, Season 2, Area: 0.0
# Plot F3, Crop 绿豆, Season 1, Area: 0.0
# Plot F3, Crop 绿豆, Season 2, Area: 0.0
# Plot F3, Crop 谷子, Season 1, Area: 0.0
# Plot F3, Crop 谷子, Season 2, Area: 0.0
# Plot F3, Crop 黑豆, Season 1, Area: 0.0
# Plot F3, Crop 黑豆, Season 2, Area: 0.0
# Plot F3, Crop 红豆, Season 1, Area: 0.0
# Plot F3, Crop 红豆, Season 2, Area: 0.0
# Plot F3, Crop 爬豆, Season 1, Area: 0.0
# Plot F3, Crop 爬豆, Season 2, Area: 0.0
# Plot F3, Crop 高粱, Season 1, Area: 0.0
# Plot F3, Crop 高粱, Season 2, Area: 0.0
# Plot F3, Crop 黍子, Season 1, Area: 0.0
# Plot F3, Crop 黍子, Season 2, Area: 0.0
# Plot F3, Crop 莜麦, Season 1, Area: 0.0
# Plot F3, Crop 莜麦, Season 2, Area: 0.0
# Plot F3, Crop 大麦, Season 1, Area: 0.0
# Plot F3, Crop 大麦, Season 2, Area: 0.0
# Plot F3, Crop 荞麦, Season 1, Area: 0.0
# Plot F3, Crop 荞麦, Season 2, Area: 0.0
# Plot F3, Crop 南瓜, Season 1, Area: 0.0
# Plot F3, Crop 南瓜, Season 2, Area: 0.0
# Plot F3, Crop 红薯, Season 1, Area: 0.0
# Plot F3, Crop 红薯, Season 2, Area: 0.0
# Plot F3, Crop 土豆, Season 1, Area: 0.6
# Plot F3, Crop 土豆, Season 2, Area: 0.6
# Plot F3, Crop 白萝卜, Season 1, Area: 0.0
# Plot F3, Crop 白萝卜, Season 2, Area: 0.0
# Plot F3, Crop 小青菜, Season 1, Area: 0.0
# Plot F3, Crop 小青菜, Season 2, Area: 0.0
# Plot F3, Crop 大白菜, Season 1, Area: 0.0
# Plot F3, Crop 大白菜, Season 2, Area: 0.0
# Plot F3, Crop 西红柿, Season 1, Area: 0.0
# Plot F3, Crop 西红柿, Season 2, Area: 0.0
# Plot F3, Crop 茄子, Season 1, Area: 0.0
# Plot F3, Crop 茄子, Season 2, Area: 0.0
# Plot F3, Crop 豇豆, Season 1, Area: 0.0
# Plot F3, Crop 豇豆, Season 2, Area: 0.0
# Plot F3, Crop 刀豆, Season 1, Area: 0.6
# Plot F3, Crop 刀豆, Season 2, Area: 0.6
# Plot F3, Crop 红萝卜, Season 1, Area: 0.0
# Plot F3, Crop 红萝卜, Season 2, Area: 0.0
# Plot F3, Crop 水稻, Season 1, Area: 0.0
# Plot F3, Crop 水稻, Season 2, Area: 0.0
# Plot F3, Crop 榆黄菇, Season 1, Area: 0.0
# Plot F3, Crop 榆黄菇, Season 2, Area: 0.0
# Plot F3, Crop 青椒, Season 1, Area: 0.0
# Plot F3, Crop 青椒, Season 2, Area: 0.0
# Plot F3, Crop 菜花, Season 1, Area: 0.0
# Plot F3, Crop 菜花, Season 2, Area: 0.0
# Plot F3, Crop 包菜, Season 1, Area: 0.0
# Plot F3, Crop 包菜, Season 2, Area: 0.0
# Plot F3, Crop 香菇, Season 1, Area: 0.0
# Plot F3, Crop 香菇, Season 2, Area: 0.0
# Plot F3, Crop 油麦菜, Season 1, Area: 0.0
# Plot F3, Crop 油麦菜, Season 2, Area: 0.0
# Plot F3, Crop 芸豆, Season 1, Area: 0.0
# Plot F3, Crop 芸豆, Season 2, Area: 0.0
# Plot F3, Crop 白灵菇, Season 1, Area: 0.0
# Plot F3, Crop 白灵菇, Season 2, Area: 0.0
# Plot F3, Crop 羊肚菌, Season 1, Area: 0.0
# Plot F3, Crop 羊肚菌, Season 2, Area: 0.0
# Plot F3, Crop 黄瓜, Season 1, Area: 0.0
# Plot F3, Crop 黄瓜, Season 2, Area: 0.0
# Plot F3, Crop 生菜, Season 1, Area: 0.6
# Plot F3, Crop 生菜, Season 2, Area: -3.3
# Plot F3, Crop 辣椒, Season 1, Area: 0.0
# Plot F3, Crop 辣椒, Season 2, Area: 0.0
# Plot F3, Crop 空心菜, Season 1, Area: 0.0
# Plot F3, Crop 空心菜, Season 2, Area: 0.0
# Plot F3, Crop 黄心菜, Season 1, Area: 0.0
# Plot F3, Crop 黄心菜, Season 2, Area: 0.0
# Plot F3, Crop 生菜 , Season 1, Area: 0.0
# Plot F3, Crop 生菜 , Season 2, Area: 0.0
# Plot F3, Crop 芹菜, Season 1, Area: 0.9
# Plot F3, Crop 芹菜, Season 2, Area: 0.0
# Plot F3, Crop 菠菜 , Season 1, Area: 0.0
# Plot F3, Crop 菠菜 , Season 2, Area: 0.0
# Plot F4, Crop 小麦, Season 1, Area: 0.0
# Plot F4, Crop 小麦, Season 2, Area: 0.0
# Plot F4, Crop 玉米, Season 1, Area: 0.0
# Plot F4, Crop 玉米, Season 2, Area: 0.0
# Plot F4, Crop 黄豆, Season 1, Area: 0.0
# Plot F4, Crop 黄豆, Season 2, Area: 0.0
# Plot F4, Crop 绿豆, Season 1, Area: 0.0
# Plot F4, Crop 绿豆, Season 2, Area: 0.0
# Plot F4, Crop 谷子, Season 1, Area: 0.0
# Plot F4, Crop 谷子, Season 2, Area: 0.0
# Plot F4, Crop 黑豆, Season 1, Area: 0.0
# Plot F4, Crop 黑豆, Season 2, Area: 0.0
# Plot F4, Crop 红豆, Season 1, Area: 0.0
# Plot F4, Crop 红豆, Season 2, Area: 0.0
# Plot F4, Crop 爬豆, Season 1, Area: 0.0
# Plot F4, Crop 爬豆, Season 2, Area: 0.0
# Plot F4, Crop 高粱, Season 1, Area: 0.6
# Plot F4, Crop 高粱, Season 2, Area: 0.0
# Plot F4, Crop 黍子, Season 1, Area: 0.0
# Plot F4, Crop 黍子, Season 2, Area: 0.0
# Plot F4, Crop 莜麦, Season 1, Area: 0.0
# Plot F4, Crop 莜麦, Season 2, Area: 0.0
# Plot F4, Crop 大麦, Season 1, Area: 0.0
# Plot F4, Crop 大麦, Season 2, Area: 0.0
# Plot F4, Crop 荞麦, Season 1, Area: 0.0
# Plot F4, Crop 荞麦, Season 2, Area: 0.0
# Plot F4, Crop 南瓜, Season 1, Area: 0.0
# Plot F4, Crop 南瓜, Season 2, Area: 0.0
# Plot F4, Crop 红薯, Season 1, Area: 0.0
# Plot F4, Crop 红薯, Season 2, Area: 0.0
# Plot F4, Crop 土豆, Season 1, Area: 0.6
# Plot F4, Crop 土豆, Season 2, Area: -0.6
# Plot F4, Crop 白萝卜, Season 1, Area: 0.0
# Plot F4, Crop 白萝卜, Season 2, Area: 0.0
# Plot F4, Crop 小青菜, Season 1, Area: 0.0
# Plot F4, Crop 小青菜, Season 2, Area: 0.0
# Plot F4, Crop 大白菜, Season 1, Area: 0.0
# Plot F4, Crop 大白菜, Season 2, Area: 0.0
# Plot F4, Crop 西红柿, Season 1, Area: 0.0
# Plot F4, Crop 西红柿, Season 2, Area: 0.0
# Plot F4, Crop 茄子, Season 1, Area: 0.0
# Plot F4, Crop 茄子, Season 2, Area: 0.0
# Plot F4, Crop 豇豆, Season 1, Area: 0.0
# Plot F4, Crop 豇豆, Season 2, Area: 0.0
# Plot F4, Crop 刀豆, Season 1, Area: 0.0
# Plot F4, Crop 刀豆, Season 2, Area: 0.0
# Plot F4, Crop 红萝卜, Season 1, Area: 0.0
# Plot F4, Crop 红萝卜, Season 2, Area: 0.0
# Plot F4, Crop 水稻, Season 1, Area: 0.0
# Plot F4, Crop 水稻, Season 2, Area: 0.0
# Plot F4, Crop 榆黄菇, Season 1, Area: 0.0
# Plot F4, Crop 榆黄菇, Season 2, Area: 0.0
# Plot F4, Crop 青椒, Season 1, Area: 0.0
# Plot F4, Crop 青椒, Season 2, Area: 0.0
# Plot F4, Crop 菜花, Season 1, Area: 0.0
# Plot F4, Crop 菜花, Season 2, Area: 0.0
# Plot F4, Crop 包菜, Season 1, Area: 0.0
# Plot F4, Crop 包菜, Season 2, Area: 0.0
# Plot F4, Crop 香菇, Season 1, Area: 0.0
# Plot F4, Crop 香菇, Season 2, Area: 0.0
# Plot F4, Crop 油麦菜, Season 1, Area: 0.0
# Plot F4, Crop 油麦菜, Season 2, Area: 0.0
# Plot F4, Crop 芸豆, Season 1, Area: 0.0
# Plot F4, Crop 芸豆, Season 2, Area: 0.0
# Plot F4, Crop 白灵菇, Season 1, Area: 0.0
# Plot F4, Crop 白灵菇, Season 2, Area: 0.0
# Plot F4, Crop 羊肚菌, Season 1, Area: 0.0
# Plot F4, Crop 羊肚菌, Season 2, Area: 0.0
# Plot F4, Crop 黄瓜, Season 1, Area: 0.0
# Plot F4, Crop 黄瓜, Season 2, Area: 0.0
# Plot F4, Crop 生菜, Season 1, Area: 0.0
# Plot F4, Crop 生菜, Season 2, Area: 0.0
# Plot F4, Crop 辣椒, Season 1, Area: 0.0
# Plot F4, Crop 辣椒, Season 2, Area: 0.0
# Plot F4, Crop 空心菜, Season 1, Area: 0.0
# Plot F4, Crop 空心菜, Season 2, Area: 0.0
# Plot F4, Crop 黄心菜, Season 1, Area: 0.0
# Plot F4, Crop 黄心菜, Season 2, Area: 0.0
# Plot F4, Crop 生菜 , Season 1, Area: 0.0
# Plot F4, Crop 生菜 , Season 2, Area: 0.0
# Plot F4, Crop 芹菜, Season 1, Area: 0.0
# Plot F4, Crop 芹菜, Season 2, Area: 0.0
# Plot F4, Crop 菠菜 , Season 1, Area: 0.0
# Plot F4, Crop 菠菜 , Season 2, Area: 0.0
#         年份  地块  季次 作物名称  种植面积
# 0     2024  A1   1   高粱  80.0
# 1     2024  A2   1   高粱  55.0
# 2     2024  A3   1   高粱  35.0
# 3     2024  A4   1   高粱  72.0
# 4     2024  A5   1   高粱  68.0
# ...    ...  ..  ..  ...   ...
# 1255  2030  F3   2   刀豆   0.6
# 1256  2030  F3   1   生菜   0.6
# 1257  2030  F3   1   芹菜   0.9
# 1258  2030  F4   1   高粱   0.6
# 1259  2030  F4   1   土豆   0.6
#
# [1260 rows x 5 columns]
# Maximized Profit for 2023-2030: 65929978.824

# %%
import pandas as pd
from openpyxl import load_workbook

df_results = pd.DataFrame(results, columns=['年份', '地块', '季次', '作物名称', '种植面积'])
def filter_rows(row):
    plot = row['地块']
    area = row['种植面积']
    land_area = land_area_dict.get(plot, 0)  # 获取地块的面积，默认为0以防止 KeyError
    # 忽略种植面积小于地块面积 15% 的行
    return area >= 0.1 * land_area

# 应用过滤条件
df_filtered_results = df_results[df_results.apply(filter_rows, axis=1)]

# 查看过滤后的结果
for index,row in df_filtered_results.iterrows():
    print(row)
# Out:
# 年份      2024
# 地块        A1
# 季次         1
# 作物名称      高粱
# 种植面积    80.0
# Name: 0, dtype: object
# 年份      2024
# 地块        A2
# 季次         1
# 作物名称      高粱
# 种植面积    55.0
# Name: 1, dtype: object
# 年份      2024
# 地块        A3
# 季次         1
# 作物名称      高粱
# 种植面积    35.0
# Name: 2, dtype: object
# 年份      2024
# 地块        A4
# 季次         1
# 作物名称      高粱
# 种植面积    72.0
# Name: 3, dtype: object
# 年份      2024
# 地块        A5
# 季次         1
# 作物名称      高粱
# 种植面积    68.0
# Name: 4, dtype: object
# 年份      2024
# 地块        A6
# 季次         1
# 作物名称      高粱
# 种植面积    55.0
# Name: 5, dtype: object
# 年份      2024
# 地块        B1
# 季次         1
# 作物名称      高粱
# 种植面积    60.0
# Name: 6, dtype: object
# 年份      2024
# 地块        B2
# 季次         1
# 作物名称      高粱
# 种植面积    46.0
# Name: 7, dtype: object
# 年份      2024
# 地块        B3
# 季次         1
# 作物名称      高粱
# 种植面积    40.0
# Name: 8, dtype: object
# 年份      2024
# 地块        B4
# 季次         1
# 作物名称      高粱
# 种植面积    28.0
# Name: 9, dtype: object
# 年份      2024
# 地块        B5
# 季次         1
# 作物名称      高粱
# 种植面积    25.0
# Name: 10, dtype: object
# 年份      2024
# 地块        B6
# 季次         1
# 作物名称      高粱
# 种植面积    86.0
# Name: 11, dtype: object
# 年份      2024
# 地块        B7
# 季次         1
# 作物名称      高粱
# 种植面积    55.0
# Name: 12, dtype: object
# 年份      2024
# 地块        B8
# 季次         1
# 作物名称      高粱
# 种植面积    44.0
# Name: 13, dtype: object
# 年份      2024
# 地块        B9
# 季次         1
# 作物名称      高粱
# 种植面积    50.0
# Name: 14, dtype: object
# 年份      2024
# 地块       B10
# 季次         1
# 作物名称      高粱
# 种植面积    25.0
# Name: 15, dtype: object
# 年份      2024
# 地块       B11
# 季次         1
# 作物名称      高粱
# 种植面积    60.0
# Name: 16, dtype: object
# 年份      2024
# 地块       B12
# 季次         1
# 作物名称      高粱
# 种植面积    45.0
# Name: 17, dtype: object
# 年份      2024
# 地块       B13
# 季次         1
# 作物名称      高粱
# 种植面积    35.0
# Name: 18, dtype: object
# 年份      2024
# 地块       B14
# 季次         1
# 作物名称      高粱
# 种植面积    20.0
# Name: 19, dtype: object
# 年份      2024
# 地块        C1
# 季次         1
# 作物名称      高粱
# 种植面积    15.0
# Name: 20, dtype: object
# 年份      2024
# 地块        C2
# 季次         1
# 作物名称      高粱
# 种植面积    13.0
# Name: 21, dtype: object
# 年份      2024
# 地块        C3
# 季次         1
# 作物名称      高粱
# 种植面积    15.0
# Name: 22, dtype: object
# 年份      2024
# 地块        C4
# 季次         1
# 作物名称      高粱
# 种植面积    18.0
# Name: 23, dtype: object
# 年份      2024
# 地块        C5
# 季次         1
# 作物名称      高粱
# 种植面积    27.0
# Name: 24, dtype: object
# 年份      2024
# 地块        C6
# 季次         1
# 作物名称      高粱
# 种植面积    20.0
# Name: 25, dtype: object
# 年份      2024
# 地块        D1
# 季次         2
# 作物名称      高粱
# 种植面积    13.2
# Name: 27, dtype: object
# 年份      2024
# 地块        D2
# 季次         2
# 作物名称      高粱
# 种植面积     8.2
# Name: 31, dtype: object
# 年份      2024
# 地块        D3
# 季次         2
# 作物名称      高粱
# 种植面积    12.2
# Name: 35, dtype: object
# 年份      2024
# 地块        D4
# 季次         2
# 作物名称      高粱
# 种植面积     4.2
# Name: 39, dtype: object
# 年份      2024
# 地块        D5
# 季次         2
# 作物名称      高粱
# 种植面积     8.2
# Name: 43, dtype: object
# 年份      2024
# 地块        D6
# 季次         2
# 作物名称      高粱
# 种植面积    10.2
# Name: 47, dtype: object
# 年份      2024
# 地块        D7
# 季次         2
# 作物名称      高粱
# 种植面积    20.2
# Name: 51, dtype: object
# 年份      2024
# 地块        D8
# 季次         2
# 作物名称      高粱
# 种植面积    18.2
# Name: 55, dtype: object
# 年份      2024
# 地块        E1
# 季次         2
# 作物名称      高粱
# 种植面积     0.6
# Name: 58, dtype: object
# 年份      2024
# 地块        E2
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 59, dtype: object
# 年份      2024
# 地块        E3
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 60, dtype: object
# 年份      2024
# 地块        E4
# 季次         2
# 作物名称      高粱
# 种植面积     0.6
# Name: 61, dtype: object
# 年份      2024
# 地块        E5
# 季次         2
# 作物名称      高粱
# 种植面积     0.6
# Name: 62, dtype: object
# 年份      2024
# 地块        E6
# 季次         2
# 作物名称      高粱
# 种植面积     0.6
# Name: 63, dtype: object
# 年份      2024
# 地块        E7
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 64, dtype: object
# 年份      2024
# 地块        E8
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 65, dtype: object
# 年份      2024
# 地块        E9
# 季次         2
# 作物名称      高粱
# 种植面积     0.6
# Name: 66, dtype: object
# 年份      2024
# 地块       E10
# 季次         2
# 作物名称      高粱
# 种植面积     0.6
# Name: 67, dtype: object
# 年份      2024
# 地块       E11
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 68, dtype: object
# 年份      2024
# 地块       E12
# 季次         2
# 作物名称      高粱
# 种植面积     0.6
# Name: 69, dtype: object
# 年份      2024
# 地块       E13
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 70, dtype: object
# 年份      2024
# 地块       E14
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 71, dtype: object
# 年份      2024
# 地块       E15
# 季次         2
# 作物名称      高粱
# 种植面积     0.3
# Name: 72, dtype: object
# 年份      2024
# 地块       E16
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 73, dtype: object
# 年份      2024
# 地块        F1
# 季次         1
# 作物名称      高粱
# 种植面积     0.3
# Name: 74, dtype: object
# 年份      2024
# 地块        F2
# 季次         1
# 作物名称      高粱
# 种植面积     0.3
# Name: 75, dtype: object
# 年份      2024
# 地块        F3
# 季次         2
# 作物名称      高粱
# 种植面积     0.6
# Name: 76, dtype: object
# 年份      2024
# 地块        F4
# 季次         2
# 作物名称      高粱
# 种植面积     0.6
# Name: 77, dtype: object
# 年份       2025
# 地块         A1
# 季次          1
# 作物名称       玉米
# 种植面积    74.55
# Name: 79, dtype: object
# 年份       2025
# 地块         A2
# 季次          1
# 作物名称       玉米
# 种植面积    49.55
# Name: 84, dtype: object
# 年份      2025
# 地块        A3
# 季次         1
# 作物名称      小麦
# 种植面积     4.4
# Name: 88, dtype: object
# 年份       2025
# 地块         A3
# 季次          1
# 作物名称       玉米
# 种植面积    29.55
# Name: 89, dtype: object
# 年份       2025
# 地块         A4
# 季次          1
# 作物名称       玉米
# 种植面积    66.55
# Name: 94, dtype: object
# 年份       2025
# 地块         A5
# 季次          1
# 作物名称       玉米
# 种植面积    62.55
# Name: 99, dtype: object
# 年份       2025
# 地块         A6
# 季次          1
# 作物名称       玉米
# 种植面积    49.55
# Name: 104, dtype: object
# 年份       2025
# 地块         B1
# 季次          1
# 作物名称       玉米
# 种植面积    54.55
# Name: 109, dtype: object
# 年份       2025
# 地块         B2
# 季次          1
# 作物名称       玉米
# 种植面积    40.55
# Name: 114, dtype: object
# 年份      2025
# 地块        B3
# 季次         1
# 作物名称      小麦
# 种植面积     4.4
# Name: 118, dtype: object
# 年份       2025
# 地块         B3
# 季次          1
# 作物名称       玉米
# 种植面积    34.55
# Name: 119, dtype: object
# 年份      2025
# 地块        B4
# 季次         1
# 作物名称      小麦
# 种植面积     4.4
# Name: 123, dtype: object
# 年份       2025
# 地块         B4
# 季次          1
# 作物名称       玉米
# 种植面积    22.55
# Name: 124, dtype: object
# 年份      2025
# 地块        B5
# 季次         1
# 作物名称      小麦
# 种植面积     4.4
# Name: 128, dtype: object
# 年份       2025
# 地块         B5
# 季次          1
# 作物名称       玉米
# 种植面积    19.55
# Name: 129, dtype: object
# 年份       2025
# 地块         B6
# 季次          1
# 作物名称       玉米
# 种植面积    80.55
# Name: 134, dtype: object
# 年份       2025
# 地块         B7
# 季次          1
# 作物名称       玉米
# 种植面积    49.55
# Name: 139, dtype: object
# 年份      2025
# 地块        B8
# 季次         1
# 作物名称      小麦
# 种植面积     4.4
# Name: 143, dtype: object
# 年份       2025
# 地块         B8
# 季次          1
# 作物名称       玉米
# 种植面积    38.55
# Name: 144, dtype: object
# 年份       2025
# 地块         B9
# 季次          1
# 作物名称       玉米
# 种植面积    44.55
# Name: 149, dtype: object
# 年份      2025
# 地块       B10
# 季次         1
# 作物名称      小麦
# 种植面积     4.4
# Name: 153, dtype: object
# 年份       2025
# 地块        B10
# 季次          1
# 作物名称       玉米
# 种植面积    19.55
# Name: 154, dtype: object
# 年份       2025
# 地块        B11
# 季次          1
# 作物名称       玉米
# 种植面积    54.55
# Name: 159, dtype: object
# 年份       2025
# 地块        B12
# 季次          1
# 作物名称       玉米
# 种植面积    39.55
# Name: 164, dtype: object
# 年份      2025
# 地块       B13
# 季次         1
# 作物名称      小麦
# 种植面积     4.4
# Name: 168, dtype: object
# 年份       2025
# 地块        B13
# 季次          1
# 作物名称       玉米
# 种植面积    29.55
# Name: 169, dtype: object
# 年份      2025
# 地块       B14
# 季次         1
# 作物名称      小麦
# 种植面积     4.4
# Name: 173, dtype: object
# 年份       2025
# 地块        B14
# 季次          1
# 作物名称       玉米
# 种植面积    14.55
# Name: 174, dtype: object
# 年份      2025
# 地块        C1
# 季次         1
# 作物名称      小麦
# 种植面积     4.4
# Name: 178, dtype: object
# 年份      2025
# 地块        C1
# 季次         1
# 作物名称      玉米
# 种植面积    9.55
# Name: 179, dtype: object
# 年份      2025
# 地块        C2
# 季次         1
# 作物名称      小麦
# 种植面积     4.4
# Name: 183, dtype: object
# 年份      2025
# 地块        C2
# 季次         1
# 作物名称      玉米
# 种植面积    7.55
# Name: 184, dtype: object
# 年份      2025
# 地块        C3
# 季次         1
# 作物名称      小麦
# 种植面积     4.4
# Name: 188, dtype: object
# 年份      2025
# 地块        C3
# 季次         1
# 作物名称      玉米
# 种植面积    9.55
# Name: 189, dtype: object
# 年份      2025
# 地块        C4
# 季次         1
# 作物名称      小麦
# 种植面积     4.4
# Name: 193, dtype: object
# 年份       2025
# 地块         C4
# 季次          1
# 作物名称       玉米
# 种植面积    12.55
# Name: 194, dtype: object
# 年份      2025
# 地块        C5
# 季次         1
# 作物名称      小麦
# 种植面积     4.4
# Name: 198, dtype: object
# 年份       2025
# 地块         C5
# 季次          1
# 作物名称       玉米
# 种植面积    21.55
# Name: 199, dtype: object
# 年份      2025
# 地块        C6
# 季次         1
# 作物名称      小麦
# 种植面积     4.4
# Name: 203, dtype: object
# 年份       2025
# 地块         C6
# 季次          1
# 作物名称       玉米
# 种植面积    14.55
# Name: 204, dtype: object
# 年份       2025
# 地块         D1
# 季次          1
# 作物名称      黄心菜
# 种植面积    11.55
# Name: 214, dtype: object
# 年份      2025
# 地块        D2
# 季次         2
# 作物名称     黄心菜
# 种植面积    6.55
# Name: 223, dtype: object
# 年份       2025
# 地块         D3
# 季次          2
# 作物名称      黄心菜
# 种植面积    10.55
# Name: 231, dtype: object
# 年份      2025
# 地块        D4
# 季次         1
# 作物名称     黄心菜
# 种植面积    2.55
# Name: 238, dtype: object
# 年份      2025
# 地块        D5
# 季次         2
# 作物名称     黄心菜
# 种植面积    6.55
# Name: 247, dtype: object
# 年份      2025
# 地块        D6
# 季次         2
# 作物名称     黄心菜
# 种植面积    8.55
# Name: 255, dtype: object
# 年份       2025
# 地块         D7
# 季次          2
# 作物名称      黄心菜
# 种植面积    18.55
# Name: 263, dtype: object
# 年份       2025
# 地块         D8
# 季次          2
# 作物名称      黄心菜
# 种植面积    16.55
# Name: 271, dtype: object
# 年份      2025
# 地块        E1
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 272, dtype: object
# 年份      2025
# 地块        E2
# 季次         2
# 作物名称      高粱
# 种植面积     0.6
# Name: 273, dtype: object
# 年份      2025
# 地块        E3
# 季次         2
# 作物名称      高粱
# 种植面积     0.6
# Name: 274, dtype: object
# 年份      2025
# 地块        E4
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 275, dtype: object
# 年份      2025
# 地块        E5
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 276, dtype: object
# 年份      2025
# 地块        E6
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 277, dtype: object
# 年份      2025
# 地块        E7
# 季次         2
# 作物名称      高粱
# 种植面积     0.6
# Name: 278, dtype: object
# 年份      2025
# 地块        E8
# 季次         2
# 作物名称      高粱
# 种植面积     0.6
# Name: 279, dtype: object
# 年份      2025
# 地块        E9
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 280, dtype: object
# 年份      2025
# 地块       E10
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 281, dtype: object
# 年份      2025
# 地块       E11
# 季次         2
# 作物名称      高粱
# 种植面积     0.6
# Name: 282, dtype: object
# 年份      2025
# 地块       E12
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 283, dtype: object
# 年份      2025
# 地块       E13
# 季次         2
# 作物名称      高粱
# 种植面积     0.6
# Name: 284, dtype: object
# 年份      2025
# 地块       E14
# 季次         2
# 作物名称      高粱
# 种植面积     0.6
# Name: 285, dtype: object
# 年份      2025
# 地块       E15
# 季次         1
# 作物名称      高粱
# 种植面积     0.3
# Name: 286, dtype: object
# 年份      2025
# 地块       E16
# 季次         2
# 作物名称      高粱
# 种植面积     0.6
# Name: 287, dtype: object
# 年份      2025
# 地块        F1
# 季次         2
# 作物名称      高粱
# 种植面积     0.3
# Name: 288, dtype: object
# 年份      2025
# 地块        F2
# 季次         2
# 作物名称      高粱
# 种植面积     0.3
# Name: 289, dtype: object
# 年份      2025
# 地块        F3
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 290, dtype: object
# 年份      2025
# 地块        F4
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 291, dtype: object
# 年份      2026
# 地块        A1
# 季次         1
# 作物名称      谷子
# 种植面积    80.0
# Name: 292, dtype: object
# 年份      2026
# 地块        A2
# 季次         1
# 作物名称      谷子
# 种植面积    55.0
# Name: 293, dtype: object
# 年份      2026
# 地块        A3
# 季次         1
# 作物名称      谷子
# 种植面积    35.0
# Name: 294, dtype: object
# 年份      2026
# 地块        A4
# 季次         1
# 作物名称      谷子
# 种植面积    72.0
# Name: 295, dtype: object
# 年份      2026
# 地块        A5
# 季次         1
# 作物名称      谷子
# 种植面积    68.0
# Name: 296, dtype: object
# 年份      2026
# 地块        A6
# 季次         1
# 作物名称      谷子
# 种植面积    55.0
# Name: 297, dtype: object
# 年份      2026
# 地块        B1
# 季次         1
# 作物名称      谷子
# 种植面积    60.0
# Name: 298, dtype: object
# 年份      2026
# 地块        B2
# 季次         1
# 作物名称      谷子
# 种植面积    46.0
# Name: 299, dtype: object
# 年份      2026
# 地块        B3
# 季次         1
# 作物名称      谷子
# 种植面积    40.0
# Name: 300, dtype: object
# 年份      2026
# 地块        B4
# 季次         1
# 作物名称      谷子
# 种植面积    28.0
# Name: 301, dtype: object
# 年份      2026
# 地块        B5
# 季次         1
# 作物名称      谷子
# 种植面积    25.0
# Name: 302, dtype: object
# 年份      2026
# 地块        B6
# 季次         1
# 作物名称      谷子
# 种植面积    86.0
# Name: 303, dtype: object
# 年份      2026
# 地块        B7
# 季次         1
# 作物名称      谷子
# 种植面积    55.0
# Name: 304, dtype: object
# 年份      2026
# 地块        B8
# 季次         1
# 作物名称      谷子
# 种植面积    44.0
# Name: 305, dtype: object
# 年份      2026
# 地块        B9
# 季次         1
# 作物名称      谷子
# 种植面积    50.0
# Name: 306, dtype: object
# 年份      2026
# 地块       B10
# 季次         1
# 作物名称      谷子
# 种植面积    25.0
# Name: 307, dtype: object
# 年份      2026
# 地块       B11
# 季次         1
# 作物名称      谷子
# 种植面积    60.0
# Name: 308, dtype: object
# 年份      2026
# 地块       B12
# 季次         1
# 作物名称      谷子
# 种植面积    45.0
# Name: 309, dtype: object
# 年份      2026
# 地块       B13
# 季次         1
# 作物名称      谷子
# 种植面积    35.0
# Name: 310, dtype: object
# 年份      2026
# 地块       B14
# 季次         1
# 作物名称      谷子
# 种植面积    20.0
# Name: 311, dtype: object
# 年份      2026
# 地块        C1
# 季次         1
# 作物名称      谷子
# 种植面积    15.0
# Name: 312, dtype: object
# 年份      2026
# 地块        C2
# 季次         1
# 作物名称      谷子
# 种植面积    13.0
# Name: 313, dtype: object
# 年份      2026
# 地块        C3
# 季次         1
# 作物名称      谷子
# 种植面积    15.0
# Name: 314, dtype: object
# 年份      2026
# 地块        C4
# 季次         1
# 作物名称      谷子
# 种植面积    18.0
# Name: 315, dtype: object
# 年份      2026
# 地块        C5
# 季次         1
# 作物名称      谷子
# 种植面积    27.0
# Name: 316, dtype: object
# 年份      2026
# 地块        C6
# 季次         1
# 作物名称      谷子
# 种植面积    20.0
# Name: 317, dtype: object
# 年份      2026
# 地块        D1
# 季次         1
# 作物名称     榆黄菇
# 种植面积     2.3
# Name: 328, dtype: object
# 年份      2026
# 地块        D1
# 季次         2
# 作物名称     榆黄菇
# 种植面积     2.3
# Name: 329, dtype: object
# 年份      2026
# 地块        D1
# 季次         1
# 作物名称     白灵菇
# 种植面积    2.95
# Name: 330, dtype: object
# 年份      2026
# 地块        D1
# 季次         2
# 作物名称     白灵菇
# 种植面积    2.95
# Name: 331, dtype: object
# 年份      2026
# 地块        D2
# 季次         1
# 作物名称     榆黄菇
# 种植面积     2.3
# Name: 334, dtype: object
# 年份      2026
# 地块        D2
# 季次         2
# 作物名称     榆黄菇
# 种植面积     2.3
# Name: 335, dtype: object
# 年份      2026
# 地块        D2
# 季次         1
# 作物名称     白灵菇
# 种植面积    2.95
# Name: 336, dtype: object
# 年份      2026
# 地块        D2
# 季次         2
# 作物名称     白灵菇
# 种植面积    2.45
# Name: 337, dtype: object
# 年份      2026
# 地块        D3
# 季次         1
# 作物名称     榆黄菇
# 种植面积     2.3
# Name: 347, dtype: object
# 年份      2026
# 地块        D3
# 季次         2
# 作物名称     榆黄菇
# 种植面积     2.3
# Name: 348, dtype: object
# 年份      2026
# 地块        D3
# 季次         1
# 作物名称     白灵菇
# 种植面积    2.95
# Name: 349, dtype: object
# 年份      2026
# 地块        D3
# 季次         2
# 作物名称     白灵菇
# 种植面积    2.95
# Name: 350, dtype: object
# 年份      2026
# 地块        D4
# 季次         1
# 作物名称     榆黄菇
# 种植面积     2.3
# Name: 353, dtype: object
# 年份      2026
# 地块        D4
# 季次         2
# 作物名称     榆黄菇
# 种植面积     2.3
# Name: 354, dtype: object
# 年份      2026
# 地块        D4
# 季次         1
# 作物名称     白灵菇
# 种植面积     1.4
# Name: 355, dtype: object
# 年份      2026
# 地块        D5
# 季次         1
# 作物名称     榆黄菇
# 种植面积     2.3
# Name: 356, dtype: object
# 年份      2026
# 地块        D5
# 季次         2
# 作物名称     榆黄菇
# 种植面积     2.3
# Name: 357, dtype: object
# 年份      2026
# 地块        D5
# 季次         1
# 作物名称     白灵菇
# 种植面积    2.45
# Name: 358, dtype: object
# 年份      2026
# 地块        D5
# 季次         2
# 作物名称     白灵菇
# 种植面积    2.95
# Name: 359, dtype: object
# 年份      2026
# 地块        D6
# 季次         1
# 作物名称     榆黄菇
# 种植面积     2.3
# Name: 363, dtype: object
# 年份      2026
# 地块        D6
# 季次         2
# 作物名称     榆黄菇
# 种植面积     2.3
# Name: 364, dtype: object
# 年份      2026
# 地块        D6
# 季次         1
# 作物名称     白灵菇
# 种植面积    2.95
# Name: 365, dtype: object
# 年份      2026
# 地块        D6
# 季次         2
# 作物名称     白灵菇
# 种植面积    2.95
# Name: 366, dtype: object
# 年份          2026
# 地块            D7
# 季次             1
# 作物名称          红豆
# 种植面积    3.633333
# Name: 370, dtype: object
# 年份          2026
# 地块            D7
# 季次             2
# 作物名称          红豆
# 种植面积    2.766667
# Name: 371, dtype: object
# 年份      2026
# 地块        D7
# 季次         1
# 作物名称     榆黄菇
# 种植面积     2.3
# Name: 381, dtype: object
# 年份      2026
# 地块        D7
# 季次         2
# 作物名称     榆黄菇
# 种植面积     2.3
# Name: 382, dtype: object
# 年份      2026
# 地块        D7
# 季次         1
# 作物名称     白灵菇
# 种植面积    2.95
# Name: 383, dtype: object
# 年份      2026
# 地块        D7
# 季次         2
# 作物名称     白灵菇
# 种植面积    2.95
# Name: 384, dtype: object
# 年份          2026
# 地块            D8
# 季次             2
# 作物名称          红豆
# 种植面积    3.633333
# Name: 390, dtype: object
# 年份      2026
# 地块        D8
# 季次         1
# 作物名称     榆黄菇
# 种植面积     2.3
# Name: 400, dtype: object
# 年份      2026
# 地块        D8
# 季次         2
# 作物名称     榆黄菇
# 种植面积     2.3
# Name: 401, dtype: object
# 年份      2026
# 地块        D8
# 季次         1
# 作物名称     白灵菇
# 种植面积    2.95
# Name: 402, dtype: object
# 年份      2026
# 地块        D8
# 季次         2
# 作物名称     白灵菇
# 种植面积    2.95
# Name: 403, dtype: object
# 年份      2026
# 地块        E1
# 季次         1
# 作物名称      土豆
# 种植面积     0.6
# Name: 406, dtype: object
# 年份      2026
# 地块        E2
# 季次         1
# 作物名称      土豆
# 种植面积     0.6
# Name: 407, dtype: object
# 年份      2026
# 地块        E3
# 季次         1
# 作物名称      土豆
# 种植面积     0.6
# Name: 408, dtype: object
# 年份      2026
# 地块        E4
# 季次         2
# 作物名称      土豆
# 种植面积     0.6
# Name: 409, dtype: object
# 年份      2026
# 地块        E5
# 季次         1
# 作物名称      土豆
# 种植面积     0.6
# Name: 410, dtype: object
# 年份      2026
# 地块        E6
# 季次         2
# 作物名称      土豆
# 种植面积     0.6
# Name: 411, dtype: object
# 年份      2026
# 地块        E7
# 季次         2
# 作物名称      土豆
# 种植面积     0.6
# Name: 412, dtype: object
# 年份      2026
# 地块        E8
# 季次         2
# 作物名称      土豆
# 种植面积     0.6
# Name: 413, dtype: object
# 年份      2026
# 地块        E9
# 季次         1
# 作物名称      土豆
# 种植面积     0.6
# Name: 414, dtype: object
# 年份      2026
# 地块       E10
# 季次         1
# 作物名称      土豆
# 种植面积     0.6
# Name: 415, dtype: object
# 年份      2026
# 地块       E11
# 季次         2
# 作物名称      土豆
# 种植面积     0.6
# Name: 416, dtype: object
# 年份      2026
# 地块       E12
# 季次         1
# 作物名称      土豆
# 种植面积     0.6
# Name: 417, dtype: object
# 年份      2026
# 地块       E13
# 季次         2
# 作物名称      土豆
# 种植面积     0.6
# Name: 418, dtype: object
# 年份      2026
# 地块       E14
# 季次         2
# 作物名称      土豆
# 种植面积     0.6
# Name: 419, dtype: object
# 年份      2026
# 地块       E15
# 季次         1
# 作物名称      土豆
# 种植面积     0.3
# Name: 420, dtype: object
# 年份      2026
# 地块       E16
# 季次         1
# 作物名称      土豆
# 种植面积     0.6
# Name: 421, dtype: object
# 年份      2026
# 地块        F1
# 季次         2
# 作物名称      土豆
# 种植面积     0.3
# Name: 422, dtype: object
# 年份      2026
# 地块        F2
# 季次         2
# 作物名称      土豆
# 种植面积     0.3
# Name: 423, dtype: object
# 年份      2026
# 地块        F3
# 季次         2
# 作物名称      土豆
# 种植面积     0.6
# Name: 424, dtype: object
# 年份      2026
# 地块        F4
# 季次         1
# 作物名称      土豆
# 种植面积     0.6
# Name: 425, dtype: object
# 年份      2027
# 地块        A1
# 季次         2
# 作物名称      黑豆
# 种植面积    80.0
# Name: 426, dtype: object
# 年份      2027
# 地块        A2
# 季次         1
# 作物名称      绿豆
# 种植面积    53.8
# Name: 429, dtype: object
# 年份      2027
# 地块        A3
# 季次         1
# 作物名称      刀豆
# 种植面积    32.3
# Name: 436, dtype: object
# 年份      2027
# 地块        A4
# 季次         1
# 作物名称      豇豆
# 种植面积    72.0
# Name: 442, dtype: object
# 年份      2027
# 地块        A5
# 季次         2
# 作物名称      黑豆
# 种植面积    68.0
# Name: 445, dtype: object
# 年份      2027
# 地块        A6
# 季次         2
# 作物名称      黄豆
# 种植面积    55.0
# Name: 450, dtype: object
# 年份      2027
# 地块        B1
# 季次         2
# 作物名称      芸豆
# 种植面积    60.0
# Name: 457, dtype: object
# 年份      2027
# 地块        B2
# 季次         1
# 作物名称      刀豆
# 种植面积    43.6
# Name: 461, dtype: object
# 年份      2027
# 地块        B3
# 季次         1
# 作物名称      土豆
# 种植面积    37.3
# Name: 465, dtype: object
# 年份      2027
# 地块        B3
# 季次         2
# 作物名称      豇豆
# 种植面积    39.4
# Name: 466, dtype: object
# 年份      2027
# 地块        B4
# 季次         1
# 作物名称     黄心菜
# 种植面积    26.8
# Name: 474, dtype: object
# 年份      2027
# 地块        B5
# 季次         1
# 作物名称      刀豆
# 种植面积    22.3
# Name: 477, dtype: object
# 年份      2027
# 地块        B6
# 季次         2
# 作物名称      刀豆
# 种植面积    86.0
# Name: 483, dtype: object
# 年份      2027
# 地块        B7
# 季次         1
# 作物名称      爬豆
# 种植面积    55.0
# Name: 485, dtype: object
# 年份      2027
# 地块        B8
# 季次         1
# 作物名称      刀豆
# 种植面积    42.2
# Name: 493, dtype: object
# 年份      2027
# 地块        B9
# 季次         1
# 作物名称      刀豆
# 种植面积    47.6
# Name: 498, dtype: object
# 年份      2027
# 地块       B10
# 季次         1
# 作物名称      刀豆
# 种植面积    22.3
# Name: 504, dtype: object
# 年份      2027
# 地块       B11
# 季次         2
# 作物名称      芸豆
# 种植面积    60.0
# Name: 510, dtype: object
# 年份      2027
# 地块       B11
# 季次         1
# 作物名称     白灵菇
# 种植面积    59.4
# Name: 511, dtype: object
# 年份      2027
# 地块       B12
# 季次         1
# 作物名称      黄豆
# 种植面积    45.0
# Name: 512, dtype: object
# 年份      2027
# 地块       B13
# 季次         2
# 作物名称      高粱
# 种植面积    33.8
# Name: 514, dtype: object
# 年份      2027
# 地块       B13
# 季次         1
# 作物名称      豇豆
# 种植面积    35.0
# Name: 517, dtype: object
# 年份      2027
# 地块       B14
# 季次         1
# 作物名称      刀豆
# 种植面积    17.3
# Name: 520, dtype: object
# 年份      2027
# 地块        C1
# 季次         1
# 作物名称      高粱
# 种植面积    13.2
# Name: 524, dtype: object
# 年份      2027
# 地块        C2
# 季次         1
# 作物名称      高粱
# 种植面积    11.8
# Name: 528, dtype: object
# 年份      2027
# 地块        C3
# 季次         1
# 作物名称      土豆
# 种植面积    11.1
# Name: 531, dtype: object
# 年份      2027
# 地块        C4
# 季次         2
# 作物名称      刀豆
# 种植面积    15.3
# Name: 542, dtype: object
# 年份      2027
# 地块        C5
# 季次         1
# 作物名称      高粱
# 种植面积    25.2
# Name: 545, dtype: object
# 年份      2027
# 地块        C6
# 季次         1
# 作物名称      高粱
# 种植面积    18.8
# Name: 549, dtype: object
# 年份      2027
# 地块        D1
# 季次         2
# 作物名称      豇豆
# 种植面积    13.8
# Name: 554, dtype: object
# 年份      2027
# 地块        D1
# 季次         1
# 作物名称      生菜
# 种植面积    11.7
# Name: 557, dtype: object
# 年份      2027
# 地块        D2
# 季次         1
# 作物名称      刀豆
# 种植面积     7.3
# Name: 562, dtype: object
# 年份      2027
# 地块        D3
# 季次         1
# 作物名称      高粱
# 种植面积    12.8
# Name: 566, dtype: object
# 年份      2027
# 地块        D4
# 季次         1
# 作物名称      高粱
# 种植面积     4.8
# Name: 569, dtype: object
# 年份      2027
# 地块        D5
# 季次         2
# 作物名称      高粱
# 种植面积     8.2
# Name: 573, dtype: object
# 年份      2027
# 地块        D6
# 季次         1
# 作物名称      高粱
# 种植面积    10.2
# Name: 576, dtype: object
# 年份      2027
# 地块        D7
# 季次         2
# 作物名称      高粱
# 种植面积    20.2
# Name: 581, dtype: object
# 年份      2027
# 地块        D8
# 季次         1
# 作物名称      刀豆
# 种植面积    19.4
# Name: 585, dtype: object
# 年份      2027
# 地块        E1
# 季次         1
# 作物名称      土豆
# 种植面积     0.6
# Name: 587, dtype: object
# 年份      2027
# 地块        E2
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 588, dtype: object
# 年份      2027
# 地块        E2
# 季次         1
# 作物名称      土豆
# 种植面积     0.6
# Name: 589, dtype: object
# 年份      2027
# 地块        E3
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 590, dtype: object
# 年份      2027
# 地块        E3
# 季次         1
# 作物名称      土豆
# 种植面积     0.6
# Name: 591, dtype: object
# 年份      2027
# 地块        E4
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 592, dtype: object
# 年份      2027
# 地块        E4
# 季次         1
# 作物名称      土豆
# 种植面积     0.6
# Name: 593, dtype: object
# 年份      2027
# 地块        E5
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 594, dtype: object
# 年份      2027
# 地块        E5
# 季次         1
# 作物名称      土豆
# 种植面积     0.6
# Name: 595, dtype: object
# 年份      2027
# 地块        E6
# 季次         2
# 作物名称      高粱
# 种植面积     0.6
# Name: 596, dtype: object
# 年份      2027
# 地块        E6
# 季次         2
# 作物名称      土豆
# 种植面积     0.6
# Name: 597, dtype: object
# 年份      2027
# 地块        E7
# 季次         2
# 作物名称      土豆
# 种植面积     0.6
# Name: 598, dtype: object
# 年份      2027
# 地块        E8
# 季次         2
# 作物名称      高粱
# 种植面积     0.6
# Name: 599, dtype: object
# 年份      2027
# 地块        E8
# 季次         2
# 作物名称      土豆
# 种植面积     0.6
# Name: 600, dtype: object
# 年份      2027
# 地块        E9
# 季次         1
# 作物名称      土豆
# 种植面积     0.6
# Name: 601, dtype: object
# 年份      2027
# 地块       E10
# 季次         2
# 作物名称      高粱
# 种植面积     0.6
# Name: 602, dtype: object
# 年份      2027
# 地块       E10
# 季次         1
# 作物名称      土豆
# 种植面积     0.6
# Name: 603, dtype: object
# 年份      2027
# 地块       E11
# 季次         2
# 作物名称      土豆
# 种植面积     0.6
# Name: 604, dtype: object
# 年份      2027
# 地块       E12
# 季次         1
# 作物名称      土豆
# 种植面积     0.6
# Name: 605, dtype: object
# 年份      2027
# 地块       E13
# 季次         2
# 作物名称      土豆
# 种植面积     0.6
# Name: 606, dtype: object
# 年份      2027
# 地块       E14
# 季次         2
# 作物名称      高粱
# 种植面积     0.6
# Name: 607, dtype: object
# 年份      2027
# 地块       E14
# 季次         2
# 作物名称      土豆
# 种植面积     0.6
# Name: 608, dtype: object
# 年份      2027
# 地块       E15
# 季次         1
# 作物名称      土豆
# 种植面积     0.3
# Name: 609, dtype: object
# 年份      2027
# 地块       E16
# 季次         1
# 作物名称      土豆
# 种植面积     0.6
# Name: 610, dtype: object
# 年份      2027
# 地块        F1
# 季次         2
# 作物名称      土豆
# 种植面积     0.6
# Name: 611, dtype: object
# 年份      2027
# 地块        F2
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 612, dtype: object
# 年份      2027
# 地块        F2
# 季次         2
# 作物名称      土豆
# 种植面积     0.3
# Name: 613, dtype: object
# 年份      2027
# 地块        F3
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 614, dtype: object
# 年份      2027
# 地块        F3
# 季次         1
# 作物名称      土豆
# 种植面积     0.6
# Name: 615, dtype: object
# 年份      2027
# 地块        F4
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 616, dtype: object
# 年份      2027
# 地块        F4
# 季次         1
# 作物名称      土豆
# 种植面积     0.6
# Name: 617, dtype: object
# 年份      2028
# 地块        A2
# 季次         2
# 作物名称     榆黄菇
# 种植面积    53.2
# Name: 625, dtype: object
# 年份      2028
# 地块        A3
# 季次         1
# 作物名称      高粱
# 种植面积    13.8
# Name: 628, dtype: object
# 年份      2028
# 地块        A3
# 季次         1
# 作物名称      刀豆
# 种植面积    35.0
# Name: 631, dtype: object
# 年份      2028
# 地块        A4
# 季次         2
# 作物名称      爬豆
# 种植面积    72.0
# Name: 632, dtype: object
# 年份      2028
# 地块        A5
# 季次         1
# 作物名称      芸豆
# 种植面积    68.0
# Name: 637, dtype: object
# 年份      2028
# 地块        A6
# 季次         2
# 作物名称     榆黄菇
# 种植面积    53.2
# Name: 642, dtype: object
# 年份      2028
# 地块        B1
# 季次         2
# 作物名称      生菜
# 种植面积    59.4
# Name: 647, dtype: object
# 年份       2028
# 地块         B2
# 季次          2
# 作物名称      黄心菜
# 种植面积    43.15
# Name: 654, dtype: object
# 年份      2028
# 地块        B3
# 季次         1
# 作物名称      刀豆
# 种植面积    37.3
# Name: 657, dtype: object
# 年份      2028
# 地块        B4
# 季次         2
# 作物名称      高粱
# 种植面积    26.8
# Name: 661, dtype: object
# 年份      2028
# 地块        B5
# 季次         2
# 作物名称      刀豆
# 种植面积    22.3
# Name: 667, dtype: object
# 年份      2028
# 地块        B6
# 季次         2
# 作物名称      芸豆
# 种植面积    86.0
# Name: 672, dtype: object
# 年份      2028
# 地块        B7
# 季次         1
# 作物名称     榆黄菇
# 种植面积    55.0
# Name: 677, dtype: object
# 年份      2028
# 地块        B8
# 季次         2
# 作物名称      高粱
# 种植面积    42.8
# Name: 680, dtype: object
# 年份      2028
# 地块        B9
# 季次         1
# 作物名称      刀豆
# 种植面积    48.2
# Name: 685, dtype: object
# 年份      2028
# 地块       B10
# 季次         2
# 作物名称     黄心菜
# 种植面积    23.8
# Name: 690, dtype: object
# 年份      2028
# 地块       B11
# 季次         1
# 作物名称     白灵菇
# 种植面积    59.4
# Name: 693, dtype: object
# 年份      2028
# 地块       B12
# 季次         2
# 作物名称      土豆
# 种植面积    42.3
# Name: 694, dtype: object
# 年份      2028
# 地块       B13
# 季次         1
# 作物名称      土豆
# 种植面积    31.7
# Name: 700, dtype: object
# 年份      2028
# 地块       B14
# 季次         1
# 作物名称      刀豆
# 种植面积    17.3
# Name: 709, dtype: object
# 年份      2028
# 地块        C1
# 季次         2
# 作物名称      高粱
# 种植面积    13.8
# Name: 713, dtype: object
# 年份      2028
# 地块        C2
# 季次         1
# 作物名称      高粱
# 种植面积    11.8
# Name: 716, dtype: object
# 年份      2028
# 地块        C3
# 季次         2
# 作物名称      高粱
# 种植面积    13.8
# Name: 719, dtype: object
# 年份      2028
# 地块        C4
# 季次         2
# 作物名称      高粱
# 种植面积    16.8
# Name: 722, dtype: object
# 年份      2028
# 地块        C5
# 季次         2
# 作物名称      刀豆
# 种植面积    24.3
# Name: 728, dtype: object
# 年份      2028
# 地块        C6
# 季次         2
# 作物名称      高粱
# 种植面积    18.8
# Name: 731, dtype: object
# 年份      2028
# 地块        D1
# 季次         1
# 作物名称      高粱
# 种植面积    13.8
# Name: 734, dtype: object
# 年份      2028
# 地块       nan
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 737, dtype: object
# 年份      2028
# 地块       nan
# 季次         2
# 作物名称      高粱
# 种植面积     0.6
# Name: 738, dtype: object
# 年份      2028
# 地块        D2
# 季次         1
# 作物名称     黄心菜
# 种植面积    8.35
# Name: 741, dtype: object
# 年份       2028
# 地块         D3
# 季次          2
# 作物名称      黄心菜
# 种植面积    12.35
# Name: 746, dtype: object
# 年份      2028
# 地块        D4
# 季次         1
# 作物名称      高粱
# 种植面积     4.8
# Name: 747, dtype: object
# 年份      2028
# 地块        D5
# 季次         2
# 作物名称      高粱
# 种植面积     8.2
# Name: 751, dtype: object
# 年份      2028
# 地块        D6
# 季次         1
# 作物名称      高粱
# 种植面积    10.2
# Name: 754, dtype: object
# 年份      2028
# 地块        D7
# 季次         1
# 作物名称      刀豆
# 种植面积    19.3
# Name: 760, dtype: object
# 年份      2028
# 地块        D8
# 季次         2
# 作物名称      高粱
# 种植面积    18.8
# Name: 764, dtype: object
# 年份      2028
# 地块        E1
# 季次         2
# 作物名称      高粱
# 种植面积     0.6
# Name: 767, dtype: object
# 年份      2028
# 地块        E1
# 季次         1
# 作物名称      土豆
# 种植面积     0.6
# Name: 768, dtype: object
# 年份      2028
# 地块        E1
# 季次         2
# 作物名称      土豆
# 种植面积     0.6
# Name: 769, dtype: object
# 年份      2028
# 地块        E1
# 季次         1
# 作物名称     黄心菜
# 种植面积    0.45
# Name: 770, dtype: object
# 年份      2028
# 地块        E1
# 季次         2
# 作物名称     黄心菜
# 种植面积    0.45
# Name: 771, dtype: object
# 年份      2028
# 地块        E2
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 772, dtype: object
# 年份      2028
# 地块        E2
# 季次         2
# 作物名称      高粱
# 种植面积     0.6
# Name: 773, dtype: object
# 年份      2028
# 地块        E2
# 季次         1
# 作物名称      土豆
# 种植面积     0.6
# Name: 774, dtype: object
# 年份      2028
# 地块        E3
# 季次         1
# 作物名称      土豆
# 种植面积     0.6
# Name: 775, dtype: object
# 年份      2028
# 地块        E3
# 季次         2
# 作物名称      土豆
# 种植面积     0.6
# Name: 776, dtype: object
# 年份      2028
# 地块        E3
# 季次         1
# 作物名称     黄心菜
# 种植面积    0.45
# Name: 777, dtype: object
# 年份      2028
# 地块        E3
# 季次         2
# 作物名称     黄心菜
# 种植面积    0.45
# Name: 778, dtype: object
# 年份      2028
# 地块        E4
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 779, dtype: object
# 年份      2028
# 地块        E4
# 季次         1
# 作物名称      土豆
# 种植面积     0.6
# Name: 780, dtype: object
# 年份      2028
# 地块        E4
# 季次         2
# 作物名称      土豆
# 种植面积     0.6
# Name: 781, dtype: object
# 年份      2028
# 地块        E5
# 季次         2
# 作物名称      高粱
# 种植面积     0.6
# Name: 782, dtype: object
# 年份      2028
# 地块        E5
# 季次         1
# 作物名称      土豆
# 种植面积     0.6
# Name: 783, dtype: object
# 年份      2028
# 地块        E5
# 季次         2
# 作物名称      土豆
# 种植面积     0.6
# Name: 784, dtype: object
# 年份      2028
# 地块        E5
# 季次         1
# 作物名称     黄心菜
# 种植面积    0.45
# Name: 785, dtype: object
# 年份      2028
# 地块        E6
# 季次         1
# 作物名称      土豆
# 种植面积     0.6
# Name: 786, dtype: object
# 年份      2028
# 地块        E6
# 季次         2
# 作物名称      土豆
# 种植面积     0.6
# Name: 787, dtype: object
# 年份      2028
# 地块        E6
# 季次         1
# 作物名称     黄心菜
# 种植面积    0.45
# Name: 788, dtype: object
# 年份      2028
# 地块        E6
# 季次         2
# 作物名称     黄心菜
# 种植面积    0.45
# Name: 789, dtype: object
# 年份      2028
# 地块        E7
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 790, dtype: object
# 年份      2028
# 地块        E7
# 季次         2
# 作物名称      高粱
# 种植面积     0.6
# Name: 791, dtype: object
# 年份      2028
# 地块        E7
# 季次         2
# 作物名称      土豆
# 种植面积     0.6
# Name: 792, dtype: object
# 年份      2028
# 地块        E8
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 793, dtype: object
# 年份      2028
# 地块        E8
# 季次         2
# 作物名称      高粱
# 种植面积     0.6
# Name: 794, dtype: object
# 年份      2028
# 地块        E8
# 季次         1
# 作物名称      刀豆
# 种植面积     0.6
# Name: 795, dtype: object
# 年份      2028
# 地块        E9
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 796, dtype: object
# 年份      2028
# 地块        E9
# 季次         1
# 作物名称      土豆
# 种植面积     0.6
# Name: 797, dtype: object
# 年份      2028
# 地块        E9
# 季次         2
# 作物名称      土豆
# 种植面积     0.6
# Name: 798, dtype: object
# 年份      2028
# 地块       E10
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 799, dtype: object
# 年份      2028
# 地块       E10
# 季次         1
# 作物名称      土豆
# 种植面积     0.6
# Name: 800, dtype: object
# 年份      2028
# 地块       E11
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 801, dtype: object
# 年份      2028
# 地块       E11
# 季次         1
# 作物名称      土豆
# 种植面积     0.6
# Name: 802, dtype: object
# 年份      2028
# 地块       E11
# 季次         2
# 作物名称      土豆
# 种植面积     0.6
# Name: 803, dtype: object
# 年份      2028
# 地块       E11
# 季次         1
# 作物名称     黄心菜
# 种植面积    0.45
# Name: 804, dtype: object
# 年份      2028
# 地块       E11
# 季次         2
# 作物名称     黄心菜
# 种植面积    0.45
# Name: 805, dtype: object
# 年份      2028
# 地块       E12
# 季次         1
# 作物名称      土豆
# 种植面积     0.6
# Name: 806, dtype: object
# 年份      2028
# 地块       E12
# 季次         2
# 作物名称      土豆
# 种植面积     0.6
# Name: 807, dtype: object
# 年份      2028
# 地块       E12
# 季次         1
# 作物名称      刀豆
# 种植面积     0.6
# Name: 808, dtype: object
# 年份      2028
# 地块       E12
# 季次         2
# 作物名称      刀豆
# 种植面积     0.6
# Name: 809, dtype: object
# 年份      2028
# 地块       E12
# 季次         1
# 作物名称     黄心菜
# 种植面积    0.45
# Name: 810, dtype: object
# 年份      2028
# 地块       E12
# 季次         2
# 作物名称     黄心菜
# 种植面积    0.45
# Name: 811, dtype: object
# 年份      2028
# 地块       E13
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 812, dtype: object
# 年份      2028
# 地块       E13
# 季次         2
# 作物名称      高粱
# 种植面积     0.6
# Name: 813, dtype: object
# 年份      2028
# 地块       E13
# 季次         1
# 作物名称      土豆
# 种植面积     0.6
# Name: 814, dtype: object
# 年份      2028
# 地块       E14
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 815, dtype: object
# 年份      2028
# 地块       E14
# 季次         1
# 作物名称      土豆
# 种植面积     0.6
# Name: 816, dtype: object
# 年份      2028
# 地块       E15
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 817, dtype: object
# 年份      2028
# 地块       E15
# 季次         2
# 作物名称      高粱
# 种植面积     0.6
# Name: 818, dtype: object
# 年份      2028
# 地块       E15
# 季次         1
# 作物名称      土豆
# 种植面积     0.6
# Name: 819, dtype: object
# 年份      2028
# 地块       E16
# 季次         1
# 作物名称      土豆
# 种植面积     0.6
# Name: 820, dtype: object
# 年份      2028
# 地块       E16
# 季次         2
# 作物名称      土豆
# 种植面积     0.6
# Name: 821, dtype: object
# 年份      2028
# 地块       E16
# 季次         1
# 作物名称     黄心菜
# 种植面积    0.45
# Name: 822, dtype: object
# 年份      2028
# 地块       E16
# 季次         2
# 作物名称     黄心菜
# 种植面积    0.45
# Name: 823, dtype: object
# 年份      2028
# 地块        F1
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 824, dtype: object
# 年份      2028
# 地块        F1
# 季次         2
# 作物名称      高粱
# 种植面积     0.6
# Name: 825, dtype: object
# 年份      2028
# 地块        F1
# 季次         2
# 作物名称      土豆
# 种植面积     0.6
# Name: 826, dtype: object
# 年份      2028
# 地块        F2
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 827, dtype: object
# 年份      2028
# 地块        F2
# 季次         2
# 作物名称      高粱
# 种植面积     0.3
# Name: 828, dtype: object
# 年份      2028
# 地块        F2
# 季次         1
# 作物名称      土豆
# 种植面积     0.6
# Name: 829, dtype: object
# 年份      2028
# 地块        F3
# 季次         1
# 作物名称      土豆
# 种植面积     0.6
# Name: 830, dtype: object
# 年份      2028
# 地块        F3
# 季次         2
# 作物名称      土豆
# 种植面积     0.6
# Name: 831, dtype: object
# 年份      2028
# 地块        F4
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 832, dtype: object
# 年份      2028
# 地块        F4
# 季次         2
# 作物名称      高粱
# 种植面积     0.6
# Name: 833, dtype: object
# 年份      2028
# 地块        F4
# 季次         2
# 作物名称      土豆
# 种植面积     0.6
# Name: 834, dtype: object
# 年份      2029
# 地块        A1
# 季次         1
# 作物名称      爬豆
# 种植面积    80.3
# Name: 835, dtype: object
# 年份      2029
# 地块        A3
# 季次         1
# 作物名称      刀豆
# 种植面积    32.3
# Name: 844, dtype: object
# 年份      2029
# 地块        A4
# 季次         2
# 作物名称      芸豆
# 种植面积    69.9
# Name: 850, dtype: object
# 年份      2029
# 地块        A5
# 季次         1
# 作物名称      芸豆
# 种植面积    68.0
# Name: 855, dtype: object
# 年份      2029
# 地块        A6
# 季次         1
# 作物名称      生菜
# 种植面积    53.8
# Name: 858, dtype: object
# 年份      2029
# 地块        B1
# 季次         1
# 作物名称      黄豆
# 种植面积    58.2
# Name: 860, dtype: object
# 年份       2029
# 地块         B2
# 季次          2
# 作物名称      黄心菜
# 种植面积    42.55
# Name: 872, dtype: object
# 年份      2029
# 地块        B3
# 季次         1
# 作物名称      刀豆
# 种植面积    37.3
# Name: 875, dtype: object
# 年份      2029
# 地块        B4
# 季次         1
# 作物名称      刀豆
# 种植面积    28.0
# Name: 881, dtype: object
# 年份      2029
# 地块        B5
# 季次         1
# 作物名称      刀豆
# 种植面积    25.0
# Name: 884, dtype: object
# 年份       2029
# 地块         B7
# 季次          1
# 作物名称       红豆
# 种植面积    53.65
# Name: 888, dtype: object
# 年份       2029
# 地块         B8
# 季次          2
# 作物名称       生菜
# 种植面积    40.55
# Name: 897, dtype: object
# 年份      2029
# 地块        B9
# 季次         2
# 作物名称     榆黄菇
# 种植面积    48.2
# Name: 901, dtype: object
# 年份      2029
# 地块       B10
# 季次         2
# 作物名称      土豆
# 种植面积    21.1
# Name: 905, dtype: object
# 年份      2029
# 地块       B11
# 季次         1
# 作物名称      芸豆
# 种植面积    60.0
# Name: 912, dtype: object
# 年份      2029
# 地块       B12
# 季次         1
# 作物名称     小青菜
# 种植面积    41.4
# Name: 915, dtype: object
# 年份      2029
# 地块       B13
# 季次         2
# 作物名称      刀豆
# 种植面积    35.0
# Name: 925, dtype: object
# 年份      2029
# 地块       B14
# 季次         2
# 作物名称      高粱
# 种植面积    18.8
# Name: 926, dtype: object
# 年份      2029
# 地块        C1
# 季次         1
# 作物名称      高粱
# 种植面积    13.2
# Name: 929, dtype: object
# 年份      2029
# 地块        C2
# 季次         2
# 作物名称      高粱
# 种植面积    11.8
# Name: 933, dtype: object
# 年份      2029
# 地块        C3
# 季次         1
# 作物名称      高粱
# 种植面积    13.2
# Name: 936, dtype: object
# 年份      2029
# 地块        C4
# 季次         1
# 作物名称      刀豆
# 种植面积    18.0
# Name: 942, dtype: object
# 年份      2029
# 地块        C5
# 季次         2
# 作物名称      刀豆
# 种植面积    24.3
# Name: 946, dtype: object
# 年份      2029
# 地块        C6
# 季次         1
# 作物名称      刀豆
# 种植面积    19.4
# Name: 952, dtype: object
# 年份      2029
# 地块        D1
# 季次         1
# 作物名称      高粱
# 种植面积    13.2
# Name: 954, dtype: object
# 年份      2029
# 地块       nan
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 958, dtype: object
# 年份      2029
# 地块       nan
# 季次         2
# 作物名称      高粱
# 种植面积     0.6
# Name: 959, dtype: object
# 年份      2029
# 地块        D2
# 季次         1
# 作物名称      高粱
# 种植面积     8.2
# Name: 960, dtype: object
# 年份      2029
# 地块        D3
# 季次         2
# 作物名称      高粱
# 种植面积    14.0
# Name: 964, dtype: object
# 年份      2029
# 地块        D4
# 季次         2
# 作物名称      高粱
# 种植面积     6.0
# Name: 968, dtype: object
# 年份      2029
# 地块        D5
# 季次         2
# 作物名称      高粱
# 种植面积     8.2
# Name: 974, dtype: object
# 年份      2029
# 地块        D6
# 季次         2
# 作物名称      高粱
# 种植面积    10.2
# Name: 978, dtype: object
# 年份      2029
# 地块        D7
# 季次         1
# 作物名称      刀豆
# 种植面积    19.3
# Name: 983, dtype: object
# 年份      2029
# 地块        D8
# 季次         1
# 作物名称      高粱
# 种植面积    18.2
# Name: 987, dtype: object
# 年份      2029
# 地块        E1
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 991, dtype: object
# 年份      2029
# 地块        E1
# 季次         2
# 作物名称      高粱
# 种植面积     0.6
# Name: 992, dtype: object
# 年份      2029
# 地块        E1
# 季次         2
# 作物名称      土豆
# 种植面积     0.6
# Name: 993, dtype: object
# 年份      2029
# 地块        E2
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 994, dtype: object
# 年份      2029
# 地块        E2
# 季次         2
# 作物名称      高粱
# 种植面积     0.6
# Name: 995, dtype: object
# 年份      2029
# 地块        E2
# 季次         1
# 作物名称      土豆
# 种植面积     0.6
# Name: 996, dtype: object
# 年份      2029
# 地块        E3
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 997, dtype: object
# 年份      2029
# 地块        E3
# 季次         1
# 作物名称      土豆
# 种植面积     0.6
# Name: 998, dtype: object
# 年份      2029
# 地块        E4
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 999, dtype: object
# 年份      2029
# 地块        E4
# 季次         2
# 作物名称      高粱
# 种植面积     0.6
# Name: 1000, dtype: object
# 年份      2029
# 地块        E4
# 季次         2
# 作物名称      土豆
# 种植面积     0.6
# Name: 1001, dtype: object
# 年份      2029
# 地块        E5
# 季次         1
# 作物名称      土豆
# 种植面积     0.6
# Name: 1002, dtype: object
# 年份      2029
# 地块        E5
# 季次         2
# 作物名称      土豆
# 种植面积     0.6
# Name: 1003, dtype: object
# 年份      2029
# 地块        E5
# 季次         1
# 作物名称     黄心菜
# 种植面积    0.45
# Name: 1004, dtype: object
# 年份      2029
# 地块        E5
# 季次         2
# 作物名称     黄心菜
# 种植面积    0.45
# Name: 1005, dtype: object
# 年份      2029
# 地块        E6
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 1006, dtype: object
# 年份      2029
# 地块        E6
# 季次         2
# 作物名称      高粱
# 种植面积     0.6
# Name: 1007, dtype: object
# 年份      2029
# 地块        E6
# 季次         1
# 作物名称      土豆
# 种植面积     0.6
# Name: 1008, dtype: object
# 年份      2029
# 地块        E7
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 1009, dtype: object
# 年份      2029
# 地块        E7
# 季次         2
# 作物名称      高粱
# 种植面积     0.6
# Name: 1010, dtype: object
# 年份      2029
# 地块        E7
# 季次         2
# 作物名称      土豆
# 种植面积     0.6
# Name: 1011, dtype: object
# 年份      2029
# 地块        E8
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 1012, dtype: object
# 年份      2029
# 地块        E8
# 季次         1
# 作物名称      土豆
# 种植面积     0.6
# Name: 1013, dtype: object
# 年份      2029
# 地块        E9
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 1014, dtype: object
# 年份      2029
# 地块        E9
# 季次         2
# 作物名称      高粱
# 种植面积     0.6
# Name: 1015, dtype: object
# 年份      2029
# 地块        E9
# 季次         2
# 作物名称      土豆
# 种植面积     0.6
# Name: 1016, dtype: object
# 年份      2029
# 地块       E10
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 1017, dtype: object
# 年份      2029
# 地块       E10
# 季次         2
# 作物名称      高粱
# 种植面积     0.6
# Name: 1018, dtype: object
# 年份      2029
# 地块       E10
# 季次         1
# 作物名称      土豆
# 种植面积     0.6
# Name: 1019, dtype: object
# 年份      2029
# 地块       E11
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 1020, dtype: object
# 年份      2029
# 地块       E11
# 季次         2
# 作物名称      高粱
# 种植面积     0.6
# Name: 1021, dtype: object
# 年份      2029
# 地块       E11
# 季次         1
# 作物名称      土豆
# 种植面积     0.6
# Name: 1022, dtype: object
# 年份      2029
# 地块       E12
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 1023, dtype: object
# 年份      2029
# 地块       E12
# 季次         2
# 作物名称      高粱
# 种植面积     0.6
# Name: 1024, dtype: object
# 年份      2029
# 地块       E12
# 季次         2
# 作物名称      土豆
# 种植面积     0.6
# Name: 1025, dtype: object
# 年份      2029
# 地块       E13
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 1026, dtype: object
# 年份      2029
# 地块       E13
# 季次         2
# 作物名称      高粱
# 种植面积     0.6
# Name: 1027, dtype: object
# 年份      2029
# 地块       E13
# 季次         2
# 作物名称      土豆
# 种植面积     0.6
# Name: 1028, dtype: object
# 年份      2029
# 地块       E14
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 1029, dtype: object
# 年份      2029
# 地块       E14
# 季次         2
# 作物名称      高粱
# 种植面积     0.6
# Name: 1030, dtype: object
# 年份      2029
# 地块       E14
# 季次         1
# 作物名称      土豆
# 种植面积     0.6
# Name: 1031, dtype: object
# 年份      2029
# 地块       E15
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 1032, dtype: object
# 年份      2029
# 地块       E15
# 季次         2
# 作物名称      高粱
# 种植面积     0.6
# Name: 1033, dtype: object
# 年份      2029
# 地块       E15
# 季次         1
# 作物名称      土豆
# 种植面积     0.6
# Name: 1034, dtype: object
# 年份      2029
# 地块       E16
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 1035, dtype: object
# 年份      2029
# 地块       E16
# 季次         2
# 作物名称      高粱
# 种植面积     0.6
# Name: 1036, dtype: object
# 年份      2029
# 地块       E16
# 季次         2
# 作物名称      土豆
# 种植面积     0.6
# Name: 1037, dtype: object
# 年份      2029
# 地块        F1
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 1038, dtype: object
# 年份      2029
# 地块        F1
# 季次         1
# 作物名称      土豆
# 种植面积     0.6
# Name: 1039, dtype: object
# 年份      2029
# 地块        F2
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 1040, dtype: object
# 年份      2029
# 地块        F2
# 季次         2
# 作物名称      高粱
# 种植面积     0.6
# Name: 1041, dtype: object
# 年份      2029
# 地块        F2
# 季次         2
# 作物名称      土豆
# 种植面积     0.6
# Name: 1042, dtype: object
# 年份      2029
# 地块        F3
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 1043, dtype: object
# 年份      2029
# 地块        F3
# 季次         2
# 作物名称      高粱
# 种植面积     0.6
# Name: 1044, dtype: object
# 年份      2029
# 地块        F3
# 季次         1
# 作物名称      土豆
# 种植面积     0.6
# Name: 1045, dtype: object
# 年份      2029
# 地块        F4
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 1046, dtype: object
# 年份      2029
# 地块        F4
# 季次         2
# 作物名称      高粱
# 种植面积     0.6
# Name: 1047, dtype: object
# 年份      2029
# 地块        F4
# 季次         2
# 作物名称      土豆
# 种植面积     0.6
# Name: 1048, dtype: object
# 年份      2030
# 地块        A1
# 季次         2
# 作物名称      豇豆
# 种植面积    80.0
# Name: 1051, dtype: object
# 年份      2030
# 地块        A2
# 季次         2
# 作物名称      生菜
# 种植面积    53.8
# Name: 1057, dtype: object
# 年份       2030
# 地块         A3
# 季次          2
# 作物名称      黄心菜
# 种植面积    33.35
# Name: 1061, dtype: object
# 年份      2030
# 地块        A4
# 季次         1
# 作物名称      芸豆
# 种植面积    72.0
# Name: 1064, dtype: object
# 年份      2030
# 地块        A6
# 季次         2
# 作物名称      爬豆
# 种植面积    55.0
# Name: 1067, dtype: object
# 年份      2030
# 地块        B1
# 季次         1
# 作物名称      生菜
# 种植面积    59.1
# Name: 1074, dtype: object
# 年份      2030
# 地块        B2
# 季次         1
# 作物名称      黄豆
# 种植面积    46.0
# Name: 1076, dtype: object
# 年份      2030
# 地块        B3
# 季次         1
# 作物名称      刀豆
# 种植面积    37.6
# Name: 1081, dtype: object
# 年份      2030
# 地块        B4
# 季次         2
# 作物名称      刀豆
# 种植面积    25.3
# Name: 1088, dtype: object
# 年份      2030
# 地块        B5
# 季次         1
# 作物名称      高粱
# 种植面积    23.2
# Name: 1091, dtype: object
# 年份      2030
# 地块        B6
# 季次         1
# 作物名称      豇豆
# 种植面积    85.7
# Name: 1096, dtype: object
# 年份      2030
# 地块        B7
# 季次         1
# 作物名称     榆黄菇
# 种植面积    53.2
# Name: 1099, dtype: object
# 年份      2030
# 地块       B10
# 季次         1
# 作物名称      高粱
# 种植面积    23.2
# Name: 1111, dtype: object
# 年份      2030
# 地块       B11
# 季次         2
# 作物名称     菠菜
# 种植面积    60.0
# Name: 1119, dtype: object
# 年份      2030
# 地块       B12
# 季次         1
# 作物名称      黑豆
# 种植面积    45.0
# Name: 1120, dtype: object
# 年份      2030
# 地块       B13
# 季次         2
# 作物名称      刀豆
# 种植面积    32.3
# Name: 1127, dtype: object
# 年份      2030
# 地块       B14
# 季次         2
# 作物名称      刀豆
# 种植面积    17.3
# Name: 1133, dtype: object
# 年份      2030
# 地块        C1
# 季次         1
# 作物名称      高粱
# 种植面积    13.2
# Name: 1136, dtype: object
# 年份      2030
# 地块        C2
# 季次         1
# 作物名称      高粱
# 种植面积    11.2
# Name: 1140, dtype: object
# 年份      2030
# 地块        C3
# 季次         1
# 作物名称      高粱
# 种植面积    13.2
# Name: 1144, dtype: object
# 年份      2030
# 地块        C4
# 季次         1
# 作物名称      刀豆
# 种植面积    15.3
# Name: 1150, dtype: object
# 年份      2030
# 地块        C5
# 季次         2
# 作物名称      高粱
# 种植面积    25.8
# Name: 1154, dtype: object
# 年份      2030
# 地块        C6
# 季次         2
# 作物名称      刀豆
# 种植面积    17.3
# Name: 1160, dtype: object
# 年份      2030
# 地块        D1
# 季次         1
# 作物名称      高粱
# 种植面积    13.2
# Name: 1163, dtype: object
# 年份      2030
# 地块       nan
# 季次         2
# 作物名称      高粱
# 种植面积     0.6
# Name: 1167, dtype: object
# 年份      2030
# 地块       nan
# 季次         1
# 作物名称      土豆
# 种植面积     0.6
# Name: 1168, dtype: object
# 年份      2030
# 地块        D2
# 季次         1
# 作物名称      刀豆
# 种植面积     7.3
# Name: 1171, dtype: object
# 年份      2030
# 地块        D3
# 季次         2
# 作物名称      高粱
# 种植面积    12.2
# Name: 1176, dtype: object
# 年份      2030
# 地块        D4
# 季次         1
# 作物名称      高粱
# 种植面积     4.8
# Name: 1179, dtype: object
# 年份      2030
# 地块        D5
# 季次         1
# 作物名称      土豆
# 种植面积     6.1
# Name: 1182, dtype: object
# 年份      2030
# 地块        D6
# 季次         2
# 作物名称      高粱
# 种植面积    10.2
# Name: 1191, dtype: object
# 年份      2030
# 地块        D7
# 季次         2
# 作物名称      高粱
# 种植面积    20.2
# Name: 1195, dtype: object
# 年份      2030
# 地块        D8
# 季次         1
# 作物名称      高粱
# 种植面积    18.2
# Name: 1198, dtype: object
# 年份      2030
# 地块        E1
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 1202, dtype: object
# 年份      2030
# 地块        E1
# 季次         2
# 作物名称      高粱
# 种植面积     0.6
# Name: 1203, dtype: object
# 年份      2030
# 地块        E1
# 季次         1
# 作物名称      土豆
# 种植面积     0.6
# Name: 1204, dtype: object
# 年份      2030
# 地块        E2
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 1205, dtype: object
# 年份      2030
# 地块        E2
# 季次         2
# 作物名称      高粱
# 种植面积     0.6
# Name: 1206, dtype: object
# 年份      2030
# 地块        E2
# 季次         1
# 作物名称      土豆
# 种植面积     0.6
# Name: 1207, dtype: object
# 年份      2030
# 地块        E3
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 1208, dtype: object
# 年份      2030
# 地块        E3
# 季次         2
# 作物名称      土豆
# 种植面积     0.6
# Name: 1209, dtype: object
# 年份      2030
# 地块        E4
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 1210, dtype: object
# 年份      2030
# 地块        E4
# 季次         2
# 作物名称      高粱
# 种植面积     0.6
# Name: 1211, dtype: object
# 年份      2030
# 地块        E4
# 季次         2
# 作物名称      土豆
# 种植面积     0.6
# Name: 1212, dtype: object
# 年份      2030
# 地块        E5
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 1213, dtype: object
# 年份      2030
# 地块        E5
# 季次         2
# 作物名称      高粱
# 种植面积     0.6
# Name: 1214, dtype: object
# 年份      2030
# 地块        E5
# 季次         1
# 作物名称      土豆
# 种植面积     0.6
# Name: 1215, dtype: object
# 年份      2030
# 地块        E6
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 1216, dtype: object
# 年份      2030
# 地块        E6
# 季次         2
# 作物名称      高粱
# 种植面积     0.6
# Name: 1217, dtype: object
# 年份      2030
# 地块        E6
# 季次         2
# 作物名称      土豆
# 种植面积     0.6
# Name: 1218, dtype: object
# 年份      2030
# 地块        E7
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 1219, dtype: object
# 年份      2030
# 地块        E7
# 季次         2
# 作物名称      高粱
# 种植面积     0.6
# Name: 1220, dtype: object
# 年份      2030
# 地块        E7
# 季次         1
# 作物名称      土豆
# 种植面积     0.6
# Name: 1221, dtype: object
# 年份      2030
# 地块        E8
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 1222, dtype: object
# 年份      2030
# 地块        E8
# 季次         2
# 作物名称      高粱
# 种植面积     0.6
# Name: 1223, dtype: object
# 年份      2030
# 地块        E8
# 季次         1
# 作物名称      土豆
# 种植面积     0.6
# Name: 1224, dtype: object
# 年份      2030
# 地块        E9
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 1225, dtype: object
# 年份      2030
# 地块        E9
# 季次         2
# 作物名称      高粱
# 种植面积     0.6
# Name: 1226, dtype: object
# 年份      2030
# 地块        E9
# 季次         1
# 作物名称      土豆
# 种植面积     0.6
# Name: 1227, dtype: object
# 年份      2030
# 地块       E10
# 季次         1
# 作物名称      土豆
# 种植面积     0.6
# Name: 1228, dtype: object
# 年份      2030
# 地块       E10
# 季次         2
# 作物名称      土豆
# 种植面积     0.6
# Name: 1229, dtype: object
# 年份      2030
# 地块       E10
# 季次         1
# 作物名称     黄心菜
# 种植面积    0.45
# Name: 1230, dtype: object
# 年份      2030
# 地块       E11
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 1231, dtype: object
# 年份      2030
# 地块       E11
# 季次         2
# 作物名称      高粱
# 种植面积     0.6
# Name: 1232, dtype: object
# 年份      2030
# 地块       E11
# 季次         1
# 作物名称      土豆
# 种植面积     0.6
# Name: 1233, dtype: object
# 年份      2030
# 地块       E12
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 1234, dtype: object
# 年份      2030
# 地块       E12
# 季次         2
# 作物名称      高粱
# 种植面积     0.6
# Name: 1235, dtype: object
# 年份      2030
# 地块       E12
# 季次         2
# 作物名称      土豆
# 种植面积     0.6
# Name: 1236, dtype: object
# 年份      2030
# 地块       E13
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 1237, dtype: object
# 年份      2030
# 地块       E13
# 季次         2
# 作物名称      高粱
# 种植面积     0.6
# Name: 1238, dtype: object
# 年份      2030
# 地块       E13
# 季次         1
# 作物名称      土豆
# 种植面积     0.6
# Name: 1239, dtype: object
# 年份      2030
# 地块       E14
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 1240, dtype: object
# 年份      2030
# 地块       E14
# 季次         1
# 作物名称      土豆
# 种植面积     0.6
# Name: 1241, dtype: object
# 年份      2030
# 地块       E15
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 1242, dtype: object
# 年份      2030
# 地块       E15
# 季次         2
# 作物名称      高粱
# 种植面积     0.6
# Name: 1243, dtype: object
# 年份      2030
# 地块       E15
# 季次         1
# 作物名称      土豆
# 种植面积     0.6
# Name: 1244, dtype: object
# 年份      2030
# 地块       E16
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 1245, dtype: object
# 年份      2030
# 地块       E16
# 季次         2
# 作物名称      土豆
# 种植面积     0.6
# Name: 1246, dtype: object
# 年份      2030
# 地块        F1
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 1247, dtype: object
# 年份      2030
# 地块        F1
# 季次         1
# 作物名称      土豆
# 种植面积     0.6
# Name: 1248, dtype: object
# 年份      2030
# 地块        F2
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 1249, dtype: object
# 年份      2030
# 地块        F2
# 季次         2
# 作物名称      高粱
# 种植面积     0.6
# Name: 1250, dtype: object
# 年份      2030
# 地块        F2
# 季次         2
# 作物名称      土豆
# 种植面积     0.6
# Name: 1251, dtype: object
# 年份      2030
# 地块        F3
# 季次         1
# 作物名称      土豆
# 种植面积     0.6
# Name: 1252, dtype: object
# 年份      2030
# 地块        F3
# 季次         2
# 作物名称      土豆
# 种植面积     0.6
# Name: 1253, dtype: object
# 年份      2030
# 地块        F3
# 季次         1
# 作物名称      刀豆
# 种植面积     0.6
# Name: 1254, dtype: object
# 年份      2030
# 地块        F3
# 季次         2
# 作物名称      刀豆
# 种植面积     0.6
# Name: 1255, dtype: object
# 年份      2030
# 地块        F3
# 季次         1
# 作物名称      生菜
# 种植面积     0.6
# Name: 1256, dtype: object
# 年份      2030
# 地块        F3
# 季次         1
# 作物名称      芹菜
# 种植面积     0.9
# Name: 1257, dtype: object
# 年份      2030
# 地块        F4
# 季次         1
# 作物名称      高粱
# 种植面积     0.6
# Name: 1258, dtype: object
# 年份      2030
# 地块        F4
# 季次         1
# 作物名称      土豆
# 种植面积     0.6
# Name: 1259, dtype: object

# %%
from openpyxl import load_workbook

file_path = 'result1_2.xlsx'

book = load_workbook(file_path)

crop_names = df_filtered_results['作物名称'].unique().tolist()

plot_to_row = {
    'A1': 2, 'A2': 3, 'A3': 4, 'A4': 5, 'A5': 6, 'A6': 7,
    'B1': 8, 'B2': 9, 'B3': 10, 'B4': 11, 'B5': 12, 'B6': 13,
    'B7': 14, 'B8': 15, 'B9': 16, 'B10': 17, 'B11': 18, 'B12': 19,
    'B13': 20, 'B14': 21,
    'C1': 22, 'C2': 23, 'C3': 24, 'C4': 25, 'C5': 26, 'C6': 27,
    'D1': 28, 'D2': 29, 'D3': 30, 'D4': 31, 'D5': 32, 'D6': 33,
    'D7': 34, 'D8': 35,
    'E1': 36, 'E2': 37, 'E3': 38, 'E4': 39, 'E5': 40, 'E6': 41,
    'E7': 42, 'E8': 43, 'E9': 44, 'E10': 45, 'E11': 46, 'E12': 47,
    'E13': 48, 'E14': 49, 'E15': 50, 'E16': 51,
    'F1': 52, 'F2': 53, 'F3': 54, 'F4': 55
}

# 地块编号 -> Excel 行号的映射表 (季次2，从56行开始)
plot_to_row_season2 = {
    'D1': 56, 'D2': 57, 'D3': 58, 'D4': 59, 'D5': 60, 'D6': 61, 'D7': 62, 'D8': 63,
    'E1': 64, 'E2': 65, 'E3': 66, 'E4': 67, 'E5': 68, 'E6': 69, 'E7': 70, 'E8': 71,
    'E9': 72, 'E10': 73, 'E11': 74, 'E12': 75, 'E13': 76, 'E14': 77, 'E15': 78, 'E16': 79,
    'F1': 80, 'F2': 81, 'F3': 82, 'F4': 83
}

# 作物名称 -> Excel 列号的映射表
crop_to_col = {
    '黄豆': 3, '黑豆': 4, '红豆': 5, '绿豆': 6, '爬豆': 7, '小麦': 8, '玉米': 9, '谷子': 10, '高粱': 11,
    '黍子': 12, '荞麦': 13, '南瓜': 14, '红薯': 15, '莜麦': 16, '大麦': 17, '水稻': 18, '豇豆': 19, '刀豆': 20,
    '芸豆': 21, '土豆': 22, '西红柿': 23, '茄子': 24, '菠菜': 25, '青椒': 26, '菜花': 27, '包菜': 28, '油麦菜': 29,
    '小青菜': 30, '黄瓜': 31, '生菜': 32, '辣椒': 33, '空心菜': 34, '黄心菜': 35, '芹菜': 36, '大白菜': 37, '白萝卜': 38,
    '红萝卜': 39, '榆黄菇': 40, '香菇': 41, '白灵菇': 42, '羊肚菌': 43
}


def get_y_coord(plot, season):
    if season == 1:
        return plot_to_row.get(plot,2)  # 获取季次1对应的行号
    elif season == 2:
        return plot_to_row_season2.get(plot, 56)  # 获取季次2对应的行号，默认从第56行开始
# 填充表格为0的函数
def fill_sheet_with_zeros(sheet):
    for row in range(2, 84):  # 遍历行（C2 到 AP83）
        for col in range(3, 44):  # 遍历列（C 到 AP）
            sheet.cell(row=row, column=col).value = 0  # 填入0
# 遍历所有年份的表格，先填充为0
for year in range(2024, 2031):  # 假设年份从2024到2030
    sheet_name = str(year)
    sheet = book[sheet_name]
    fill_sheet_with_zeros(sheet)  # 将C2到AP83单元格填充为0
for _, row in df_filtered_results.iterrows():
    year = row['年份']
    plot = row['地块']
    season = row['季次']
    crop = row['作物名称'].strip()
    area = row['种植面积']
    sheet_name = str(year)
    sheet = book[sheet_name]
    # 根据地块和季次确定行数（Y 坐标）
    if season == 2 and plot[0] in ['A','B','C']:
        continue
    y_coord = get_y_coord(plot, season)
        # 根据作物名称确定列数（X 坐标）
    x_coord = crop_to_col.get(crop)  # 通过作物名称获取列号
        # 将种植面积写入对应的单元格
    # 检查是否正确获取了坐标
    if y_coord is None or x_coord is None:
        print(f"Skipping plot {plot} and crop {crop} in year {year} due to missing coordinates.")
        continue
    sheet.cell(row=y_coord, column=x_coord).value = area
        # 保存修改后的 Excel 文件
book.save(file_path)
book.close()

print("结果已成功写入 Excel 文件！")
